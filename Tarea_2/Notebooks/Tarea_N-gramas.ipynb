# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/NLP-MCD/blob/main/04-N-gramas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modelos de lenguaje: $N$-gramas

# %% [markdown]
# ## Ejercicios - Tarea 2

# %% [markdown]
# ⭕ Repetir el experimento con 2-gramas, 4-gramas y 2-skip-2-gramas.

# %%
# Importar librerías necesarias
import nltk
from nltk import bigrams, trigrams
from nltk.corpus import reuters
from collections import defaultdict, Counter
from itertools import chain, islice
import string

# Descargar los recursos que necesita NLTK
nltk.download('reuters')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     C:\Users\jcbar\AppData\Roaming\nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jcbar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jcbar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Función para crear el modelo de n-gramas deseado
def generate_ngrams(corpus, n, skip=0, remove_punctuation=False):
    """
    Genera n-gramas (o skip-gramas si skip > 0) a partir de un corpus.
    
    corpus: Lista de documentos
    n: Número de palabras en el n-grama
    skip: Número de palabras a saltar (solo para skip-gramas)
    remove_punctuation: Si se desean eliminar los signos de puntuación
    
    return: Lista de n-gramas
    """
    ngrams = []
    for doc in corpus:
        # Tokenización
        tokens = nltk.word_tokenize(doc.lower())
        
        # Remover signos de puntuación
        if remove_punctuation:
            tokens = [word for word in tokens if word not in string.punctuation]
        
        # Generar skip-gramas
        if skip > 0:
            tokens = list(chain(*[tokens[i::skip+1] for i in range(skip+1)]))
        
        # Crear n-gramas
        n_grams = list(nltk.ngrams(tokens, n))
        ngrams.extend(n_grams)
    
    return ngrams

# %% [markdown]
# En cada uno de ellos:
#
# * **Generar el modelo de $n$-gramas (con y sin signos de puntuación).**

# %%
# Documentos de entrenamiento del corpus
docs = [reuters.raw(fileid) for fileid in reuters.fileids()]

# Generar 2-gramas con y sin signos de puntuación
bigrams_with_punctuation = generate_ngrams(docs, 2, remove_punctuation=False)
bigrams_without_punctuation = generate_ngrams(docs, 2, remove_punctuation=True)

print("Ejemplo de 2-gramas con signos de puntuación:")
print(bigrams_with_punctuation[:5])

print("\nEjemplo de 2-gramas sin signos de puntuación:")
print(bigrams_without_punctuation[:5])
# Out:
# Ejemplo de 2-gramas con signos de puntuación:
# [('asian', 'exporters'), ('exporters', 'fear'), ('fear', 'damage'), ('damage', 'from'), ('from', 'u.s.-japan')]
#
# Ejemplo de 2-gramas sin signos de puntuación:
# [('asian', 'exporters'), ('exporters', 'fear'), ('fear', 'damage'), ('damage', 'from'), ('from', 'u.s.-japan')]

# %%
# Generar 4-gramas con y sin signos de puntuación
fourgrams_with_punctuation = generate_ngrams(docs, 4, remove_punctuation=False)
fourgrams_without_punctuation = generate_ngrams(docs, 4, remove_punctuation=True)

print("\nEjemplo de 4-gramas con signos de puntuación:")
print(fourgrams_with_punctuation[:5])

print("\nEjemplo de 4-gramas sin signos de puntuación:")
print(fourgrams_without_punctuation[:5])
# Out:
# Ejemplo de 4-gramas con signos de puntuación:
# [('asian', 'exporters', 'fear', 'damage'), ('exporters', 'fear', 'damage', 'from'), ('fear', 'damage', 'from', 'u.s.-japan'), ('damage', 'from', 'u.s.-japan', 'rift'), ('from', 'u.s.-japan', 'rift', 'mounting')]
#
# Ejemplo de 4-gramas sin signos de puntuación:
# [('asian', 'exporters', 'fear', 'damage'), ('exporters', 'fear', 'damage', 'from'), ('fear', 'damage', 'from', 'u.s.-japan'), ('damage', 'from', 'u.s.-japan', 'rift'), ('from', 'u.s.-japan', 'rift', 'mounting')]

# %%
# Generar 2-skip-2-gramas con y sin signos de puntuación
skip_2_gram_with_punctuation = generate_ngrams(docs, 2, skip=2, remove_punctuation=False)
skip_2_gram_without_punctuation = generate_ngrams(docs, 2, skip=2, remove_punctuation=True)

print("\nEjemplo de 2-skip-2-gramas con signos de puntuación:")
print(skip_2_gram_with_punctuation[:5])

print("\nEjemplo de 2-skip-2-gramas sin signos de puntuación:")
print(skip_2_gram_without_punctuation[:5])
# Out:
# Ejemplo de 2-skip-2-gramas con signos de puntuación:
# [('asian', 'damage'), ('damage', 'rift'), ('rift', 'friction'), ('friction', 'u.s.'), ('u.s.', 'has')]
#
# Ejemplo de 2-skip-2-gramas sin signos de puntuación:
# [('asian', 'damage'), ('damage', 'rift'), ('rift', 'friction'), ('friction', 'u.s.'), ('u.s.', 'has')]

# %% [markdown]
# * **Realizar el experimento de predecir la siguiente palabra con el texto. Evaluar el experimento.**

# %%
# Función para entrenar un modelo de n-gramas
def train_ngram_model(ngrams):
    """
    Entrena un modelo basado en la frecuencia de los n-gramas.
    
    ngrams: Lista de n-gramas
    
    return: Un diccionario que mapea los (n-1)-gramas a cada posible palabra siguiente con sus frecuencias respectivas
    """
    
    # Instanciamos defaultdict con contador para almacener el número de veces que aparece cada n-grama
    model = defaultdict(Counter)
    for ngram in ngrams:
        prefix, word = tuple(ngram[:-1]), ngram[-1]
        model[prefix][word] += 1
    return model

# %%
# Entrenar el modelo 2-gramas con y sin signos de puntuación
bigram_model_with_punctuation = train_ngram_model(bigrams_with_punctuation)
bigram_model_without_punctuation = train_ngram_model(bigrams_without_punctuation)

# Entrenar el modelo 4-gramas con y sin signos de puntuación
fourgram_model_with_punctuation = train_ngram_model(fourgrams_with_punctuation)
fourgram_model_without_punctuation = train_ngram_model(fourgrams_without_punctuation)

# Entrenar el modelo 2-skip-2-gramas con y sin signos de puntuación
skip_2_gram_model_with_punctuation = train_ngram_model(skip_2_gram_with_punctuation)
skip_2_gram_model_without_punctuation = train_ngram_model(skip_2_gram_without_punctuation)

# %%
# Función para predecir la siguiente palabra con base en un (n-1)-grama
def predict_next_word(model, text, n):
    """
    Predice la siguiente palabra en una secuencia dada utilizando un modelo n-grama.
    
    model: Un modelo n-grama entrenado
    text: La secuencia de texto (lista de palabras)
    n: El tamaño del n-grama
    
    return: La palabra más probable para continuar la secuencia
    """
    
    # Tomar el (n-1)-grama
    prefix = tuple(text.split()[-(n-1):])
    
    # Obtener las posibles siguientes palabras y sus frecuencias
    next_word_candidates = model[prefix]
    
    # Devolver la palabra con la frecuencia más alta
    if next_word_candidates:
        return next_word_candidates.most_common(1)[0][0]
    else:
        return None  # No hay palabras posibles

# %%
# Función para evaluar el desempeño predictivo del modelo con base en un archivo del corpus
def evaluar(text, model, n):
    """
    Evalúa el modelo de n-gramas y muestra las predicciones realizadas.
    
    text: Texto a evaluar
    model: Modelo n-grama entrenado
    n: Tamaño del n-grama
    """

    # Tokenización del texto
    tokens = nltk.word_tokenize(text.lower())
    
    # Variables de conteo
    correct_predictions = 0
    total_predictions = 0
    
    # Obtener los n-gramas del texto que servirán de referencia
    for i in range(len(tokens) - n):
        prefix_tokens = tokens[i:i+(n-1)]
        prefix = "-".join(f"'{token}'" for token in prefix_tokens)
        true_word = tokens[i+(n-1)]
        predicted_word = predict_next_word(model, " ".join(prefix_tokens), n)
        
        # Mostrar la predicción y el resultado esperado
        if predicted_word is None:
            print(f"Predicción para {prefix}: SIN PREDICCIÓN. Debería ser: '{true_word}'")
        else:
            print(f"Predicción para {prefix}: '{predicted_word}'. Debería ser: '{true_word}'")
        
        # Evaluar predicción
        if predicted_word == true_word:
            correct_predictions += 1
        total_predictions += 1
    
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0
    print(f"\nAciertos: {correct_predictions}/{total_predictions} = {accuracy * 100:.2f}%\n")

# %%
# Ejemplo con un archivo del corpus Reuters
text = reuters.raw('test/14826')

print("2-grama con signos de puntuación:\n")
evaluar(text, bigram_model_with_punctuation, 2)
# Out:
# 2-grama con signos de puntuación:
#
# Predicción para 'asian': 'nations'. Debería ser: 'exporters'
# Predicción para 'exporters': 'report'. Debería ser: 'fear'
# Predicción para 'fear': 'of'. Debería ser: 'damage'
# Predicción para 'damage': 'to'. Debería ser: 'from'
# Predicción para 'from': 'the'. Debería ser: 'u.s.-japan'
# Predicción para 'u.s.-japan': 'trade'. Debería ser: 'rift'
# Predicción para 'rift': 'mounting'. Debería ser: 'mounting'
# Predicción para 'mounting': 'trade'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'friction'
# Predicción para 'friction': 'materials'. Debería ser: 'between'
# Predicción para 'between': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'has'
# Predicción para 'has': 'been'. Debería ser: 'raised'
# Predicción para 'raised': 'its'. Debería ser: 'fears'
# Predicción para 'fears': 'of'. Debería ser: 'among'
# Predicción para 'among': 'the'. Debería ser: 'many'
# Predicción para 'many': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'asia'
# Predicción para 'asia': 'and'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'exporting'
# Predicción para 'exporting': 'countries'. Debería ser: 'nations'
# Predicción para 'nations': 'to'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'row'
# Predicción para 'row': 'publishers'. Debería ser: 'could'
# Predicción para 'could': 'be'. Debería ser: 'inflict'
# Predicción para 'inflict': 'far-reaching'. Debería ser: 'far-reaching'
# Predicción para 'far-reaching': 'economic'. Debería ser: 'economic'
# Predicción para 'economic': 'growth'. Debería ser: 'damage'
# Predicción para 'damage': 'to'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'said'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'officials'
# Predicción para 'officials': 'said'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'they'
# Predicción para 'they': 'said'. Debería ser: 'told'
# Predicción para 'told': 'reuters'. Debería ser: 'reuter'
# Predicción para 'reuter': '...'. Debería ser: 'correspondents'
# Predicción para 'correspondents': '.'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'asian'
# Predicción para 'asian': 'nations'. Debería ser: 'capitals'
# Predicción para 'capitals': ','. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'move'
# Predicción para 'move': 'to'. Debería ser: 'against'
# Predicción para 'against': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'might'
# Predicción para 'might': 'be'. Debería ser: 'boost'
# Predicción para 'boost': 'the'. Debería ser: 'protectionist'
# Predicción para 'protectionist': 'sentiment'. Debería ser: 'sentiment'
# Predicción para 'sentiment': 'in'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'lead'
# Predicción para 'lead': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'curbs'
# Predicción para 'curbs': 'on'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'american'
# Predicción para 'american': 'express'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'their'
# Predicción para 'their': 'own'. Debería ser: 'products'
# Predicción para 'products': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'but'
# Predicción para 'but': 'the'. Debería ser: 'some'
# Predicción para 'some': 'of'. Debería ser: 'exporters'
# Predicción para 'exporters': 'report'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'while'
# Predicción para 'while': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'conflict'
# Predicción para 'conflict': 'with'. Debería ser: 'would'
# Predicción para 'would': 'be'. Debería ser: 'hurt'
# Predicción para 'hurt': 'by'. Debería ser: 'them'
# Predicción para 'them': 'to'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'long-run'
# Predicción para 'long-run': ','. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'short-term'
# Predicción para 'short-term': 'discount'. Debería ser: 'tokyo'
# Predicción para 'tokyo': ','. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'loss'
# Predicción para 'loss': 'of'. Debería ser: 'might'
# Predicción para 'might': 'be'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'their'
# Predicción para 'their': 'own'. Debería ser: 'gain'
# Predicción para 'gain': 'of'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'has'
# Predicción para 'has': 'been'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'will'
# Predicción para 'will': 'be'. Debería ser: 'impose'
# Predicción para 'impose': 'tariffs'. Debería ser: '300'
# Predicción para '300': 'mln'. Debería ser: 'mln'
# Predicción para 'mln': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'japanese'
# Predicción para 'japanese': 'government'. Debería ser: 'electronics'
# Predicción para 'electronics': 'inc'. Debería ser: 'goods'
# Predicción para 'goods': 'and'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'april'
# Predicción para 'april': '30'. Debería ser: '17'
# Predicción para '17': 'cts'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'retaliation'
# Predicción para 'retaliation': 'for'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'alleged'
# Predicción para 'alleged': 'failure'. Debería ser: 'failure'
# Predicción para 'failure': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'stick'
# Predicción para 'stick': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'pact'
# Predicción para 'pact': ','. Debería ser: 'not'
# Predicción para 'not': 'be'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'sell'
# Predicción para 'sell': 'its'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': '.'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'world'
# Predicción para 'world': ''s'. Debería ser: 'markets'
# Predicción para 'markets': '.'. Debería ser: 'at'
# Predicción para 'at': 'the'. Debería ser: 'below'
# Predicción para 'below': 'the'. Debería ser: 'cost'
# Predicción para 'cost': 'of'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'unofficial'
# Predicción para 'unofficial': 'targets'. Debería ser: 'japanese'
# Predicción para 'japanese': 'government'. Debería ser: 'estimates'
# Predicción para 'estimates': 'of'. Debería ser: 'put'
# Predicción para 'put': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'impact'
# Predicción para 'impact': 'on'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: 'at'
# Predicción para 'at': 'the'. Debería ser: '10'
# Predicción para '10': 'pct'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'spokesmen'
# Predicción para 'spokesmen': 'said'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'major'
# Predicción para 'major': 'industrial'. Debería ser: 'electronics'
# Predicción para 'electronics': 'inc'. Debería ser: 'firms'
# Predicción para 'firms': ','. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'they'
# Predicción para 'they': 'said'. Debería ser: 'would'
# Predicción para 'would': 'be'. Debería ser: 'virtually'
# Predicción para 'virtually': 'all'. Debería ser: 'halt'
# Predicción para 'halt': 'the'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'products'
# Predicción para 'products': '.'. Debería ser: 'hit'
# Predicción para 'hit': 'by'. Debería ser: 'by'
# Predicción para 'by': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'new'
# Predicción para 'new': 'york'. Debería ser: 'taxes'
# Predicción para 'taxes': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'we'
# Predicción para 'we': 'are'. Debería ser: 'would'
# Predicción para 'would': 'be'. Debería ser: 'n't'
# Predicción para 'n't': 'think'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'able'
# Predicción para 'able': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'do'
# Predicción para 'do': 'n't'. Debería ser: 'business'
# Predicción para 'business': '.'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'spokesman'
# Predicción para 'spokesman': 'said'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'leading'
# Predicción para 'leading': 'industrial'. Debería ser: 'japanese'
# Predicción para 'japanese': 'government'. Debería ser: 'electronics'
# Predicción para 'electronics': 'inc'. Debería ser: 'firm'
# Predicción para 'firm': ','. Debería ser: 'matsushita'
# Predicción para 'matsushita': 'electric'. Debería ser: 'electric'
# Predicción para 'electric': 'co'. Debería ser: 'industrial'
# Predicción para 'industrial': 'production'. Debería ser: 'co'
# Predicción para 'co': '&'. Debería ser: 'ltd'
# Predicción para 'ltd': '>'. Debería ser: '&'
# Predicción para '&': 'lt'. Debería ser: 'lt'
# Predicción para 'lt': ';'. Debería ser: ';'
# Predicción para ';': 'xon'. Debería ser: 'mc.t'
# Predicción para 'mc.t': '>'. Debería ser: '>'
# Predicción para '>': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'if'
# Predicción para 'if': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: 'remain'
# Predicción para 'remain': 'at'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'place'
# Predicción para 'place': '.'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'any'
# Predicción para 'any': 'of'. Debería ser: 'length'
# Predicción para 'length': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'time'
# Predicción para 'time': ','. Debería ser: 'beyond'
# Predicción para 'beyond': 'the'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'few'
# Predicción para 'few': 'months'. Debería ser: 'months'
# Predicción para 'months': 'of'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'will'
# Predicción para 'will': 'be'. Debería ser: 'mean'
# Predicción para 'mean': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'complete'
# Predicción para 'complete': 'the'. Debería ser: 'erosion'
# Predicción para 'erosion': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: '('
# Predicción para '(': 'ec'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'goods'
# Predicción para 'goods': 'and'. Debería ser: 'subject'
# Predicción para 'subject': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: ')'
# Predicción para ')': ','. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'tom'
# Predicción para 'tom': 'murtha'. Debería ser: 'murtha'
# Predicción para 'murtha': ','. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'stock'
# Predicción para 'stock': 'split'. Debería ser: 'analyst'
# Predicción para 'analyst': 'with'. Debería ser: 'at'
# Predicción para 'at': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'tokyo'
# Predicción para 'tokyo': ','. Debería ser: 'office'
# Predicción para 'office': 'said'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'broker'
# Predicción para 'broker': 'loan'. Debería ser: '&'
# Predicción para '&': 'lt'. Debería ser: 'lt'
# Predicción para 'lt': ';'. Debería ser: ';'
# Predicción para ';': 'xon'. Debería ser: 'james'
# Predicción para 'james': 'baker'. Debería ser: 'capel'
# Predicción para 'capel': 'and'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'co'
# Predicción para 'co': '&'. Debería ser: '>'
# Predicción para '>': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'taiwan'
# Predicción para 'taiwan': ''s'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'said'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'officials'
# Predicción para 'officials': 'said'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'also'
# Predicción para 'also': 'said'. Debería ser: 'worried'
# Predicción para 'worried': 'about'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'we'
# Predicción para 'we': 'are'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'aware'
# Predicción para 'aware': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'seriousness'
# Predicción para 'seriousness': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'threat'
# Predicción para 'threat': 'to'. Debería ser: 'against'
# Predicción para 'against': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'because'
# Predicción para 'because': 'of'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'serves'
# Predicción para 'serves': 'about'. Debería ser: 'as'
# Predicción para 'as': 'a'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'warning'
# Predicción para 'warning': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'us'
# Predicción para 'us': 'to'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'senior'
# Predicción para 'senior': 'management'. Debería ser: 'taiwanese'
# Predicción para 'taiwanese': 'products'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'official'
# Predicción para 'official': 'said'. Debería ser: 'who'
# Predicción para 'who': 'is'. Debería ser: 'asked'
# Predicción para 'asked': 'if'. Debería ser: 'not'
# Predicción para 'not': 'be'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'named'
# Predicción para 'named': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'taiwan'
# Predicción para 'taiwan': ''s'. Debería ser: 'had'
# Predicción para 'had': 'been'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'surplus'
# Predicción para 'surplus': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: '15.6'
# Predicción para '15.6': 'mln'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'last'
# Predicción para 'last': 'year'. Debería ser: 'year'
# Predicción para 'year': '.'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: '95'
# Predicción para '95': 'cts'. Debería ser: 'pct'
# Predicción para 'pct': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'with'
# Predicción para 'with': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'surplus'
# Predicción para 'surplus': 'of'. Debería ser: 'helped'
# Predicción para 'helped': 'by'. Debería ser: 'swell'
# Predicción para 'swell': 'taiwan'. Debería ser: 'taiwan'
# Predicción para 'taiwan': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'foreign'
# Predicción para 'foreign': 'exchange'. Debería ser: 'exchange'
# Predicción para 'exchange': 'commission'. Debería ser: 'reserves'
# Predicción para 'reserves': 'of'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: '53'
# Predicción para '53': 'cts'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'among'
# Predicción para 'among': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'world'
# Predicción para 'world': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'largest'
# Predicción para 'largest': 'u.s.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'we'
# Predicción para 'we': 'are'. Debería ser: 'must'
# Predicción para 'must': 'be'. Debería ser: 'quickly'
# Predicción para 'quickly': 'as'. Debería ser: 'open'
# Predicción para 'open': 'market'. Debería ser: 'our'
# Predicción para 'our': 'trade'. Debería ser: 'markets'
# Predicción para 'markets': '.'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'remove'
# Predicción para 'remove': 'all'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'barriers'
# Predicción para 'barriers': 'to'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'cut'
# Predicción para 'cut': 'its'. Debería ser: 'import'
# Predicción para 'import': 'fee'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'allow'
# Predicción para 'allow': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'products'
# Predicción para 'products': '.'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'if'
# Predicción para 'if': 'the'. Debería ser: 'we'
# Predicción para 'we': 'are'. Debería ser: 'want'
# Predicción para 'want': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'defuse'
# Predicción para 'defuse': 'american'. Debería ser: 'problems'
# Predicción para 'problems': '.'. Debería ser: 'from'
# Predicción para 'from': 'the'. Debería ser: 'possible'
# Predicción para 'possible': '.'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'retaliation'
# Predicción para 'retaliation': 'for'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'paul'
# Predicción para 'paul': 'volcker'. Debería ser: 'sheen'
# Predicción para 'sheen': ','. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'chairman'
# Predicción para 'chairman': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'textile'
# Predicción para 'textile': 'industry'. Debería ser: 'exporters'
# Predicción para 'exporters': 'report'. Debería ser: '&'
# Predicción para '&': 'lt'. Debería ser: 'lt'
# Predicción para 'lt': ';'. Debería ser: ';'
# Predicción para ';': 'xon'. Debería ser: 'taiwan'
# Predicción para 'taiwan': ''s'. Debería ser: 'safe'
# Predicción para 'safe': 'drug'. Debería ser: 'group'
# Predicción para 'group': 'of'. Debería ser: '>'
# Predicción para '>': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'senior'
# Predicción para 'senior': 'management'. Debería ser: 'official'
# Predicción para 'official': 'said'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'south'
# Predicción para 'south': 'korea'. Debería ser: 'korea'
# Predicción para 'korea': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'promotion'
# Predicción para 'promotion': 'corp'. Debería ser: 'association'
# Predicción para 'association': 'of'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'dispute'
# Predicción para 'dispute': 'over'. Debería ser: 'between'
# Predicción para 'between': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'might'
# Predicción para 'might': 'be'. Debería ser: 'also'
# Predicción para 'also': 'said'. Debería ser: 'lead'
# Predicción para 'lead': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'pressure'
# Predicción para 'pressure': 'on'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'south'
# Predicción para 'south': 'korea'. Debería ser: 'korea'
# Predicción para 'korea': ''s'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'whose'
# Predicción para 'whose': 'chief'. Debería ser: 'chief'
# Predicción para 'chief': 'executive'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'similar'
# Predicción para 'similar': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'those'
# Predicción para 'those': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'last'
# Predicción para 'last': 'year'. Debería ser: 'year'
# Predicción para 'year': '.'. Debería ser: 'south'
# Predicción para 'south': 'korea'. Debería ser: 'korea'
# Predicción para 'korea': ''s'. Debería ser: 'had'
# Predicción para 'had': 'been'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'surplus'
# Predicción para 'surplus': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: '7.1'
# Predicción para '7.1': 'mln'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'with'
# Predicción para 'with': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'up'
# Predicción para 'up': 'to'. Debería ser: 'from'
# Predicción para 'from': 'the'. Debería ser: '4.9'
# Predicción para '4.9': 'mln'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: '1985.'
# Predicción para '1985.': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'malaysia'
# Predicción para 'malaysia': ''s'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'officers'
# Predicción para 'officers': 'and'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'said'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'tough'
# Predicción para 'tough': 'trade'. Debería ser: 'curbs'
# Predicción para 'curbs': 'on'. Debería ser: 'against'
# Predicción para 'against': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'might'
# Predicción para 'might': 'be'. Debería ser: 'allow'
# Predicción para 'allow': 'the'. Debería ser: 'hard-hit'
# Predicción para 'hard-hit': 'by'. Debería ser: 'producers'
# Predicción para 'producers': 'and'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': '.'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'third'
# Predicción para 'third': 'quarter'. Debería ser: 'countries'
# Predicción para 'countries': '.'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'expand'
# Predicción para 'expand': 'its'. Debería ser: 'their'
# Predicción para 'their': 'own'. Debería ser: 'sales'
# Predicción para 'sales': 'of'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'kong'. Debería ser: 'kong'
# Predicción para 'kong': ','. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'where'
# Predicción para 'where': 'the'. Debería ser: 'newspapers'
# Predicción para 'newspapers': 'in'. Debería ser: 'have'
# Predicción para 'have': 'been'. Debería ser: 'alleged'
# Predicción para 'alleged': 'failure'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'has'
# Predicción para 'has': 'been'. Debería ser: 'been'
# Predicción para 'been': 'a'. Debería ser: 'selling'
# Predicción para 'selling': 'price'. Debería ser: 'below-cost'
# Predicción para 'below-cost': 'semiconductors'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': '.'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'some'
# Predicción para 'some': 'of'. Debería ser: 'electronics'
# Predicción para 'electronics': 'inc'. Debería ser: 'manufacturers'
# Predicción para 'manufacturers': 'hanover'. Debería ser: 'share'
# Predicción para 'share': ','. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'view'
# Predicción para 'view': 'of'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'but'
# Predicción para 'but': 'the'. Debería ser: 'other'
# Predicción para 'other': 'countries'. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'said'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'such'
# Predicción para 'such': 'as'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'short-term'
# Predicción para 'short-term': 'discount'. Debería ser: 'commercial'
# Predicción para 'commercial': 'banks'. Debería ser: 'advantage'
# Predicción para 'advantage': 'of'. Debería ser: 'would'
# Predicción para 'would': 'be'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'outweighed'
# Predicción para 'outweighed': 'by'. Debería ser: 'by'
# Predicción para 'by': 'the'. Debería ser: 'further'
# Predicción para 'further': 'details'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'pressure'
# Predicción para 'pressure': 'on'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'block'
# Predicción para 'block': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'very'
# Predicción para 'very': 'good'. Debería ser: 'short-term'
# Predicción para 'short-term': 'discount'. Debería ser: 'view'
# Predicción para 'view': 'of'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'lawrence'
# Predicción para 'lawrence': 'seaway'. Debería ser: 'mills'
# Predicción para 'mills': '.'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'director-general'
# Predicción para 'director-general': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'federation'
# Predicción para 'federation': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'kong'. Debería ser: 'kong'
# Predicción para 'kong': ','. Debería ser: 'industry'
# Predicción para 'industry': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'if'
# Predicción para 'if': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'whole'
# Predicción para 'whole': 'of'. Debería ser: 'purpose'
# Predicción para 'purpose': 'of'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'prevent'
# Predicción para 'prevent': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'one'
# Predicción para 'one': 'of'. Debería ser: 'day'
# Predicción para 'day': ','. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'will'
# Predicción para 'will': 'be'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'extended'
# Predicción para 'extended': '.'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'other'
# Predicción para 'other': 'countries'. Debería ser: 'sources'
# Predicción para 'sources': 'said'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'much'
# Predicción para 'much': 'as'. Debería ser: 'more'
# Predicción para 'more': 'than'. Debería ser: 'serious'
# Predicción para 'serious': 'about'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'kong'. Debería ser: 'kong'
# Predicción para 'kong': ','. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'disadvantage'
# Predicción para 'disadvantage': '.'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'action'
# Predicción para 'action': '.'. Debería ser: 'restraining'
# Predicción para 'restraining': 'order'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'he'
# Predicción para 'he': 'said'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'last'
# Predicción para 'last': 'year'. Debería ser: 'year'
# Predicción para 'year': '.'. Debería ser: 'was'
# Predicción para 'was': 'not'. Debería ser: 'hong'
# Predicción para 'hong': 'kong'. Debería ser: 'kong'
# Predicción para 'kong': ','. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'biggest'
# Predicción para 'biggest': 'producer'. Debería ser: 'export'
# Predicción para 'export': 'quotas'. Debería ser: 'market'
# Predicción para 'market': ','. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'accounting'
# Predicción para 'accounting': 'for'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'over'
# Predicción para 'over': 'the'. Debería ser: '30'
# Predicción para '30': ','. Debería ser: 'pct'
# Predicción para 'pct': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'domestically'
# Predicción para 'domestically': 'produced'. Debería ser: 'produced'
# Predicción para 'produced': 'in'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'australian'
# Predicción para 'australian': 'dollar'. Debería ser: 'government'
# Predicción para 'government': ''s'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'awaiting'
# Predicción para 'awaiting': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'outcome'
# Predicción para 'outcome': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'talks'
# Predicción para 'talks': 'with'. Debería ser: 'between'
# Predicción para 'between': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'with'
# Predicción para 'with': 'the'. Debería ser: 'interest'
# Predicción para 'interest': 'rates'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'concern'
# Predicción para 'concern': 'about'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'industry'
# Predicción para 'industry': ','. Debería ser: 'minister'
# Predicción para 'minister': 'kiichi'. Debería ser: 'john'
# Predicción para 'john': 'herrington'. Debería ser: 'button'
# Predicción para 'button': 'said'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'canberra'
# Predicción para 'canberra': 'last'. Debería ser: 'last'
# Predicción para 'last': 'year'. Debería ser: 'friday'
# Predicción para 'friday': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'this'
# Predicción para 'this': 'year'. Debería ser: 'kind'
# Predicción para 'kind': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'deterioration'
# Predicción para 'deterioration': 'in'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'relations'
# Predicción para 'relations': 'with'. Debería ser: 'between'
# Predicción para 'between': 'the'. Debería ser: 'two'
# Predicción para 'two': 'cts'. Debería ser: 'countries'
# Predicción para 'countries': '.'. Debería ser: 'which'
# Predicción para 'which': 'is'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'major'
# Predicción para 'major': 'industrial'. Debería ser: 'trading'
# Predicción para 'trading': 'at'. Debería ser: 'partners'
# Predicción para 'partners': ','. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'ours'
# Predicción para 'ours': 'is'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'very'
# Predicción para 'very': 'good'. Debería ser: 'serious'
# Predicción para 'serious': 'about'. Debería ser: 'matter'
# Predicción para 'matter': 'of'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'button'
# Predicción para 'button': 'said'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'he'
# Predicción para 'he': 'said'. Debería ser: 'said'
# Predicción para 'said': '.'. Debería ser: 'australia'
# Predicción para 'australia': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'concerns'
# Predicción para 'concerns': 'about'. Debería ser: 'centred'
# Predicción para 'centred': 'on'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'coal'
# Predicción para 'coal': 'and'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'beef'
# Predicción para 'beef': 'and'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'australia'
# Predicción para 'australia': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'two'
# Predicción para 'two': 'cts'. Debería ser: 'largest'
# Predicción para 'largest': 'u.s.'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'also'
# Predicción para 'also': 'said'. Debería ser: 'significant'
# Predicción para 'significant': 'impact'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'country'
# Predicción para 'country': ''s'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'meanwhile'
# Predicción para 'meanwhile': ','. Debería ser: 'u.s.-japanese'
# Predicción para 'u.s.-japanese': 'semiconductor'. Debería ser: 'diplomatic'
# Predicción para 'diplomatic': 'sources'. Debería ser: 'manoeuvres'
# Predicción para 'manoeuvres': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'solve'
# Predicción para 'solve': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'stand-off'
# Predicción para 'stand-off': 'continue'. Debería ser: 'continue'
# Predicción para 'continue': 'to'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'ruling'
# Predicción para 'ruling': 'liberal'. Debería ser: 'liberal'
# Predicción para 'liberal': 'democratic'. Debería ser: 'democratic'
# Predicción para 'democratic': 'party'. Debería ser: 'party'
# Predicción para 'party': ','. Debería ser: 'yesterday'
# Predicción para 'yesterday': ','. Debería ser: 'outlined'
# Predicción para 'outlined': 'in'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'package'
# Predicción para 'package': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'economic'
# Predicción para 'economic': 'growth'. Debería ser: 'measures'
# Predicción para 'measures': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'boost'
# Predicción para 'boost': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'japanese'
# Predicción para 'japanese': 'government'. Debería ser: 'economy'
# Predicción para 'economy': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'measures'
# Predicción para 'measures': 'to'. Debería ser: 'proposed'
# Predicción para 'proposed': 'merger'. Debería ser: 'include'
# Predicción para 'include': 'a'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'large'
# Predicción para 'large': 'trade'. Debería ser: 'supplementary'
# Predicción para 'supplementary': 'budget'. Debería ser: 'budget'
# Predicción para 'budget': 'deficit'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'record'
# Predicción para 'record': 'april'. Debería ser: 'public'
# Predicción para 'public': 'sector'. Debería ser: 'works'
# Predicción para 'works': '&'. Debería ser: 'spending'
# Predicción para 'spending': ','. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'first'
# Predicción para 'first': 'quarter'. Debería ser: 'half'
# Predicción para 'half': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'financial'
# Predicción para 'financial': 'corp'. Debería ser: 'year'
# Predicción para 'year': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'they'
# Predicción para 'they': 'said'. Debería ser: 'also'
# Predicción para 'also': 'said'. Debería ser: 'call'
# Predicción para 'call': 'money'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'stepped-up'
# Predicción para 'stepped-up': 'spending'. Debería ser: 'spending'
# Predicción para 'spending': ','. Debería ser: 'as'
# Predicción para 'as': 'a'. Debería ser: 'an'
# Predicción para 'an': 'agreement'. Debería ser: 'emergency'
# Predicción para 'emergency': 'opec'. Debería ser: 'measure'
# Predicción para 'measure': 'of'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'stimulate'
# Predicción para 'stimulate': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'economy'
# Predicción para 'economy': ','. Debería ser: 'despite'
# Predicción para 'despite': 'the'. Debería ser: 'prime'
# Predicción para 'prime': 'rate'. Debería ser: 'minister'
# Predicción para 'minister': 'kiichi'. Debería ser: 'yasuhiro'
# Predicción para 'yasuhiro': 'nakasone'. Debería ser: 'nakasone'
# Predicción para 'nakasone': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'avowed'
# Predicción para 'avowed': 'fiscal'. Debería ser: 'fiscal'
# Predicción para 'fiscal': 'year'. Debería ser: 'reform'
# Predicción para 'reform': 'act'. Debería ser: 'program'
# Predicción para 'program': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'deputy'
# Predicción para 'deputy': 'energy'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'representative'
# Predicción para 'representative': 'clayton'. Debería ser: 'michael'
# Predicción para 'michael': 'wilson'. Debería ser: 'smith'
# Predicción para 'smith': 'barney'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'makoto'
# Predicción para 'makoto': 'kuroda'. Debería ser: 'kuroda'
# Predicción para 'kuroda': 'said'. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: ''s'
# Predicción para ''s': '&'. Debería ser: 'deputy'
# Predicción para 'deputy': 'energy'. Debería ser: 'minister'
# Predicción para 'minister': 'kiichi'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'international'
# Predicción para 'international': 'inc'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'industry'
# Predicción para 'industry': ','. Debería ser: '('
# Predicción para '(': 'ec'. Debería ser: 'miti'
# Predicción para 'miti': ')'. Debería ser: ')'
# Predicción para ')': ','. Debería ser: ','
# Predicción para ',': 'the'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'due'
# Predicción para 'due': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'meet'
# Predicción para 'meet': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'washington'
# Predicción para 'washington': ','. Debería ser: 'this'
# Predicción para 'this': 'year'. Debería ser: 'week'
# Predicción para 'week': ','. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'an'
# Predicción para 'an': 'agreement'. Debería ser: 'effort'
# Predicción para 'effort': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'end'
# Predicción para 'end': 'of'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'dispute'
#
# Aciertos: 168/809 = 20.77%

# %%
print("2-grama sin signos de puntuación:\n")
evaluar(text, bigram_model_without_punctuation, 2)
# Out:
# 2-grama sin signos de puntuación:
#
# Predicción para 'asian': 'nations'. Debería ser: 'exporters'
# Predicción para 'exporters': 'report'. Debería ser: 'fear'
# Predicción para 'fear': 'of'. Debería ser: 'damage'
# Predicción para 'damage': 'to'. Debería ser: 'from'
# Predicción para 'from': 'the'. Debería ser: 'u.s.-japan'
# Predicción para 'u.s.-japan': 'trade'. Debería ser: 'rift'
# Predicción para 'rift': 'mounting'. Debería ser: 'mounting'
# Predicción para 'mounting': 'trade'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'friction'
# Predicción para 'friction': 'materials'. Debería ser: 'between'
# Predicción para 'between': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'has'
# Predicción para 'has': 'been'. Debería ser: 'raised'
# Predicción para 'raised': 'its'. Debería ser: 'fears'
# Predicción para 'fears': 'of'. Debería ser: 'among'
# Predicción para 'among': 'the'. Debería ser: 'many'
# Predicción para 'many': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'asia'
# Predicción para 'asia': 'and'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'exporting'
# Predicción para 'exporting': 'countries'. Debería ser: 'nations'
# Predicción para 'nations': 'to'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'row'
# Predicción para 'row': 'publishers'. Debería ser: 'could'
# Predicción para 'could': 'be'. Debería ser: 'inflict'
# Predicción para 'inflict': 'far-reaching'. Debería ser: 'far-reaching'
# Predicción para 'far-reaching': 'economic'. Debería ser: 'economic'
# Predicción para 'economic': 'growth'. Debería ser: 'damage'
# Predicción para 'damage': 'to'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'said'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'officials'
# Predicción para 'officials': 'said'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'they': 'said'. Debería ser: 'told'
# Predicción para 'told': 'reuters'. Debería ser: 'reuter'
# Predicción para 'reuter': '...'. Debería ser: 'correspondents'
# Predicción para 'correspondents': 'in'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'asian'
# Predicción para 'asian': 'nations'. Debería ser: 'capitals'
# Predicción para 'capitals': 'a'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'move'
# Predicción para 'move': 'to'. Debería ser: 'against'
# Predicción para 'against': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'might'
# Predicción para 'might': 'be'. Debería ser: 'boost'
# Predicción para 'boost': 'the'. Debería ser: 'protectionist'
# Predicción para 'protectionist': 'sentiment'. Debería ser: 'sentiment'
# Predicción para 'sentiment': 'in'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'lead'
# Predicción para 'lead': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'curbs'
# Predicción para 'curbs': 'on'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'american'
# Predicción para 'american': 'express'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'their'
# Predicción para 'their': 'own'. Debería ser: 'products'
# Predicción para 'products': 'and'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'but'
# Predicción para 'but': 'the'. Debería ser: 'some'
# Predicción para 'some': 'of'. Debería ser: 'exporters'
# Predicción para 'exporters': 'report'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'while'
# Predicción para 'while': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'conflict'
# Predicción para 'conflict': 'with'. Debería ser: 'would'
# Predicción para 'would': 'be'. Debería ser: 'hurt'
# Predicción para 'hurt': 'by'. Debería ser: 'them'
# Predicción para 'them': 'to'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'long-run'
# Predicción para 'long-run': 'in'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'short-term'
# Predicción para 'short-term': 'discount'. Debería ser: 'tokyo'
# Predicción para 'tokyo': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'loss'
# Predicción para 'loss': 'of'. Debería ser: 'might'
# Predicción para 'might': 'be'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'their'
# Predicción para 'their': 'own'. Debería ser: 'gain'
# Predicción para 'gain': 'of'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'has'
# Predicción para 'has': 'been'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'will'
# Predicción para 'will': 'be'. Debería ser: 'impose'
# Predicción para 'impose': 'tariffs'. Debería ser: '300'
# Predicción para '300': 'mln'. Debería ser: 'mln'
# Predicción para 'mln': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'japanese'
# Predicción para 'japanese': 'government'. Debería ser: 'electronics'
# Predicción para 'electronics': 'inc'. Debería ser: 'goods'
# Predicción para 'goods': 'and'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'april'
# Predicción para 'april': '30'. Debería ser: '17'
# Predicción para '17': 'cts'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'retaliation'
# Predicción para 'retaliation': 'for'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'alleged'
# Predicción para 'alleged': 'failure'. Debería ser: 'failure'
# Predicción para 'failure': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'stick'
# Predicción para 'stick': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'pact'
# Predicción para 'pact': 'to'. Debería ser: 'not'
# Predicción para 'not': 'be'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'sell'
# Predicción para 'sell': 'its'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'in'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'world'
# Predicción para 'world': ''s'. Debería ser: 'markets'
# Predicción para 'markets': 'and'. Debería ser: 'at'
# Predicción para 'at': 'the'. Debería ser: 'below'
# Predicción para 'below': 'the'. Debería ser: 'cost'
# Predicción para 'cost': 'of'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'unofficial'
# Predicción para 'unofficial': 'targets'. Debería ser: 'japanese'
# Predicción para 'japanese': 'government'. Debería ser: 'estimates'
# Predicción para 'estimates': 'of'. Debería ser: 'put'
# Predicción para 'put': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'impact'
# Predicción para 'impact': 'on'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: 'at'
# Predicción para 'at': 'the'. Debería ser: '10'
# Predicción para '10': 'pct'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'spokesmen'
# Predicción para 'spokesmen': 'said'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'major'
# Predicción para 'major': 'industrial'. Debería ser: 'electronics'
# Predicción para 'electronics': 'inc'. Debería ser: 'firms'
# Predicción para 'firms': 'to'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'they'
# Predicción para 'they': 'said'. Debería ser: 'would'
# Predicción para 'would': 'be'. Debería ser: 'virtually'
# Predicción para 'virtually': 'all'. Debería ser: 'halt'
# Predicción para 'halt': 'the'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'products'
# Predicción para 'products': 'and'. Debería ser: 'hit'
# Predicción para 'hit': 'by'. Debería ser: 'by'
# Predicción para 'by': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'new'
# Predicción para 'new': 'york'. Debería ser: 'taxes'
# Predicción para 'taxes': 'and'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'we'
# Predicción para 'we': 'are'. Debería ser: 'would'
# Predicción para 'would': 'be'. Debería ser: 'n't'
# Predicción para 'n't': 'think'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'able'
# Predicción para 'able': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'do'
# Predicción para 'do': 'n't'. Debería ser: 'business'
# Predicción para 'business': 'and'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'spokesman'
# Predicción para 'spokesman': 'said'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'leading'
# Predicción para 'leading': 'industrial'. Debería ser: 'japanese'
# Predicción para 'japanese': 'government'. Debería ser: 'electronics'
# Predicción para 'electronics': 'inc'. Debería ser: 'firm'
# Predicción para 'firm': 'said'. Debería ser: 'matsushita'
# Predicción para 'matsushita': 'electric'. Debería ser: 'electric'
# Predicción para 'electric': 'co'. Debería ser: 'industrial'
# Predicción para 'industrial': 'production'. Debería ser: 'co'
# Predicción para 'co': 'lt'. Debería ser: 'ltd'
# Predicción para 'ltd': 'lt'. Debería ser: '&'
# Predicción para '&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'lt': 'xon'. Debería ser: ';'
# Predicción para ';': SIN PREDICCIÓN. Debería ser: 'mc.t'
# Predicción para 'mc.t': '``'. Debería ser: '>'
# Predicción para '>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'if'
# Predicción para 'if': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: 'remain'
# Predicción para 'remain': 'at'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'place'
# Predicción para 'place': 'in'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'any'
# Predicción para 'any': 'of'. Debería ser: 'length'
# Predicción para 'length': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'time'
# Predicción para 'time': 'of'. Debería ser: 'beyond'
# Predicción para 'beyond': 'the'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'few'
# Predicción para 'few': 'months'. Debería ser: 'months'
# Predicción para 'months': 'of'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'will'
# Predicción para 'will': 'be'. Debería ser: 'mean'
# Predicción para 'mean': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'complete'
# Predicción para 'complete': 'the'. Debería ser: 'erosion'
# Predicción para 'erosion': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: '('
# Predicción para '(': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'goods'
# Predicción para 'goods': 'and'. Debería ser: 'subject'
# Predicción para 'subject': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: ')'
# Predicción para ')': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'tom'
# Predicción para 'tom': 'murtha'. Debería ser: 'murtha'
# Predicción para 'murtha': 'said'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'stock'
# Predicción para 'stock': 'split'. Debería ser: 'analyst'
# Predicción para 'analyst': 'with'. Debería ser: 'at'
# Predicción para 'at': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'tokyo'
# Predicción para 'tokyo': ''s'. Debería ser: 'office'
# Predicción para 'office': 'said'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'broker'
# Predicción para 'broker': 'loan'. Debería ser: '&'
# Predicción para '&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'lt': 'xon'. Debería ser: ';'
# Predicción para ';': SIN PREDICCIÓN. Debería ser: 'james'
# Predicción para 'james': 'baker'. Debería ser: 'capel'
# Predicción para 'capel': 'and'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'co'
# Predicción para 'co': 'lt'. Debería ser: '>'
# Predicción para '>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'taiwan'
# Predicción para 'taiwan': ''s'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'said'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'officials'
# Predicción para 'officials': 'said'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'also'
# Predicción para 'also': 'said'. Debería ser: 'worried'
# Predicción para 'worried': 'about'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'we'
# Predicción para 'we': 'are'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'aware'
# Predicción para 'aware': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'seriousness'
# Predicción para 'seriousness': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'threat'
# Predicción para 'threat': 'to'. Debería ser: 'against'
# Predicción para 'against': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'because'
# Predicción para 'because': 'of'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'serves'
# Predicción para 'serves': 'about'. Debería ser: 'as'
# Predicción para 'as': 'a'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'warning'
# Predicción para 'warning': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'us'
# Predicción para 'us': 'to'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'senior'
# Predicción para 'senior': 'management'. Debería ser: 'taiwanese'
# Predicción para 'taiwanese': 'products'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'official'
# Predicción para 'official': 'said'. Debería ser: 'who'
# Predicción para 'who': 'is'. Debería ser: 'asked'
# Predicción para 'asked': 'if'. Debería ser: 'not'
# Predicción para 'not': 'be'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'named'
# Predicción para 'named': 'said'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'taiwan': ''s'. Debería ser: 'had'
# Predicción para 'had': 'been'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'surplus'
# Predicción para 'surplus': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: '15.6'
# Predicción para '15.6': 'mln'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'last'
# Predicción para 'last': 'year'. Debería ser: 'year'
# Predicción para 'year': 'shr'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: '95'
# Predicción para '95': 'cts'. Debería ser: 'pct'
# Predicción para 'pct': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'with'
# Predicción para 'with': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'surplus'
# Predicción para 'surplus': 'of'. Debería ser: 'helped'
# Predicción para 'helped': 'by'. Debería ser: 'swell'
# Predicción para 'swell': 'taiwan'. Debería ser: 'taiwan'
# Predicción para 'taiwan': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'foreign'
# Predicción para 'foreign': 'exchange'. Debería ser: 'exchange'
# Predicción para 'exchange': 'commission'. Debería ser: 'reserves'
# Predicción para 'reserves': 'of'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: '53'
# Predicción para '53': 'cts'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'among'
# Predicción para 'among': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'world'
# Predicción para 'world': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'largest'
# Predicción para 'largest': 'u.s.'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'we'
# Predicción para 'we': 'are'. Debería ser: 'must'
# Predicción para 'must': 'be'. Debería ser: 'quickly'
# Predicción para 'quickly': 'as'. Debería ser: 'open'
# Predicción para 'open': 'market'. Debería ser: 'our'
# Predicción para 'our': 'trade'. Debería ser: 'markets'
# Predicción para 'markets': 'and'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'remove'
# Predicción para 'remove': 'all'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'barriers'
# Predicción para 'barriers': 'to'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'cut'
# Predicción para 'cut': 'its'. Debería ser: 'import'
# Predicción para 'import': 'fee'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'and'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'allow'
# Predicción para 'allow': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'products'
# Predicción para 'products': 'and'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'if'
# Predicción para 'if': 'the'. Debería ser: 'we'
# Predicción para 'we': 'are'. Debería ser: 'want'
# Predicción para 'want': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'defuse'
# Predicción para 'defuse': 'american'. Debería ser: 'problems'
# Predicción para 'problems': 'in'. Debería ser: 'from'
# Predicción para 'from': 'the'. Debería ser: 'possible'
# Predicción para 'possible': 'sale'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'retaliation'
# Predicción para 'retaliation': 'for'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'paul'
# Predicción para 'paul': 'volcker'. Debería ser: 'sheen'
# Predicción para 'sheen': 'chairman'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'chairman'
# Predicción para 'chairman': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'textile'
# Predicción para 'textile': 'industry'. Debería ser: 'exporters'
# Predicción para 'exporters': 'report'. Debería ser: '&'
# Predicción para '&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'lt': 'xon'. Debería ser: ';'
# Predicción para ';': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'taiwan': ''s'. Debería ser: 'safe'
# Predicción para 'safe': 'drug'. Debería ser: 'group'
# Predicción para 'group': 'of'. Debería ser: '>'
# Predicción para '>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'senior'
# Predicción para 'senior': 'management'. Debería ser: 'official'
# Predicción para 'official': 'said'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'south'
# Predicción para 'south': 'korea'. Debería ser: 'korea'
# Predicción para 'korea': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'promotion'
# Predicción para 'promotion': 'corp'. Debería ser: 'association'
# Predicción para 'association': 'of'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'dispute'
# Predicción para 'dispute': 'over'. Debería ser: 'between'
# Predicción para 'between': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'might'
# Predicción para 'might': 'be'. Debería ser: 'also'
# Predicción para 'also': 'said'. Debería ser: 'lead'
# Predicción para 'lead': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'pressure'
# Predicción para 'pressure': 'on'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'south'
# Predicción para 'south': 'korea'. Debería ser: 'korea'
# Predicción para 'korea': ''s'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'whose'
# Predicción para 'whose': 'chief'. Debería ser: 'chief'
# Predicción para 'chief': 'executive'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'similar'
# Predicción para 'similar': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'those'
# Predicción para 'those': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'last': 'year'. Debería ser: 'year'
# Predicción para 'year': 'shr'. Debería ser: 'south'
# Predicción para 'south': 'korea'. Debería ser: 'korea'
# Predicción para 'korea': ''s'. Debería ser: 'had'
# Predicción para 'had': 'been'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'surplus'
# Predicción para 'surplus': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: '7.1'
# Predicción para '7.1': 'mln'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'with'
# Predicción para 'with': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'up'
# Predicción para 'up': 'to'. Debería ser: 'from'
# Predicción para 'from': 'the'. Debería ser: '4.9'
# Predicción para '4.9': 'mln'. Debería ser: 'billion'
# Predicción para 'billion': 'dlrs'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'in'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: '1985.'
# Predicción para '1985.': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'malaysia'
# Predicción para 'malaysia': ''s'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'officers'
# Predicción para 'officers': 'and'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'said'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'tough'
# Predicción para 'tough': 'trade'. Debería ser: 'curbs'
# Predicción para 'curbs': 'on'. Debería ser: 'against'
# Predicción para 'against': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'might'
# Predicción para 'might': 'be'. Debería ser: 'allow'
# Predicción para 'allow': 'the'. Debería ser: 'hard-hit'
# Predicción para 'hard-hit': 'by'. Debería ser: 'producers'
# Predicción para 'producers': 'and'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'in'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'third'
# Predicción para 'third': 'quarter'. Debería ser: 'countries'
# Predicción para 'countries': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'expand'
# Predicción para 'expand': 'its'. Debería ser: 'their'
# Predicción para 'their': 'own'. Debería ser: 'sales'
# Predicción para 'sales': 'of'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'kong'. Debería ser: 'kong'
# Predicción para 'kong': ''s'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'where'
# Predicción para 'where': 'the'. Debería ser: 'newspapers'
# Predicción para 'newspapers': 'in'. Debería ser: 'have'
# Predicción para 'have': 'been'. Debería ser: 'alleged'
# Predicción para 'alleged': 'failure'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'has'
# Predicción para 'has': 'been'. Debería ser: 'been'
# Predicción para 'been': 'a'. Debería ser: 'selling'
# Predicción para 'selling': 'price'. Debería ser: 'below-cost'
# Predicción para 'below-cost': 'semiconductors'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'in'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'some'
# Predicción para 'some': 'of'. Debería ser: 'electronics'
# Predicción para 'electronics': 'inc'. Debería ser: 'manufacturers'
# Predicción para 'manufacturers': 'hanover'. Debería ser: 'share'
# Predicción para 'share': 'in'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'view'
# Predicción para 'view': 'of'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'but'
# Predicción para 'but': 'the'. Debería ser: 'other'
# Predicción para 'other': 'countries'. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'said'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'such'
# Predicción para 'such': 'as'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'short-term'
# Predicción para 'short-term': 'discount'. Debería ser: 'commercial'
# Predicción para 'commercial': 'banks'. Debería ser: 'advantage'
# Predicción para 'advantage': 'of'. Debería ser: 'would'
# Predicción para 'would': 'be'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'outweighed'
# Predicción para 'outweighed': 'by'. Debería ser: 'by'
# Predicción para 'by': 'the'. Debería ser: 'further'
# Predicción para 'further': 'details'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'pressure'
# Predicción para 'pressure': 'on'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'block'
# Predicción para 'block': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'very'
# Predicción para 'very': 'good'. Debería ser: 'short-term'
# Predicción para 'short-term': 'discount'. Debería ser: 'view'
# Predicción para 'view': 'of'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'lawrence'
# Predicción para 'lawrence': 'seaway'. Debería ser: 'mills'
# Predicción para 'mills': 'ltd'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'director-general'
# Predicción para 'director-general': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'federation'
# Predicción para 'federation': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'kong'. Debería ser: 'kong'
# Predicción para 'kong': ''s'. Debería ser: 'industry'
# Predicción para 'industry': 'sources'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'if'
# Predicción para 'if': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'whole'
# Predicción para 'whole': 'of'. Debería ser: 'purpose'
# Predicción para 'purpose': 'of'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'prevent'
# Predicción para 'prevent': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'of'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'one'
# Predicción para 'one': 'of'. Debería ser: 'day'
# Predicción para 'day': 'bpd'. Debería ser: 'it'
# Predicción para 'it': 'said'. Debería ser: 'will'
# Predicción para 'will': 'be'. Debería ser: 'be'
# Predicción para 'be': 'a'. Debería ser: 'extended'
# Predicción para 'extended': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'other'
# Predicción para 'other': 'countries'. Debería ser: 'sources'
# Predicción para 'sources': 'said'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'much'
# Predicción para 'much': 'as'. Debería ser: 'more'
# Predicción para 'more': 'than'. Debería ser: 'serious'
# Predicción para 'serious': 'about'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'kong'. Debería ser: 'kong'
# Predicción para 'kong': ''s'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'disadvantage'
# Predicción para 'disadvantage': ''''. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'action'
# Predicción para 'action': 'to'. Debería ser: 'restraining'
# Predicción para 'restraining': 'order'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'he'
# Predicción para 'he': 'said'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'last'
# Predicción para 'last': 'year'. Debería ser: 'year'
# Predicción para 'year': 'shr'. Debería ser: 'was'
# Predicción para 'was': 'not'. Debería ser: 'hong'
# Predicción para 'hong': 'kong'. Debería ser: 'kong'
# Predicción para 'kong': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'biggest'
# Predicción para 'biggest': 'producer'. Debería ser: 'export'
# Predicción para 'export': 'quotas'. Debería ser: 'market'
# Predicción para 'market': 'to'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'accounting'
# Predicción para 'accounting': 'for'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'over'
# Predicción para 'over': 'the'. Debería ser: '30'
# Predicción para '30': 'pct'. Debería ser: 'pct'
# Predicción para 'pct': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'domestically'
# Predicción para 'domestically': 'produced'. Debería ser: 'produced'
# Predicción para 'produced': 'in'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'australian'
# Predicción para 'australian': 'dollar'. Debería ser: 'government'
# Predicción para 'government': ''s'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'awaiting'
# Predicción para 'awaiting': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'outcome'
# Predicción para 'outcome': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'talks'
# Predicción para 'talks': 'with'. Debería ser: 'between'
# Predicción para 'between': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'with'
# Predicción para 'with': 'the'. Debería ser: 'interest'
# Predicción para 'interest': 'rates'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'concern'
# Predicción para 'concern': 'about'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'industry'
# Predicción para 'industry': 'sources'. Debería ser: 'minister'
# Predicción para 'minister': 'kiichi'. Debería ser: 'john'
# Predicción para 'john': 'herrington'. Debería ser: 'button'
# Predicción para 'button': 'said'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'canberra'
# Predicción para 'canberra': 'last'. Debería ser: 'last'
# Predicción para 'last': 'year'. Debería ser: 'friday'
# Predicción para 'friday': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': 'the'. Debería ser: 'this'
# Predicción para 'this': 'year'. Debería ser: 'kind'
# Predicción para 'kind': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'deterioration'
# Predicción para 'deterioration': 'in'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'relations'
# Predicción para 'relations': 'with'. Debería ser: 'between'
# Predicción para 'between': 'the'. Debería ser: 'two'
# Predicción para 'two': 'cts'. Debería ser: 'countries'
# Predicción para 'countries': 'to'. Debería ser: 'which'
# Predicción para 'which': 'is'. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'major'
# Predicción para 'major': 'industrial'. Debería ser: 'trading'
# Predicción para 'trading': 'at'. Debería ser: 'partners'
# Predicción para 'partners': 'said'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'ours'
# Predicción para 'ours': 'is'. Debería ser: 'is'
# Predicción para 'is': 'expected'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'very'
# Predicción para 'very': 'good'. Debería ser: 'serious'
# Predicción para 'serious': 'about'. Debería ser: 'matter'
# Predicción para 'matter': 'of'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'he'. Debería ser: 'button'
# Predicción para 'button': 'said'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'he'
# Predicción para 'he': 'said'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'australia'
# Predicción para 'australia': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'concerns'
# Predicción para 'concerns': 'about'. Debería ser: 'centred'
# Predicción para 'centred': 'on'. Debería ser: 'on'
# Predicción para 'on': 'the'. Debería ser: 'coal'
# Predicción para 'coal': 'and'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'beef'
# Predicción para 'beef': 'and'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'australia'
# Predicción para 'australia': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'two'
# Predicción para 'two': 'cts'. Debería ser: 'largest'
# Predicción para 'largest': 'u.s.'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'also'
# Predicción para 'also': 'said'. Debería ser: 'significant'
# Predicción para 'significant': 'impact'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'country'
# Predicción para 'country': ''s'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'meanwhile'
# Predicción para 'meanwhile': 'the'. Debería ser: 'u.s.-japanese'
# Predicción para 'u.s.-japanese': 'semiconductor'. Debería ser: 'diplomatic'
# Predicción para 'diplomatic': 'sources'. Debería ser: 'manoeuvres'
# Predicción para 'manoeuvres': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'solve'
# Predicción para 'solve': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'stand-off'
# Predicción para 'stand-off': 'continue'. Debería ser: 'continue'
# Predicción para 'continue': 'to'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'ruling'
# Predicción para 'ruling': 'liberal'. Debería ser: 'liberal'
# Predicción para 'liberal': 'democratic'. Debería ser: 'democratic'
# Predicción para 'democratic': 'party'. Debería ser: 'party'
# Predicción para 'party': 'ldp'. Debería ser: 'yesterday'
# Predicción para 'yesterday': ''s'. Debería ser: 'outlined'
# Predicción para 'outlined': 'in'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'package'
# Predicción para 'package': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'economic'
# Predicción para 'economic': 'growth'. Debería ser: 'measures'
# Predicción para 'measures': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'boost'
# Predicción para 'boost': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'japanese'
# Predicción para 'japanese': 'government'. Debería ser: 'economy'
# Predicción para 'economy': 'and'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'measures'
# Predicción para 'measures': 'to'. Debería ser: 'proposed'
# Predicción para 'proposed': 'merger'. Debería ser: 'include'
# Predicción para 'include': 'a'. Debería ser: 'a'
# Predicción para 'a': 'share'. Debería ser: 'large'
# Predicción para 'large': 'trade'. Debería ser: 'supplementary'
# Predicción para 'supplementary': 'budget'. Debería ser: 'budget'
# Predicción para 'budget': 'deficit'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'record'
# Predicción para 'record': 'april'. Debería ser: 'public'
# Predicción para 'public': 'sector'. Debería ser: 'works'
# Predicción para 'works': 'lt'. Debería ser: 'spending'
# Predicción para 'spending': 'and'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'first'
# Predicción para 'first': 'quarter'. Debería ser: 'half'
# Predicción para 'half': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'financial'
# Predicción para 'financial': 'corp'. Debería ser: 'year'
# Predicción para 'year': 'shr'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'they': 'said'. Debería ser: 'also'
# Predicción para 'also': 'said'. Debería ser: 'call'
# Predicción para 'call': 'money'. Debería ser: 'for'
# Predicción para 'for': 'the'. Debería ser: 'stepped-up'
# Predicción para 'stepped-up': 'spending'. Debería ser: 'spending'
# Predicción para 'spending': 'and'. Debería ser: 'as'
# Predicción para 'as': 'a'. Debería ser: 'an'
# Predicción para 'an': 'agreement'. Debería ser: 'emergency'
# Predicción para 'emergency': 'opec'. Debería ser: 'measure'
# Predicción para 'measure': 'of'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'stimulate'
# Predicción para 'stimulate': 'the'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'economy'
# Predicción para 'economy': 'and'. Debería ser: 'despite'
# Predicción para 'despite': 'the'. Debería ser: 'prime'
# Predicción para 'prime': 'rate'. Debería ser: 'minister'
# Predicción para 'minister': 'kiichi'. Debería ser: 'yasuhiro'
# Predicción para 'yasuhiro': 'nakasone'. Debería ser: 'nakasone'
# Predicción para 'nakasone': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'avowed'
# Predicción para 'avowed': 'fiscal'. Debería ser: 'fiscal'
# Predicción para 'fiscal': 'year'. Debería ser: 'reform'
# Predicción para 'reform': 'act'. Debería ser: 'program'
# Predicción para 'program': 'to'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'deputy'
# Predicción para 'deputy': 'energy'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'agriculture'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'representative'
# Predicción para 'representative': 'clayton'. Debería ser: 'michael'
# Predicción para 'michael': 'wilson'. Debería ser: 'smith'
# Predicción para 'smith': 'barney'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'makoto'
# Predicción para 'makoto': 'kuroda'. Debería ser: 'kuroda'
# Predicción para 'kuroda': 'said'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'japan': ''s'. Debería ser: ''s'
# Predicción para ''s': 'lt'. Debería ser: 'deputy'
# Predicción para 'deputy': 'energy'. Debería ser: 'minister'
# Predicción para 'minister': 'kiichi'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'international'
# Predicción para 'international': 'inc'. Debería ser: 'trade'
# Predicción para 'trade': 'deficit'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'industry'
# Predicción para 'industry': 'sources'. Debería ser: '('
# Predicción para '(': SIN PREDICCIÓN. Debería ser: 'miti'
# Predicción para 'miti': ''s'. Debería ser: ')'
# Predicción para ')': SIN PREDICCIÓN. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para 'are': 'not'. Debería ser: 'due'
# Predicción para 'due': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'meet'
# Predicción para 'meet': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'washington'
# Predicción para 'washington': 'to'. Debería ser: 'this'
# Predicción para 'this': 'year'. Debería ser: 'week'
# Predicción para 'week': ''s'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'an'
# Predicción para 'an': 'agreement'. Debería ser: 'effort'
# Predicción para 'effort': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'end'
# Predicción para 'end': 'of'. Debería ser: 'the'
# Predicción para 'the': 'company'. Debería ser: 'dispute'
#
# Aciertos: 151/809 = 18.67%

# %%
print("4-grama con signos de puntuación:\n")
evaluar(text, bigram_model_with_punctuation, 4)
# Out:
# 4-grama con signos de puntuación:
#
# Predicción para 'asian'-'exporters'-'fear': SIN PREDICCIÓN. Debería ser: 'damage'
# Predicción para 'exporters'-'fear'-'damage': SIN PREDICCIÓN. Debería ser: 'from'
# Predicción para 'fear'-'damage'-'from': SIN PREDICCIÓN. Debería ser: 'u.s.-japan'
# Predicción para 'damage'-'from'-'u.s.-japan': SIN PREDICCIÓN. Debería ser: 'rift'
# Predicción para 'from'-'u.s.-japan'-'rift': SIN PREDICCIÓN. Debería ser: 'mounting'
# Predicción para 'u.s.-japan'-'rift'-'mounting': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'rift'-'mounting'-'trade': SIN PREDICCIÓN. Debería ser: 'friction'
# Predicción para 'mounting'-'trade'-'friction': SIN PREDICCIÓN. Debería ser: 'between'
# Predicción para 'trade'-'friction'-'between': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'friction'-'between'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'between'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'the'-'u.s.'-'and': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'u.s.'-'and'-'japan': SIN PREDICCIÓN. Debería ser: 'has'
# Predicción para 'and'-'japan'-'has': SIN PREDICCIÓN. Debería ser: 'raised'
# Predicción para 'japan'-'has'-'raised': SIN PREDICCIÓN. Debería ser: 'fears'
# Predicción para 'has'-'raised'-'fears': SIN PREDICCIÓN. Debería ser: 'among'
# Predicción para 'raised'-'fears'-'among': SIN PREDICCIÓN. Debería ser: 'many'
# Predicción para 'fears'-'among'-'many': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'among'-'many'-'of': SIN PREDICCIÓN. Debería ser: 'asia'
# Predicción para 'many'-'of'-'asia': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'of'-'asia'-''s': SIN PREDICCIÓN. Debería ser: 'exporting'
# Predicción para 'asia'-''s'-'exporting': SIN PREDICCIÓN. Debería ser: 'nations'
# Predicción para ''s'-'exporting'-'nations': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para 'exporting'-'nations'-'that': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'nations'-'that'-'the': SIN PREDICCIÓN. Debería ser: 'row'
# Predicción para 'that'-'the'-'row': SIN PREDICCIÓN. Debería ser: 'could'
# Predicción para 'the'-'row'-'could': SIN PREDICCIÓN. Debería ser: 'inflict'
# Predicción para 'row'-'could'-'inflict': SIN PREDICCIÓN. Debería ser: 'far-reaching'
# Predicción para 'could'-'inflict'-'far-reaching': SIN PREDICCIÓN. Debería ser: 'economic'
# Predicción para 'inflict'-'far-reaching'-'economic': SIN PREDICCIÓN. Debería ser: 'damage'
# Predicción para 'far-reaching'-'economic'-'damage': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'economic'-'damage'-',': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'damage'-','-'businessmen': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para ','-'businessmen'-'and': SIN PREDICCIÓN. Debería ser: 'officials'
# Predicción para 'businessmen'-'and'-'officials': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'and'-'officials'-'said': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'officials'-'said'-'.': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'said'-'.'-'they': SIN PREDICCIÓN. Debería ser: 'told'
# Predicción para '.'-'they'-'told': SIN PREDICCIÓN. Debería ser: 'reuter'
# Predicción para 'they'-'told'-'reuter': SIN PREDICCIÓN. Debería ser: 'correspondents'
# Predicción para 'told'-'reuter'-'correspondents': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'reuter'-'correspondents'-'in': SIN PREDICCIÓN. Debería ser: 'asian'
# Predicción para 'correspondents'-'in'-'asian': SIN PREDICCIÓN. Debería ser: 'capitals'
# Predicción para 'in'-'asian'-'capitals': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'asian'-'capitals'-'a': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'capitals'-'a'-'u.s.': SIN PREDICCIÓN. Debería ser: 'move'
# Predicción para 'a'-'u.s.'-'move': SIN PREDICCIÓN. Debería ser: 'against'
# Predicción para 'u.s.'-'move'-'against': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'move'-'against'-'japan': SIN PREDICCIÓN. Debería ser: 'might'
# Predicción para 'against'-'japan'-'might': SIN PREDICCIÓN. Debería ser: 'boost'
# Predicción para 'japan'-'might'-'boost': SIN PREDICCIÓN. Debería ser: 'protectionist'
# Predicción para 'might'-'boost'-'protectionist': SIN PREDICCIÓN. Debería ser: 'sentiment'
# Predicción para 'boost'-'protectionist'-'sentiment': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'protectionist'-'sentiment'-'in': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'sentiment'-'in'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'in'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'the'-'u.s.'-'and': SIN PREDICCIÓN. Debería ser: 'lead'
# Predicción para 'u.s.'-'and'-'lead': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'and'-'lead'-'to': SIN PREDICCIÓN. Debería ser: 'curbs'
# Predicción para 'lead'-'to'-'curbs': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'to'-'curbs'-'on': SIN PREDICCIÓN. Debería ser: 'american'
# Predicción para 'curbs'-'on'-'american': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'on'-'american'-'imports': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'american'-'imports'-'of': SIN PREDICCIÓN. Debería ser: 'their'
# Predicción para 'imports'-'of'-'their': SIN PREDICCIÓN. Debería ser: 'products'
# Predicción para 'of'-'their'-'products': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'their'-'products'-'.': SIN PREDICCIÓN. Debería ser: 'but'
# Predicción para 'products'-'.'-'but': SIN PREDICCIÓN. Debería ser: 'some'
# Predicción para '.'-'but'-'some': SIN PREDICCIÓN. Debería ser: 'exporters'
# Predicción para 'but'-'some'-'exporters': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'some'-'exporters'-'said': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para 'exporters'-'said'-'that': SIN PREDICCIÓN. Debería ser: 'while'
# Predicción para 'said'-'that'-'while': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'that'-'while'-'the': SIN PREDICCIÓN. Debería ser: 'conflict'
# Predicción para 'while'-'the'-'conflict': SIN PREDICCIÓN. Debería ser: 'would'
# Predicción para 'the'-'conflict'-'would': SIN PREDICCIÓN. Debería ser: 'hurt'
# Predicción para 'conflict'-'would'-'hurt': SIN PREDICCIÓN. Debería ser: 'them'
# Predicción para 'would'-'hurt'-'them': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'hurt'-'them'-'in': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'them'-'in'-'the': SIN PREDICCIÓN. Debería ser: 'long-run'
# Predicción para 'in'-'the'-'long-run': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'the'-'long-run'-',': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'long-run'-','-'in': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para ','-'in'-'the': SIN PREDICCIÓN. Debería ser: 'short-term'
# Predicción para 'in'-'the'-'short-term': SIN PREDICCIÓN. Debería ser: 'tokyo'
# Predicción para 'the'-'short-term'-'tokyo': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'short-term'-'tokyo'-''s': SIN PREDICCIÓN. Debería ser: 'loss'
# Predicción para 'tokyo'-''s'-'loss': SIN PREDICCIÓN. Debería ser: 'might'
# Predicción para ''s'-'loss'-'might': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'loss'-'might'-'be': SIN PREDICCIÓN. Debería ser: 'their'
# Predicción para 'might'-'be'-'their': SIN PREDICCIÓN. Debería ser: 'gain'
# Predicción para 'be'-'their'-'gain': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'their'-'gain'-'.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'gain'-'.'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para '.'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'has'
# Predicción para 'the'-'u.s.'-'has': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'u.s.'-'has'-'said': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'has'-'said'-'it': SIN PREDICCIÓN. Debería ser: 'will'
# Predicción para 'said'-'it'-'will': SIN PREDICCIÓN. Debería ser: 'impose'
# Predicción para 'it'-'will'-'impose': SIN PREDICCIÓN. Debería ser: '300'
# Predicción para 'will'-'impose'-'300': SIN PREDICCIÓN. Debería ser: 'mln'
# Predicción para 'impose'-'300'-'mln': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '300'-'mln'-'dlrs': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'mln'-'dlrs'-'of': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'dlrs'-'of'-'tariffs': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'of'-'tariffs'-'on': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'tariffs'-'on'-'imports': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'on'-'imports'-'of': SIN PREDICCIÓN. Debería ser: 'japanese'
# Predicción para 'imports'-'of'-'japanese': SIN PREDICCIÓN. Debería ser: 'electronics'
# Predicción para 'of'-'japanese'-'electronics': SIN PREDICCIÓN. Debería ser: 'goods'
# Predicción para 'japanese'-'electronics'-'goods': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'electronics'-'goods'-'on': SIN PREDICCIÓN. Debería ser: 'april'
# Predicción para 'goods'-'on'-'april': SIN PREDICCIÓN. Debería ser: '17'
# Predicción para 'on'-'april'-'17': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'april'-'17'-',': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para '17'-','-'in': SIN PREDICCIÓN. Debería ser: 'retaliation'
# Predicción para ','-'in'-'retaliation': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'in'-'retaliation'-'for': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'retaliation'-'for'-'japan': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'for'-'japan'-''s': SIN PREDICCIÓN. Debería ser: 'alleged'
# Predicción para 'japan'-''s'-'alleged': SIN PREDICCIÓN. Debería ser: 'failure'
# Predicción para ''s'-'alleged'-'failure': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'alleged'-'failure'-'to': SIN PREDICCIÓN. Debería ser: 'stick'
# Predicción para 'failure'-'to'-'stick': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'to'-'stick'-'to': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'stick'-'to'-'a': SIN PREDICCIÓN. Debería ser: 'pact'
# Predicción para 'to'-'a'-'pact': SIN PREDICCIÓN. Debería ser: 'not'
# Predicción para 'a'-'pact'-'not': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'pact'-'not'-'to': SIN PREDICCIÓN. Debería ser: 'sell'
# Predicción para 'not'-'to'-'sell': SIN PREDICCIÓN. Debería ser: 'semiconductors'
# Predicción para 'to'-'sell'-'semiconductors': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'sell'-'semiconductors'-'on': SIN PREDICCIÓN. Debería ser: 'world'
# Predicción para 'semiconductors'-'on'-'world': SIN PREDICCIÓN. Debería ser: 'markets'
# Predicción para 'on'-'world'-'markets': SIN PREDICCIÓN. Debería ser: 'at'
# Predicción para 'world'-'markets'-'at': SIN PREDICCIÓN. Debería ser: 'below'
# Predicción para 'markets'-'at'-'below': SIN PREDICCIÓN. Debería ser: 'cost'
# Predicción para 'at'-'below'-'cost': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'below'-'cost'-'.': SIN PREDICCIÓN. Debería ser: 'unofficial'
# Predicción para 'cost'-'.'-'unofficial': SIN PREDICCIÓN. Debería ser: 'japanese'
# Predicción para '.'-'unofficial'-'japanese': SIN PREDICCIÓN. Debería ser: 'estimates'
# Predicción para 'unofficial'-'japanese'-'estimates': SIN PREDICCIÓN. Debería ser: 'put'
# Predicción para 'japanese'-'estimates'-'put': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'estimates'-'put'-'the': SIN PREDICCIÓN. Debería ser: 'impact'
# Predicción para 'put'-'the'-'impact': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'impact'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'impact'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'of'-'the'-'tariffs': SIN PREDICCIÓN. Debería ser: 'at'
# Predicción para 'the'-'tariffs'-'at': SIN PREDICCIÓN. Debería ser: '10'
# Predicción para 'tariffs'-'at'-'10': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'at'-'10'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '10'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'billion'-'dlrs'-'and': SIN PREDICCIÓN. Debería ser: 'spokesmen'
# Predicción para 'dlrs'-'and'-'spokesmen': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'and'-'spokesmen'-'for': SIN PREDICCIÓN. Debería ser: 'major'
# Predicción para 'spokesmen'-'for'-'major': SIN PREDICCIÓN. Debería ser: 'electronics'
# Predicción para 'for'-'major'-'electronics': SIN PREDICCIÓN. Debería ser: 'firms'
# Predicción para 'major'-'electronics'-'firms': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'electronics'-'firms'-'said': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'firms'-'said'-'they': SIN PREDICCIÓN. Debería ser: 'would'
# Predicción para 'said'-'they'-'would': SIN PREDICCIÓN. Debería ser: 'virtually'
# Predicción para 'they'-'would'-'virtually': SIN PREDICCIÓN. Debería ser: 'halt'
# Predicción para 'would'-'virtually'-'halt': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'virtually'-'halt'-'exports': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'halt'-'exports'-'of': SIN PREDICCIÓN. Debería ser: 'products'
# Predicción para 'exports'-'of'-'products': SIN PREDICCIÓN. Debería ser: 'hit'
# Predicción para 'of'-'products'-'hit': SIN PREDICCIÓN. Debería ser: 'by'
# Predicción para 'products'-'hit'-'by': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'hit'-'by'-'the': SIN PREDICCIÓN. Debería ser: 'new'
# Predicción para 'by'-'the'-'new': SIN PREDICCIÓN. Debería ser: 'taxes'
# Predicción para 'the'-'new'-'taxes': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'new'-'taxes'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'taxes'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'we'
# Predicción para '.'-'``'-'we': SIN PREDICCIÓN. Debería ser: 'would'
# Predicción para '``'-'we'-'would': SIN PREDICCIÓN. Debería ser: 'n't'
# Predicción para 'we'-'would'-'n't': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'would'-'n't'-'be': SIN PREDICCIÓN. Debería ser: 'able'
# Predicción para 'n't'-'be'-'able': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'be'-'able'-'to': SIN PREDICCIÓN. Debería ser: 'do'
# Predicción para 'able'-'to'-'do': SIN PREDICCIÓN. Debería ser: 'business'
# Predicción para 'to'-'do'-'business': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'do'-'business'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'business'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para ''''-'said'-'a': SIN PREDICCIÓN. Debería ser: 'spokesman'
# Predicción para 'said'-'a'-'spokesman': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'a'-'spokesman'-'for': SIN PREDICCIÓN. Debería ser: 'leading'
# Predicción para 'spokesman'-'for'-'leading': SIN PREDICCIÓN. Debería ser: 'japanese'
# Predicción para 'for'-'leading'-'japanese': SIN PREDICCIÓN. Debería ser: 'electronics'
# Predicción para 'leading'-'japanese'-'electronics': SIN PREDICCIÓN. Debería ser: 'firm'
# Predicción para 'japanese'-'electronics'-'firm': SIN PREDICCIÓN. Debería ser: 'matsushita'
# Predicción para 'electronics'-'firm'-'matsushita': SIN PREDICCIÓN. Debería ser: 'electric'
# Predicción para 'firm'-'matsushita'-'electric': SIN PREDICCIÓN. Debería ser: 'industrial'
# Predicción para 'matsushita'-'electric'-'industrial': SIN PREDICCIÓN. Debería ser: 'co'
# Predicción para 'electric'-'industrial'-'co': SIN PREDICCIÓN. Debería ser: 'ltd'
# Predicción para 'industrial'-'co'-'ltd': SIN PREDICCIÓN. Debería ser: '&'
# Predicción para 'co'-'ltd'-'&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'ltd'-'&'-'lt': SIN PREDICCIÓN. Debería ser: ';'
# Predicción para '&'-'lt'-';': SIN PREDICCIÓN. Debería ser: 'mc.t'
# Predicción para 'lt'-';'-'mc.t': SIN PREDICCIÓN. Debería ser: '>'
# Predicción para ';'-'mc.t'-'>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'mc.t'-'>'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '>'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'if'
# Predicción para '.'-'``'-'if': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para '``'-'if'-'the': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'if'-'the'-'tariffs': SIN PREDICCIÓN. Debería ser: 'remain'
# Predicción para 'the'-'tariffs'-'remain': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'tariffs'-'remain'-'in': SIN PREDICCIÓN. Debería ser: 'place'
# Predicción para 'remain'-'in'-'place': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'in'-'place'-'for': SIN PREDICCIÓN. Debería ser: 'any'
# Predicción para 'place'-'for'-'any': SIN PREDICCIÓN. Debería ser: 'length'
# Predicción para 'for'-'any'-'length': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'any'-'length'-'of': SIN PREDICCIÓN. Debería ser: 'time'
# Predicción para 'length'-'of'-'time': SIN PREDICCIÓN. Debería ser: 'beyond'
# Predicción para 'of'-'time'-'beyond': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'time'-'beyond'-'a': SIN PREDICCIÓN. Debería ser: 'few'
# Predicción para 'beyond'-'a'-'few': SIN PREDICCIÓN. Debería ser: 'months'
# Predicción para 'a'-'few'-'months': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'few'-'months'-'it': SIN PREDICCIÓN. Debería ser: 'will'
# Predicción para 'months'-'it'-'will': SIN PREDICCIÓN. Debería ser: 'mean'
# Predicción para 'it'-'will'-'mean': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'will'-'mean'-'the': SIN PREDICCIÓN. Debería ser: 'complete'
# Predicción para 'mean'-'the'-'complete': SIN PREDICCIÓN. Debería ser: 'erosion'
# Predicción para 'the'-'complete'-'erosion': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'complete'-'erosion'-'of': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'erosion'-'of'-'exports': SIN PREDICCIÓN. Debería ser: '('
# Predicción para 'of'-'exports'-'(': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'exports'-'('-'of': SIN PREDICCIÓN. Debería ser: 'goods'
# Predicción para '('-'of'-'goods': SIN PREDICCIÓN. Debería ser: 'subject'
# Predicción para 'of'-'goods'-'subject': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'goods'-'subject'-'to': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'subject'-'to'-'tariffs': SIN PREDICCIÓN. Debería ser: ')'
# Predicción para 'to'-'tariffs'-')': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'tariffs'-')'-'to': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para ')'-'to'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'to'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'the'-'u.s.'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'u.s.'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'tom'
# Predicción para ''''-'said'-'tom': SIN PREDICCIÓN. Debería ser: 'murtha'
# Predicción para 'said'-'tom'-'murtha': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'tom'-'murtha'-',': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'murtha'-','-'a': SIN PREDICCIÓN. Debería ser: 'stock'
# Predicción para ','-'a'-'stock': SIN PREDICCIÓN. Debería ser: 'analyst'
# Predicción para 'a'-'stock'-'analyst': SIN PREDICCIÓN. Debería ser: 'at'
# Predicción para 'stock'-'analyst'-'at': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'analyst'-'at'-'the': SIN PREDICCIÓN. Debería ser: 'tokyo'
# Predicción para 'at'-'the'-'tokyo': SIN PREDICCIÓN. Debería ser: 'office'
# Predicción para 'the'-'tokyo'-'office': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'tokyo'-'office'-'of': SIN PREDICCIÓN. Debería ser: 'broker'
# Predicción para 'office'-'of'-'broker': SIN PREDICCIÓN. Debería ser: '&'
# Predicción para 'of'-'broker'-'&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'broker'-'&'-'lt': SIN PREDICCIÓN. Debería ser: ';'
# Predicción para '&'-'lt'-';': SIN PREDICCIÓN. Debería ser: 'james'
# Predicción para 'lt'-';'-'james': SIN PREDICCIÓN. Debería ser: 'capel'
# Predicción para ';'-'james'-'capel': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'james'-'capel'-'and': SIN PREDICCIÓN. Debería ser: 'co'
# Predicción para 'capel'-'and'-'co': SIN PREDICCIÓN. Debería ser: '>'
# Predicción para 'and'-'co'-'>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'co'-'>'-'.': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para '>'-'.'-'in': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para '.'-'in'-'taiwan': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'in'-'taiwan'-',': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'taiwan'-','-'businessmen': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para ','-'businessmen'-'and': SIN PREDICCIÓN. Debería ser: 'officials'
# Predicción para 'businessmen'-'and'-'officials': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para 'and'-'officials'-'are': SIN PREDICCIÓN. Debería ser: 'also'
# Predicción para 'officials'-'are'-'also': SIN PREDICCIÓN. Debería ser: 'worried'
# Predicción para 'are'-'also'-'worried': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'also'-'worried'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'worried'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'we'
# Predicción para '.'-'``'-'we': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para '``'-'we'-'are': SIN PREDICCIÓN. Debería ser: 'aware'
# Predicción para 'we'-'are'-'aware': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'are'-'aware'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'aware'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'seriousness'
# Predicción para 'of'-'the'-'seriousness': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'seriousness'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'seriousness'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'of'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'threat'
# Predicción para 'the'-'u.s.'-'threat': SIN PREDICCIÓN. Debería ser: 'against'
# Predicción para 'u.s.'-'threat'-'against': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'threat'-'against'-'japan': SIN PREDICCIÓN. Debería ser: 'because'
# Predicción para 'against'-'japan'-'because': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'japan'-'because'-'it': SIN PREDICCIÓN. Debería ser: 'serves'
# Predicción para 'because'-'it'-'serves': SIN PREDICCIÓN. Debería ser: 'as'
# Predicción para 'it'-'serves'-'as': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'serves'-'as'-'a': SIN PREDICCIÓN. Debería ser: 'warning'
# Predicción para 'as'-'a'-'warning': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'a'-'warning'-'to': SIN PREDICCIÓN. Debería ser: 'us'
# Predicción para 'warning'-'to'-'us': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'to'-'us'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'us'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para ''''-'said'-'a': SIN PREDICCIÓN. Debería ser: 'senior'
# Predicción para 'said'-'a'-'senior': SIN PREDICCIÓN. Debería ser: 'taiwanese'
# Predicción para 'a'-'senior'-'taiwanese': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'senior'-'taiwanese'-'trade': SIN PREDICCIÓN. Debería ser: 'official'
# Predicción para 'taiwanese'-'trade'-'official': SIN PREDICCIÓN. Debería ser: 'who'
# Predicción para 'trade'-'official'-'who': SIN PREDICCIÓN. Debería ser: 'asked'
# Predicción para 'official'-'who'-'asked': SIN PREDICCIÓN. Debería ser: 'not'
# Predicción para 'who'-'asked'-'not': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'asked'-'not'-'to': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'not'-'to'-'be': SIN PREDICCIÓN. Debería ser: 'named'
# Predicción para 'to'-'be'-'named': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'be'-'named'-'.': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'named'-'.'-'taiwan': SIN PREDICCIÓN. Debería ser: 'had'
# Predicción para '.'-'taiwan'-'had': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'taiwan'-'had'-'a': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'had'-'a'-'trade': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'a'-'trade'-'trade': SIN PREDICCIÓN. Debería ser: 'surplus'
# Predicción para 'trade'-'trade'-'surplus': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'trade'-'surplus'-'of': SIN PREDICCIÓN. Debería ser: '15.6'
# Predicción para 'surplus'-'of'-'15.6': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'of'-'15.6'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '15.6'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'billion'-'dlrs'-'last': SIN PREDICCIÓN. Debería ser: 'year'
# Predicción para 'dlrs'-'last'-'year': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'last'-'year'-',': SIN PREDICCIÓN. Debería ser: '95'
# Predicción para 'year'-','-'95': SIN PREDICCIÓN. Debería ser: 'pct'
# Predicción para ','-'95'-'pct': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para '95'-'pct'-'of': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'pct'-'of'-'it': SIN PREDICCIÓN. Debería ser: 'with'
# Predicción para 'of'-'it'-'with': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'it'-'with'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'with'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the'-'u.s.'-'the': SIN PREDICCIÓN. Debería ser: 'surplus'
# Predicción para 'u.s.'-'the'-'surplus': SIN PREDICCIÓN. Debería ser: 'helped'
# Predicción para 'the'-'surplus'-'helped': SIN PREDICCIÓN. Debería ser: 'swell'
# Predicción para 'surplus'-'helped'-'swell': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'helped'-'swell'-'taiwan': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'swell'-'taiwan'-''s': SIN PREDICCIÓN. Debería ser: 'foreign'
# Predicción para 'taiwan'-''s'-'foreign': SIN PREDICCIÓN. Debería ser: 'exchange'
# Predicción para ''s'-'foreign'-'exchange': SIN PREDICCIÓN. Debería ser: 'reserves'
# Predicción para 'foreign'-'exchange'-'reserves': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'exchange'-'reserves'-'to': SIN PREDICCIÓN. Debería ser: '53'
# Predicción para 'reserves'-'to'-'53': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'to'-'53'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '53'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'billion'-'dlrs'-',': SIN PREDICCIÓN. Debería ser: 'among'
# Predicción para 'dlrs'-','-'among': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para ','-'among'-'the': SIN PREDICCIÓN. Debería ser: 'world'
# Predicción para 'among'-'the'-'world': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'the'-'world'-''s': SIN PREDICCIÓN. Debería ser: 'largest'
# Predicción para 'world'-''s'-'largest': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para ''s'-'largest'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'largest'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'we'
# Predicción para '.'-'``'-'we': SIN PREDICCIÓN. Debería ser: 'must'
# Predicción para '``'-'we'-'must': SIN PREDICCIÓN. Debería ser: 'quickly'
# Predicción para 'we'-'must'-'quickly': SIN PREDICCIÓN. Debería ser: 'open'
# Predicción para 'must'-'quickly'-'open': SIN PREDICCIÓN. Debería ser: 'our'
# Predicción para 'quickly'-'open'-'our': SIN PREDICCIÓN. Debería ser: 'markets'
# Predicción para 'open'-'our'-'markets': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'our'-'markets'-',': SIN PREDICCIÓN. Debería ser: 'remove'
# Predicción para 'markets'-','-'remove': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para ','-'remove'-'trade': SIN PREDICCIÓN. Debería ser: 'barriers'
# Predicción para 'remove'-'trade'-'barriers': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'trade'-'barriers'-'and': SIN PREDICCIÓN. Debería ser: 'cut'
# Predicción para 'barriers'-'and'-'cut': SIN PREDICCIÓN. Debería ser: 'import'
# Predicción para 'and'-'cut'-'import': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'cut'-'import'-'tariffs': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'import'-'tariffs'-'to': SIN PREDICCIÓN. Debería ser: 'allow'
# Predicción para 'tariffs'-'to'-'allow': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'to'-'allow'-'imports': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'allow'-'imports'-'of': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'imports'-'of'-'u.s.': SIN PREDICCIÓN. Debería ser: 'products'
# Predicción para 'of'-'u.s.'-'products': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'u.s.'-'products'-',': SIN PREDICCIÓN. Debería ser: 'if'
# Predicción para 'products'-','-'if': SIN PREDICCIÓN. Debería ser: 'we'
# Predicción para ','-'if'-'we': SIN PREDICCIÓN. Debería ser: 'want'
# Predicción para 'if'-'we'-'want': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'we'-'want'-'to': SIN PREDICCIÓN. Debería ser: 'defuse'
# Predicción para 'want'-'to'-'defuse': SIN PREDICCIÓN. Debería ser: 'problems'
# Predicción para 'to'-'defuse'-'problems': SIN PREDICCIÓN. Debería ser: 'from'
# Predicción para 'defuse'-'problems'-'from': SIN PREDICCIÓN. Debería ser: 'possible'
# Predicción para 'problems'-'from'-'possible': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'from'-'possible'-'u.s.': SIN PREDICCIÓN. Debería ser: 'retaliation'
# Predicción para 'possible'-'u.s.'-'retaliation': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'u.s.'-'retaliation'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'retaliation'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'paul'
# Predicción para ''''-'said'-'paul': SIN PREDICCIÓN. Debería ser: 'sheen'
# Predicción para 'said'-'paul'-'sheen': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'paul'-'sheen'-',': SIN PREDICCIÓN. Debería ser: 'chairman'
# Predicción para 'sheen'-','-'chairman': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para ','-'chairman'-'of': SIN PREDICCIÓN. Debería ser: 'textile'
# Predicción para 'chairman'-'of'-'textile': SIN PREDICCIÓN. Debería ser: 'exporters'
# Predicción para 'of'-'textile'-'exporters': SIN PREDICCIÓN. Debería ser: '&'
# Predicción para 'textile'-'exporters'-'&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'exporters'-'&'-'lt': SIN PREDICCIÓN. Debería ser: ';'
# Predicción para '&'-'lt'-';': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'lt'-';'-'taiwan': SIN PREDICCIÓN. Debería ser: 'safe'
# Predicción para ';'-'taiwan'-'safe': SIN PREDICCIÓN. Debería ser: 'group'
# Predicción para 'taiwan'-'safe'-'group': SIN PREDICCIÓN. Debería ser: '>'
# Predicción para 'safe'-'group'-'>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'group'-'>'-'.': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para '>'-'.'-'a': SIN PREDICCIÓN. Debería ser: 'senior'
# Predicción para '.'-'a'-'senior': SIN PREDICCIÓN. Debería ser: 'official'
# Predicción para 'a'-'senior'-'official': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'senior'-'official'-'of': SIN PREDICCIÓN. Debería ser: 'south'
# Predicción para 'official'-'of'-'south': SIN PREDICCIÓN. Debería ser: 'korea'
# Predicción para 'of'-'south'-'korea': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'south'-'korea'-''s': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'korea'-''s'-'trade': SIN PREDICCIÓN. Debería ser: 'promotion'
# Predicción para ''s'-'trade'-'promotion': SIN PREDICCIÓN. Debería ser: 'association'
# Predicción para 'trade'-'promotion'-'association': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'promotion'-'association'-'said': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'association'-'said'-'the': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'said'-'the'-'trade': SIN PREDICCIÓN. Debería ser: 'dispute'
# Predicción para 'the'-'trade'-'dispute': SIN PREDICCIÓN. Debería ser: 'between'
# Predicción para 'trade'-'dispute'-'between': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'dispute'-'between'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'between'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'the'-'u.s.'-'and': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'u.s.'-'and'-'japan': SIN PREDICCIÓN. Debería ser: 'might'
# Predicción para 'and'-'japan'-'might': SIN PREDICCIÓN. Debería ser: 'also'
# Predicción para 'japan'-'might'-'also': SIN PREDICCIÓN. Debería ser: 'lead'
# Predicción para 'might'-'also'-'lead': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'also'-'lead'-'to': SIN PREDICCIÓN. Debería ser: 'pressure'
# Predicción para 'lead'-'to'-'pressure': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'to'-'pressure'-'on': SIN PREDICCIÓN. Debería ser: 'south'
# Predicción para 'pressure'-'on'-'south': SIN PREDICCIÓN. Debería ser: 'korea'
# Predicción para 'on'-'south'-'korea': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'south'-'korea'-',': SIN PREDICCIÓN. Debería ser: 'whose'
# Predicción para 'korea'-','-'whose': SIN PREDICCIÓN. Debería ser: 'chief'
# Predicción para ','-'whose'-'chief': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'whose'-'chief'-'exports': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para 'chief'-'exports'-'are': SIN PREDICCIÓN. Debería ser: 'similar'
# Predicción para 'exports'-'are'-'similar': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'are'-'similar'-'to': SIN PREDICCIÓN. Debería ser: 'those'
# Predicción para 'similar'-'to'-'those': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'to'-'those'-'of': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'those'-'of'-'japan': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'of'-'japan'-'.': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'japan'-'.'-'last': SIN PREDICCIÓN. Debería ser: 'year'
# Predicción para '.'-'last'-'year': SIN PREDICCIÓN. Debería ser: 'south'
# Predicción para 'last'-'year'-'south': SIN PREDICCIÓN. Debería ser: 'korea'
# Predicción para 'year'-'south'-'korea': SIN PREDICCIÓN. Debería ser: 'had'
# Predicción para 'south'-'korea'-'had': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'korea'-'had'-'a': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'had'-'a'-'trade': SIN PREDICCIÓN. Debería ser: 'surplus'
# Predicción para 'a'-'trade'-'surplus': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'trade'-'surplus'-'of': SIN PREDICCIÓN. Debería ser: '7.1'
# Predicción para 'surplus'-'of'-'7.1': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'of'-'7.1'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '7.1'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: 'with'
# Predicción para 'billion'-'dlrs'-'with': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'dlrs'-'with'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'with'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'the'-'u.s.'-',': SIN PREDICCIÓN. Debería ser: 'up'
# Predicción para 'u.s.'-','-'up': SIN PREDICCIÓN. Debería ser: 'from'
# Predicción para ','-'up'-'from': SIN PREDICCIÓN. Debería ser: '4.9'
# Predicción para 'up'-'from'-'4.9': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'from'-'4.9'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '4.9'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'billion'-'dlrs'-'in': SIN PREDICCIÓN. Debería ser: '1985.'
# Predicción para 'dlrs'-'in'-'1985.': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'in'-'1985.'-'in': SIN PREDICCIÓN. Debería ser: 'malaysia'
# Predicción para '1985.'-'in'-'malaysia': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'in'-'malaysia'-',': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'malaysia'-','-'trade': SIN PREDICCIÓN. Debería ser: 'officers'
# Predicción para ','-'trade'-'officers': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'trade'-'officers'-'and': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'officers'-'and'-'businessmen': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'and'-'businessmen'-'said': SIN PREDICCIÓN. Debería ser: 'tough'
# Predicción para 'businessmen'-'said'-'tough': SIN PREDICCIÓN. Debería ser: 'curbs'
# Predicción para 'said'-'tough'-'curbs': SIN PREDICCIÓN. Debería ser: 'against'
# Predicción para 'tough'-'curbs'-'against': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'curbs'-'against'-'japan': SIN PREDICCIÓN. Debería ser: 'might'
# Predicción para 'against'-'japan'-'might': SIN PREDICCIÓN. Debería ser: 'allow'
# Predicción para 'japan'-'might'-'allow': SIN PREDICCIÓN. Debería ser: 'hard-hit'
# Predicción para 'might'-'allow'-'hard-hit': SIN PREDICCIÓN. Debería ser: 'producers'
# Predicción para 'allow'-'hard-hit'-'producers': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'hard-hit'-'producers'-'of': SIN PREDICCIÓN. Debería ser: 'semiconductors'
# Predicción para 'producers'-'of'-'semiconductors': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'of'-'semiconductors'-'in': SIN PREDICCIÓN. Debería ser: 'third'
# Predicción para 'semiconductors'-'in'-'third': SIN PREDICCIÓN. Debería ser: 'countries'
# Predicción para 'in'-'third'-'countries': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'third'-'countries'-'to': SIN PREDICCIÓN. Debería ser: 'expand'
# Predicción para 'countries'-'to'-'expand': SIN PREDICCIÓN. Debería ser: 'their'
# Predicción para 'to'-'expand'-'their': SIN PREDICCIÓN. Debería ser: 'sales'
# Predicción para 'expand'-'their'-'sales': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'their'-'sales'-'to': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'sales'-'to'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'to'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'the'-'u.s.'-'in': SIN PREDICCIÓN. Debería ser: 'hong'
# Predicción para 'u.s.'-'in'-'hong': SIN PREDICCIÓN. Debería ser: 'kong'
# Predicción para 'in'-'hong'-'kong': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'hong'-'kong'-',': SIN PREDICCIÓN. Debería ser: 'where'
# Predicción para 'kong'-','-'where': SIN PREDICCIÓN. Debería ser: 'newspapers'
# Predicción para ','-'where'-'newspapers': SIN PREDICCIÓN. Debería ser: 'have'
# Predicción para 'where'-'newspapers'-'have': SIN PREDICCIÓN. Debería ser: 'alleged'
# Predicción para 'newspapers'-'have'-'alleged': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'have'-'alleged'-'japan': SIN PREDICCIÓN. Debería ser: 'has'
# Predicción para 'alleged'-'japan'-'has': SIN PREDICCIÓN. Debería ser: 'been'
# Predicción para 'japan'-'has'-'been': SIN PREDICCIÓN. Debería ser: 'selling'
# Predicción para 'has'-'been'-'selling': SIN PREDICCIÓN. Debería ser: 'below-cost'
# Predicción para 'been'-'selling'-'below-cost': SIN PREDICCIÓN. Debería ser: 'semiconductors'
# Predicción para 'selling'-'below-cost'-'semiconductors': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'below-cost'-'semiconductors'-',': SIN PREDICCIÓN. Debería ser: 'some'
# Predicción para 'semiconductors'-','-'some': SIN PREDICCIÓN. Debería ser: 'electronics'
# Predicción para ','-'some'-'electronics': SIN PREDICCIÓN. Debería ser: 'manufacturers'
# Predicción para 'some'-'electronics'-'manufacturers': SIN PREDICCIÓN. Debería ser: 'share'
# Predicción para 'electronics'-'manufacturers'-'share': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para 'manufacturers'-'share'-'that': SIN PREDICCIÓN. Debería ser: 'view'
# Predicción para 'share'-'that'-'view': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'that'-'view'-'.': SIN PREDICCIÓN. Debería ser: 'but'
# Predicción para 'view'-'.'-'but': SIN PREDICCIÓN. Debería ser: 'other'
# Predicción para '.'-'but'-'other': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'but'-'other'-'businessmen': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'other'-'businessmen'-'said': SIN PREDICCIÓN. Debería ser: 'such'
# Predicción para 'businessmen'-'said'-'such': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'said'-'such'-'a': SIN PREDICCIÓN. Debería ser: 'short-term'
# Predicción para 'such'-'a'-'short-term': SIN PREDICCIÓN. Debería ser: 'commercial'
# Predicción para 'a'-'short-term'-'commercial': SIN PREDICCIÓN. Debería ser: 'advantage'
# Predicción para 'short-term'-'commercial'-'advantage': SIN PREDICCIÓN. Debería ser: 'would'
# Predicción para 'commercial'-'advantage'-'would': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'advantage'-'would'-'be': SIN PREDICCIÓN. Debería ser: 'outweighed'
# Predicción para 'would'-'be'-'outweighed': SIN PREDICCIÓN. Debería ser: 'by'
# Predicción para 'be'-'outweighed'-'by': SIN PREDICCIÓN. Debería ser: 'further'
# Predicción para 'outweighed'-'by'-'further': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'by'-'further'-'u.s.': SIN PREDICCIÓN. Debería ser: 'pressure'
# Predicción para 'further'-'u.s.'-'pressure': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'u.s.'-'pressure'-'to': SIN PREDICCIÓN. Debería ser: 'block'
# Predicción para 'pressure'-'to'-'block': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'to'-'block'-'imports': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'block'-'imports'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'imports'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para '.'-'``'-'that': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para '``'-'that'-'is': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'that'-'is'-'a': SIN PREDICCIÓN. Debería ser: 'very'
# Predicción para 'is'-'a'-'very': SIN PREDICCIÓN. Debería ser: 'short-term'
# Predicción para 'a'-'very'-'short-term': SIN PREDICCIÓN. Debería ser: 'view'
# Predicción para 'very'-'short-term'-'view': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'short-term'-'view'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'view'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'lawrence'
# Predicción para ''''-'said'-'lawrence': SIN PREDICCIÓN. Debería ser: 'mills'
# Predicción para 'said'-'lawrence'-'mills': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'lawrence'-'mills'-',': SIN PREDICCIÓN. Debería ser: 'director-general'
# Predicción para 'mills'-','-'director-general': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para ','-'director-general'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'director-general'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'federation'
# Predicción para 'of'-'the'-'federation': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'federation'-'of': SIN PREDICCIÓN. Debería ser: 'hong'
# Predicción para 'federation'-'of'-'hong': SIN PREDICCIÓN. Debería ser: 'kong'
# Predicción para 'of'-'hong'-'kong': SIN PREDICCIÓN. Debería ser: 'industry'
# Predicción para 'hong'-'kong'-'industry': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'kong'-'industry'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'industry'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'if'
# Predicción para '.'-'``'-'if': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para '``'-'if'-'the': SIN PREDICCIÓN. Debería ser: 'whole'
# Predicción para 'if'-'the'-'whole': SIN PREDICCIÓN. Debería ser: 'purpose'
# Predicción para 'the'-'whole'-'purpose': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para 'whole'-'purpose'-'is': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'purpose'-'is'-'to': SIN PREDICCIÓN. Debería ser: 'prevent'
# Predicción para 'is'-'to'-'prevent': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'to'-'prevent'-'imports': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'prevent'-'imports'-',': SIN PREDICCIÓN. Debería ser: 'one'
# Predicción para 'imports'-','-'one': SIN PREDICCIÓN. Debería ser: 'day'
# Predicción para ','-'one'-'day': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'one'-'day'-'it': SIN PREDICCIÓN. Debería ser: 'will'
# Predicción para 'day'-'it'-'will': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'it'-'will'-'be': SIN PREDICCIÓN. Debería ser: 'extended'
# Predicción para 'will'-'be'-'extended': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'be'-'extended'-'to': SIN PREDICCIÓN. Debería ser: 'other'
# Predicción para 'extended'-'to'-'other': SIN PREDICCIÓN. Debería ser: 'sources'
# Predicción para 'to'-'other'-'sources': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'other'-'sources'-'.': SIN PREDICCIÓN. Debería ser: 'much'
# Predicción para 'sources'-'.'-'much': SIN PREDICCIÓN. Debería ser: 'more'
# Predicción para '.'-'much'-'more': SIN PREDICCIÓN. Debería ser: 'serious'
# Predicción para 'much'-'more'-'serious': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'more'-'serious'-'for': SIN PREDICCIÓN. Debería ser: 'hong'
# Predicción para 'serious'-'for'-'hong': SIN PREDICCIÓN. Debería ser: 'kong'
# Predicción para 'for'-'hong'-'kong': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para 'hong'-'kong'-'is': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'kong'-'is'-'the': SIN PREDICCIÓN. Debería ser: 'disadvantage'
# Predicción para 'is'-'the'-'disadvantage': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'disadvantage'-'of': SIN PREDICCIÓN. Debería ser: 'action'
# Predicción para 'disadvantage'-'of'-'action': SIN PREDICCIÓN. Debería ser: 'restraining'
# Predicción para 'of'-'action'-'restraining': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'action'-'restraining'-'trade': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'restraining'-'trade'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'trade'-','-'''': SIN PREDICCIÓN. Debería ser: 'he'
# Predicción para ','-''''-'he': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ''''-'he'-'said': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'he'-'said'-'.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'said'-'.'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para '.'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'the'-'u.s.'-'last': SIN PREDICCIÓN. Debería ser: 'year'
# Predicción para 'u.s.'-'last'-'year': SIN PREDICCIÓN. Debería ser: 'was'
# Predicción para 'last'-'year'-'was': SIN PREDICCIÓN. Debería ser: 'hong'
# Predicción para 'year'-'was'-'hong': SIN PREDICCIÓN. Debería ser: 'kong'
# Predicción para 'was'-'hong'-'kong': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'hong'-'kong'-''s': SIN PREDICCIÓN. Debería ser: 'biggest'
# Predicción para 'kong'-''s'-'biggest': SIN PREDICCIÓN. Debería ser: 'export'
# Predicción para ''s'-'biggest'-'export': SIN PREDICCIÓN. Debería ser: 'market'
# Predicción para 'biggest'-'export'-'market': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'export'-'market'-',': SIN PREDICCIÓN. Debería ser: 'accounting'
# Predicción para 'market'-','-'accounting': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para ','-'accounting'-'for': SIN PREDICCIÓN. Debería ser: 'over'
# Predicción para 'accounting'-'for'-'over': SIN PREDICCIÓN. Debería ser: '30'
# Predicción para 'for'-'over'-'30': SIN PREDICCIÓN. Debería ser: 'pct'
# Predicción para 'over'-'30'-'pct': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para '30'-'pct'-'of': SIN PREDICCIÓN. Debería ser: 'domestically'
# Predicción para 'pct'-'of'-'domestically': SIN PREDICCIÓN. Debería ser: 'produced'
# Predicción para 'of'-'domestically'-'produced': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'domestically'-'produced'-'exports': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'produced'-'exports'-'.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'exports'-'.'-'the': SIN PREDICCIÓN. Debería ser: 'australian'
# Predicción para '.'-'the'-'australian': SIN PREDICCIÓN. Debería ser: 'government'
# Predicción para 'the'-'australian'-'government': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para 'australian'-'government'-'is': SIN PREDICCIÓN. Debería ser: 'awaiting'
# Predicción para 'government'-'is'-'awaiting': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'is'-'awaiting'-'the': SIN PREDICCIÓN. Debería ser: 'outcome'
# Predicción para 'awaiting'-'the'-'outcome': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'outcome'-'of': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'outcome'-'of'-'trade': SIN PREDICCIÓN. Debería ser: 'talks'
# Predicción para 'of'-'trade'-'talks': SIN PREDICCIÓN. Debería ser: 'between'
# Predicción para 'trade'-'talks'-'between': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'talks'-'between'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'between'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'the'-'u.s.'-'and': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'u.s.'-'and'-'japan': SIN PREDICCIÓN. Debería ser: 'with'
# Predicción para 'and'-'japan'-'with': SIN PREDICCIÓN. Debería ser: 'interest'
# Predicción para 'japan'-'with'-'interest': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'with'-'interest'-'and': SIN PREDICCIÓN. Debería ser: 'concern'
# Predicción para 'interest'-'and'-'concern': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'and'-'concern'-',': SIN PREDICCIÓN. Debería ser: 'industry'
# Predicción para 'concern'-','-'industry': SIN PREDICCIÓN. Debería ser: 'minister'
# Predicción para ','-'industry'-'minister': SIN PREDICCIÓN. Debería ser: 'john'
# Predicción para 'industry'-'minister'-'john': SIN PREDICCIÓN. Debería ser: 'button'
# Predicción para 'minister'-'john'-'button': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'john'-'button'-'said': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'button'-'said'-'in': SIN PREDICCIÓN. Debería ser: 'canberra'
# Predicción para 'said'-'in'-'canberra': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'in'-'canberra'-'last': SIN PREDICCIÓN. Debería ser: 'friday'
# Predicción para 'canberra'-'last'-'friday': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'last'-'friday'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'friday'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'this'
# Predicción para '.'-'``'-'this': SIN PREDICCIÓN. Debería ser: 'kind'
# Predicción para '``'-'this'-'kind': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'this'-'kind'-'of': SIN PREDICCIÓN. Debería ser: 'deterioration'
# Predicción para 'kind'-'of'-'deterioration': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'of'-'deterioration'-'in': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'deterioration'-'in'-'trade': SIN PREDICCIÓN. Debería ser: 'relations'
# Predicción para 'in'-'trade'-'relations': SIN PREDICCIÓN. Debería ser: 'between'
# Predicción para 'trade'-'relations'-'between': SIN PREDICCIÓN. Debería ser: 'two'
# Predicción para 'relations'-'between'-'two': SIN PREDICCIÓN. Debería ser: 'countries'
# Predicción para 'between'-'two'-'countries': SIN PREDICCIÓN. Debería ser: 'which'
# Predicción para 'two'-'countries'-'which': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para 'countries'-'which'-'are': SIN PREDICCIÓN. Debería ser: 'major'
# Predicción para 'which'-'are'-'major': SIN PREDICCIÓN. Debería ser: 'trading'
# Predicción para 'are'-'major'-'trading': SIN PREDICCIÓN. Debería ser: 'partners'
# Predicción para 'major'-'trading'-'partners': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'trading'-'partners'-'of': SIN PREDICCIÓN. Debería ser: 'ours'
# Predicción para 'partners'-'of'-'ours': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para 'of'-'ours'-'is': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'ours'-'is'-'a': SIN PREDICCIÓN. Debería ser: 'very'
# Predicción para 'is'-'a'-'very': SIN PREDICCIÓN. Debería ser: 'serious'
# Predicción para 'a'-'very'-'serious': SIN PREDICCIÓN. Debería ser: 'matter'
# Predicción para 'very'-'serious'-'matter': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'serious'-'matter'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'matter'-','-'''': SIN PREDICCIÓN. Debería ser: 'button'
# Predicción para ','-''''-'button': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ''''-'button'-'said': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'button'-'said'-'.': SIN PREDICCIÓN. Debería ser: 'he'
# Predicción para 'said'-'.'-'he': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para '.'-'he'-'said': SIN PREDICCIÓN. Debería ser: 'australia'
# Predicción para 'he'-'said'-'australia': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'said'-'australia'-''s': SIN PREDICCIÓN. Debería ser: 'concerns'
# Predicción para 'australia'-''s'-'concerns': SIN PREDICCIÓN. Debería ser: 'centred'
# Predicción para ''s'-'concerns'-'centred': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'concerns'-'centred'-'on': SIN PREDICCIÓN. Debería ser: 'coal'
# Predicción para 'centred'-'on'-'coal': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'on'-'coal'-'and': SIN PREDICCIÓN. Debería ser: 'beef'
# Predicción para 'coal'-'and'-'beef': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'and'-'beef'-',': SIN PREDICCIÓN. Debería ser: 'australia'
# Predicción para 'beef'-','-'australia': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para ','-'australia'-''s': SIN PREDICCIÓN. Debería ser: 'two'
# Predicción para 'australia'-''s'-'two': SIN PREDICCIÓN. Debería ser: 'largest'
# Predicción para ''s'-'two'-'largest': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'two'-'largest'-'exports': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'largest'-'exports'-'to': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'exports'-'to'-'japan': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'to'-'japan'-'and': SIN PREDICCIÓN. Debería ser: 'also'
# Predicción para 'japan'-'and'-'also': SIN PREDICCIÓN. Debería ser: 'significant'
# Predicción para 'and'-'also'-'significant': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'also'-'significant'-'u.s.': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'significant'-'u.s.'-'exports': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'u.s.'-'exports'-'to': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para 'exports'-'to'-'that': SIN PREDICCIÓN. Debería ser: 'country'
# Predicción para 'to'-'that'-'country': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'that'-'country'-'.': SIN PREDICCIÓN. Debería ser: 'meanwhile'
# Predicción para 'country'-'.'-'meanwhile': SIN PREDICCIÓN. Debería ser: 'u.s.-japanese'
# Predicción para '.'-'meanwhile'-'u.s.-japanese': SIN PREDICCIÓN. Debería ser: 'diplomatic'
# Predicción para 'meanwhile'-'u.s.-japanese'-'diplomatic': SIN PREDICCIÓN. Debería ser: 'manoeuvres'
# Predicción para 'u.s.-japanese'-'diplomatic'-'manoeuvres': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'diplomatic'-'manoeuvres'-'to': SIN PREDICCIÓN. Debería ser: 'solve'
# Predicción para 'manoeuvres'-'to'-'solve': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'to'-'solve'-'the': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'solve'-'the'-'trade': SIN PREDICCIÓN. Debería ser: 'stand-off'
# Predicción para 'the'-'trade'-'stand-off': SIN PREDICCIÓN. Debería ser: 'continue'
# Predicción para 'trade'-'stand-off'-'continue': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'stand-off'-'continue'-'.': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'continue'-'.'-'japan': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para '.'-'japan'-''s': SIN PREDICCIÓN. Debería ser: 'ruling'
# Predicción para 'japan'-''s'-'ruling': SIN PREDICCIÓN. Debería ser: 'liberal'
# Predicción para ''s'-'ruling'-'liberal': SIN PREDICCIÓN. Debería ser: 'democratic'
# Predicción para 'ruling'-'liberal'-'democratic': SIN PREDICCIÓN. Debería ser: 'party'
# Predicción para 'liberal'-'democratic'-'party': SIN PREDICCIÓN. Debería ser: 'yesterday'
# Predicción para 'democratic'-'party'-'yesterday': SIN PREDICCIÓN. Debería ser: 'outlined'
# Predicción para 'party'-'yesterday'-'outlined': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'yesterday'-'outlined'-'a': SIN PREDICCIÓN. Debería ser: 'package'
# Predicción para 'outlined'-'a'-'package': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'a'-'package'-'of': SIN PREDICCIÓN. Debería ser: 'economic'
# Predicción para 'package'-'of'-'economic': SIN PREDICCIÓN. Debería ser: 'measures'
# Predicción para 'of'-'economic'-'measures': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'economic'-'measures'-'to': SIN PREDICCIÓN. Debería ser: 'boost'
# Predicción para 'measures'-'to'-'boost': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'to'-'boost'-'the': SIN PREDICCIÓN. Debería ser: 'japanese'
# Predicción para 'boost'-'the'-'japanese': SIN PREDICCIÓN. Debería ser: 'economy'
# Predicción para 'the'-'japanese'-'economy': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'japanese'-'economy'-'.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'economy'-'.'-'the': SIN PREDICCIÓN. Debería ser: 'measures'
# Predicción para '.'-'the'-'measures': SIN PREDICCIÓN. Debería ser: 'proposed'
# Predicción para 'the'-'measures'-'proposed': SIN PREDICCIÓN. Debería ser: 'include'
# Predicción para 'measures'-'proposed'-'include': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'proposed'-'include'-'a': SIN PREDICCIÓN. Debería ser: 'large'
# Predicción para 'include'-'a'-'large': SIN PREDICCIÓN. Debería ser: 'supplementary'
# Predicción para 'a'-'large'-'supplementary': SIN PREDICCIÓN. Debería ser: 'budget'
# Predicción para 'large'-'supplementary'-'budget': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'supplementary'-'budget'-'and': SIN PREDICCIÓN. Debería ser: 'record'
# Predicción para 'budget'-'and'-'record': SIN PREDICCIÓN. Debería ser: 'public'
# Predicción para 'and'-'record'-'public': SIN PREDICCIÓN. Debería ser: 'works'
# Predicción para 'record'-'public'-'works': SIN PREDICCIÓN. Debería ser: 'spending'
# Predicción para 'public'-'works'-'spending': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'works'-'spending'-'in': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'spending'-'in'-'the': SIN PREDICCIÓN. Debería ser: 'first'
# Predicción para 'in'-'the'-'first': SIN PREDICCIÓN. Debería ser: 'half'
# Predicción para 'the'-'first'-'half': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'first'-'half'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'half'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'financial'
# Predicción para 'of'-'the'-'financial': SIN PREDICCIÓN. Debería ser: 'year'
# Predicción para 'the'-'financial'-'year': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'financial'-'year'-'.': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'year'-'.'-'they': SIN PREDICCIÓN. Debería ser: 'also'
# Predicción para '.'-'they'-'also': SIN PREDICCIÓN. Debería ser: 'call'
# Predicción para 'they'-'also'-'call': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'also'-'call'-'for': SIN PREDICCIÓN. Debería ser: 'stepped-up'
# Predicción para 'call'-'for'-'stepped-up': SIN PREDICCIÓN. Debería ser: 'spending'
# Predicción para 'for'-'stepped-up'-'spending': SIN PREDICCIÓN. Debería ser: 'as'
# Predicción para 'stepped-up'-'spending'-'as': SIN PREDICCIÓN. Debería ser: 'an'
# Predicción para 'spending'-'as'-'an': SIN PREDICCIÓN. Debería ser: 'emergency'
# Predicción para 'as'-'an'-'emergency': SIN PREDICCIÓN. Debería ser: 'measure'
# Predicción para 'an'-'emergency'-'measure': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'emergency'-'measure'-'to': SIN PREDICCIÓN. Debería ser: 'stimulate'
# Predicción para 'measure'-'to'-'stimulate': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'to'-'stimulate'-'the': SIN PREDICCIÓN. Debería ser: 'economy'
# Predicción para 'stimulate'-'the'-'economy': SIN PREDICCIÓN. Debería ser: 'despite'
# Predicción para 'the'-'economy'-'despite': SIN PREDICCIÓN. Debería ser: 'prime'
# Predicción para 'economy'-'despite'-'prime': SIN PREDICCIÓN. Debería ser: 'minister'
# Predicción para 'despite'-'prime'-'minister': SIN PREDICCIÓN. Debería ser: 'yasuhiro'
# Predicción para 'prime'-'minister'-'yasuhiro': SIN PREDICCIÓN. Debería ser: 'nakasone'
# Predicción para 'minister'-'yasuhiro'-'nakasone': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'yasuhiro'-'nakasone'-''s': SIN PREDICCIÓN. Debería ser: 'avowed'
# Predicción para 'nakasone'-''s'-'avowed': SIN PREDICCIÓN. Debería ser: 'fiscal'
# Predicción para ''s'-'avowed'-'fiscal': SIN PREDICCIÓN. Debería ser: 'reform'
# Predicción para 'avowed'-'fiscal'-'reform': SIN PREDICCIÓN. Debería ser: 'program'
# Predicción para 'fiscal'-'reform'-'program': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'reform'-'program'-'.': SIN PREDICCIÓN. Debería ser: 'deputy'
# Predicción para 'program'-'.'-'deputy': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para '.'-'deputy'-'u.s.': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'deputy'-'u.s.'-'trade': SIN PREDICCIÓN. Debería ser: 'representative'
# Predicción para 'u.s.'-'trade'-'representative': SIN PREDICCIÓN. Debería ser: 'michael'
# Predicción para 'trade'-'representative'-'michael': SIN PREDICCIÓN. Debería ser: 'smith'
# Predicción para 'representative'-'michael'-'smith': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'michael'-'smith'-'and': SIN PREDICCIÓN. Debería ser: 'makoto'
# Predicción para 'smith'-'and'-'makoto': SIN PREDICCIÓN. Debería ser: 'kuroda'
# Predicción para 'and'-'makoto'-'kuroda': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'makoto'-'kuroda'-',': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'kuroda'-','-'japan': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para ','-'japan'-''s': SIN PREDICCIÓN. Debería ser: 'deputy'
# Predicción para 'japan'-''s'-'deputy': SIN PREDICCIÓN. Debería ser: 'minister'
# Predicción para ''s'-'deputy'-'minister': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'deputy'-'minister'-'of': SIN PREDICCIÓN. Debería ser: 'international'
# Predicción para 'minister'-'of'-'international': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'of'-'international'-'trade': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'international'-'trade'-'and': SIN PREDICCIÓN. Debería ser: 'industry'
# Predicción para 'trade'-'and'-'industry': SIN PREDICCIÓN. Debería ser: '('
# Predicción para 'and'-'industry'-'(': SIN PREDICCIÓN. Debería ser: 'miti'
# Predicción para 'industry'-'('-'miti': SIN PREDICCIÓN. Debería ser: ')'
# Predicción para '('-'miti'-')': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'miti'-')'-',': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para ')'-','-'are': SIN PREDICCIÓN. Debería ser: 'due'
# Predicción para ','-'are'-'due': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'are'-'due'-'to': SIN PREDICCIÓN. Debería ser: 'meet'
# Predicción para 'due'-'to'-'meet': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'to'-'meet'-'in': SIN PREDICCIÓN. Debería ser: 'washington'
# Predicción para 'meet'-'in'-'washington': SIN PREDICCIÓN. Debería ser: 'this'
# Predicción para 'in'-'washington'-'this': SIN PREDICCIÓN. Debería ser: 'week'
# Predicción para 'washington'-'this'-'week': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'this'-'week'-'in': SIN PREDICCIÓN. Debería ser: 'an'
# Predicción para 'week'-'in'-'an': SIN PREDICCIÓN. Debería ser: 'effort'
# Predicción para 'in'-'an'-'effort': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'an'-'effort'-'to': SIN PREDICCIÓN. Debería ser: 'end'
# Predicción para 'effort'-'to'-'end': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'to'-'end'-'the': SIN PREDICCIÓN. Debería ser: 'dispute'
#
# Aciertos: 0/807 = 0.00%

# %%
print("4-grama sin signos de puntuación:\n")
evaluar(text, bigram_model_without_punctuation, 4)
# Out:
# 4-grama sin signos de puntuación:
#
# Predicción para 'asian'-'exporters'-'fear': SIN PREDICCIÓN. Debería ser: 'damage'
# Predicción para 'exporters'-'fear'-'damage': SIN PREDICCIÓN. Debería ser: 'from'
# Predicción para 'fear'-'damage'-'from': SIN PREDICCIÓN. Debería ser: 'u.s.-japan'
# Predicción para 'damage'-'from'-'u.s.-japan': SIN PREDICCIÓN. Debería ser: 'rift'
# Predicción para 'from'-'u.s.-japan'-'rift': SIN PREDICCIÓN. Debería ser: 'mounting'
# Predicción para 'u.s.-japan'-'rift'-'mounting': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'rift'-'mounting'-'trade': SIN PREDICCIÓN. Debería ser: 'friction'
# Predicción para 'mounting'-'trade'-'friction': SIN PREDICCIÓN. Debería ser: 'between'
# Predicción para 'trade'-'friction'-'between': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'friction'-'between'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'between'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'the'-'u.s.'-'and': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'u.s.'-'and'-'japan': SIN PREDICCIÓN. Debería ser: 'has'
# Predicción para 'and'-'japan'-'has': SIN PREDICCIÓN. Debería ser: 'raised'
# Predicción para 'japan'-'has'-'raised': SIN PREDICCIÓN. Debería ser: 'fears'
# Predicción para 'has'-'raised'-'fears': SIN PREDICCIÓN. Debería ser: 'among'
# Predicción para 'raised'-'fears'-'among': SIN PREDICCIÓN. Debería ser: 'many'
# Predicción para 'fears'-'among'-'many': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'among'-'many'-'of': SIN PREDICCIÓN. Debería ser: 'asia'
# Predicción para 'many'-'of'-'asia': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'of'-'asia'-''s': SIN PREDICCIÓN. Debería ser: 'exporting'
# Predicción para 'asia'-''s'-'exporting': SIN PREDICCIÓN. Debería ser: 'nations'
# Predicción para ''s'-'exporting'-'nations': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para 'exporting'-'nations'-'that': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'nations'-'that'-'the': SIN PREDICCIÓN. Debería ser: 'row'
# Predicción para 'that'-'the'-'row': SIN PREDICCIÓN. Debería ser: 'could'
# Predicción para 'the'-'row'-'could': SIN PREDICCIÓN. Debería ser: 'inflict'
# Predicción para 'row'-'could'-'inflict': SIN PREDICCIÓN. Debería ser: 'far-reaching'
# Predicción para 'could'-'inflict'-'far-reaching': SIN PREDICCIÓN. Debería ser: 'economic'
# Predicción para 'inflict'-'far-reaching'-'economic': SIN PREDICCIÓN. Debería ser: 'damage'
# Predicción para 'far-reaching'-'economic'-'damage': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'economic'-'damage'-',': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'damage'-','-'businessmen': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para ','-'businessmen'-'and': SIN PREDICCIÓN. Debería ser: 'officials'
# Predicción para 'businessmen'-'and'-'officials': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'and'-'officials'-'said': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'officials'-'said'-'.': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'said'-'.'-'they': SIN PREDICCIÓN. Debería ser: 'told'
# Predicción para '.'-'they'-'told': SIN PREDICCIÓN. Debería ser: 'reuter'
# Predicción para 'they'-'told'-'reuter': SIN PREDICCIÓN. Debería ser: 'correspondents'
# Predicción para 'told'-'reuter'-'correspondents': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'reuter'-'correspondents'-'in': SIN PREDICCIÓN. Debería ser: 'asian'
# Predicción para 'correspondents'-'in'-'asian': SIN PREDICCIÓN. Debería ser: 'capitals'
# Predicción para 'in'-'asian'-'capitals': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'asian'-'capitals'-'a': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'capitals'-'a'-'u.s.': SIN PREDICCIÓN. Debería ser: 'move'
# Predicción para 'a'-'u.s.'-'move': SIN PREDICCIÓN. Debería ser: 'against'
# Predicción para 'u.s.'-'move'-'against': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'move'-'against'-'japan': SIN PREDICCIÓN. Debería ser: 'might'
# Predicción para 'against'-'japan'-'might': SIN PREDICCIÓN. Debería ser: 'boost'
# Predicción para 'japan'-'might'-'boost': SIN PREDICCIÓN. Debería ser: 'protectionist'
# Predicción para 'might'-'boost'-'protectionist': SIN PREDICCIÓN. Debería ser: 'sentiment'
# Predicción para 'boost'-'protectionist'-'sentiment': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'protectionist'-'sentiment'-'in': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'sentiment'-'in'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'in'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'the'-'u.s.'-'and': SIN PREDICCIÓN. Debería ser: 'lead'
# Predicción para 'u.s.'-'and'-'lead': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'and'-'lead'-'to': SIN PREDICCIÓN. Debería ser: 'curbs'
# Predicción para 'lead'-'to'-'curbs': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'to'-'curbs'-'on': SIN PREDICCIÓN. Debería ser: 'american'
# Predicción para 'curbs'-'on'-'american': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'on'-'american'-'imports': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'american'-'imports'-'of': SIN PREDICCIÓN. Debería ser: 'their'
# Predicción para 'imports'-'of'-'their': SIN PREDICCIÓN. Debería ser: 'products'
# Predicción para 'of'-'their'-'products': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'their'-'products'-'.': SIN PREDICCIÓN. Debería ser: 'but'
# Predicción para 'products'-'.'-'but': SIN PREDICCIÓN. Debería ser: 'some'
# Predicción para '.'-'but'-'some': SIN PREDICCIÓN. Debería ser: 'exporters'
# Predicción para 'but'-'some'-'exporters': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'some'-'exporters'-'said': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para 'exporters'-'said'-'that': SIN PREDICCIÓN. Debería ser: 'while'
# Predicción para 'said'-'that'-'while': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'that'-'while'-'the': SIN PREDICCIÓN. Debería ser: 'conflict'
# Predicción para 'while'-'the'-'conflict': SIN PREDICCIÓN. Debería ser: 'would'
# Predicción para 'the'-'conflict'-'would': SIN PREDICCIÓN. Debería ser: 'hurt'
# Predicción para 'conflict'-'would'-'hurt': SIN PREDICCIÓN. Debería ser: 'them'
# Predicción para 'would'-'hurt'-'them': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'hurt'-'them'-'in': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'them'-'in'-'the': SIN PREDICCIÓN. Debería ser: 'long-run'
# Predicción para 'in'-'the'-'long-run': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'the'-'long-run'-',': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'long-run'-','-'in': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para ','-'in'-'the': SIN PREDICCIÓN. Debería ser: 'short-term'
# Predicción para 'in'-'the'-'short-term': SIN PREDICCIÓN. Debería ser: 'tokyo'
# Predicción para 'the'-'short-term'-'tokyo': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'short-term'-'tokyo'-''s': SIN PREDICCIÓN. Debería ser: 'loss'
# Predicción para 'tokyo'-''s'-'loss': SIN PREDICCIÓN. Debería ser: 'might'
# Predicción para ''s'-'loss'-'might': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'loss'-'might'-'be': SIN PREDICCIÓN. Debería ser: 'their'
# Predicción para 'might'-'be'-'their': SIN PREDICCIÓN. Debería ser: 'gain'
# Predicción para 'be'-'their'-'gain': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'their'-'gain'-'.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'gain'-'.'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para '.'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'has'
# Predicción para 'the'-'u.s.'-'has': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'u.s.'-'has'-'said': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'has'-'said'-'it': SIN PREDICCIÓN. Debería ser: 'will'
# Predicción para 'said'-'it'-'will': SIN PREDICCIÓN. Debería ser: 'impose'
# Predicción para 'it'-'will'-'impose': SIN PREDICCIÓN. Debería ser: '300'
# Predicción para 'will'-'impose'-'300': SIN PREDICCIÓN. Debería ser: 'mln'
# Predicción para 'impose'-'300'-'mln': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '300'-'mln'-'dlrs': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'mln'-'dlrs'-'of': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'dlrs'-'of'-'tariffs': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'of'-'tariffs'-'on': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'tariffs'-'on'-'imports': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'on'-'imports'-'of': SIN PREDICCIÓN. Debería ser: 'japanese'
# Predicción para 'imports'-'of'-'japanese': SIN PREDICCIÓN. Debería ser: 'electronics'
# Predicción para 'of'-'japanese'-'electronics': SIN PREDICCIÓN. Debería ser: 'goods'
# Predicción para 'japanese'-'electronics'-'goods': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'electronics'-'goods'-'on': SIN PREDICCIÓN. Debería ser: 'april'
# Predicción para 'goods'-'on'-'april': SIN PREDICCIÓN. Debería ser: '17'
# Predicción para 'on'-'april'-'17': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'april'-'17'-',': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para '17'-','-'in': SIN PREDICCIÓN. Debería ser: 'retaliation'
# Predicción para ','-'in'-'retaliation': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'in'-'retaliation'-'for': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'retaliation'-'for'-'japan': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'for'-'japan'-''s': SIN PREDICCIÓN. Debería ser: 'alleged'
# Predicción para 'japan'-''s'-'alleged': SIN PREDICCIÓN. Debería ser: 'failure'
# Predicción para ''s'-'alleged'-'failure': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'alleged'-'failure'-'to': SIN PREDICCIÓN. Debería ser: 'stick'
# Predicción para 'failure'-'to'-'stick': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'to'-'stick'-'to': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'stick'-'to'-'a': SIN PREDICCIÓN. Debería ser: 'pact'
# Predicción para 'to'-'a'-'pact': SIN PREDICCIÓN. Debería ser: 'not'
# Predicción para 'a'-'pact'-'not': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'pact'-'not'-'to': SIN PREDICCIÓN. Debería ser: 'sell'
# Predicción para 'not'-'to'-'sell': SIN PREDICCIÓN. Debería ser: 'semiconductors'
# Predicción para 'to'-'sell'-'semiconductors': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'sell'-'semiconductors'-'on': SIN PREDICCIÓN. Debería ser: 'world'
# Predicción para 'semiconductors'-'on'-'world': SIN PREDICCIÓN. Debería ser: 'markets'
# Predicción para 'on'-'world'-'markets': SIN PREDICCIÓN. Debería ser: 'at'
# Predicción para 'world'-'markets'-'at': SIN PREDICCIÓN. Debería ser: 'below'
# Predicción para 'markets'-'at'-'below': SIN PREDICCIÓN. Debería ser: 'cost'
# Predicción para 'at'-'below'-'cost': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'below'-'cost'-'.': SIN PREDICCIÓN. Debería ser: 'unofficial'
# Predicción para 'cost'-'.'-'unofficial': SIN PREDICCIÓN. Debería ser: 'japanese'
# Predicción para '.'-'unofficial'-'japanese': SIN PREDICCIÓN. Debería ser: 'estimates'
# Predicción para 'unofficial'-'japanese'-'estimates': SIN PREDICCIÓN. Debería ser: 'put'
# Predicción para 'japanese'-'estimates'-'put': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'estimates'-'put'-'the': SIN PREDICCIÓN. Debería ser: 'impact'
# Predicción para 'put'-'the'-'impact': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'impact'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'impact'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'of'-'the'-'tariffs': SIN PREDICCIÓN. Debería ser: 'at'
# Predicción para 'the'-'tariffs'-'at': SIN PREDICCIÓN. Debería ser: '10'
# Predicción para 'tariffs'-'at'-'10': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'at'-'10'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '10'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'billion'-'dlrs'-'and': SIN PREDICCIÓN. Debería ser: 'spokesmen'
# Predicción para 'dlrs'-'and'-'spokesmen': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'and'-'spokesmen'-'for': SIN PREDICCIÓN. Debería ser: 'major'
# Predicción para 'spokesmen'-'for'-'major': SIN PREDICCIÓN. Debería ser: 'electronics'
# Predicción para 'for'-'major'-'electronics': SIN PREDICCIÓN. Debería ser: 'firms'
# Predicción para 'major'-'electronics'-'firms': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'electronics'-'firms'-'said': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'firms'-'said'-'they': SIN PREDICCIÓN. Debería ser: 'would'
# Predicción para 'said'-'they'-'would': SIN PREDICCIÓN. Debería ser: 'virtually'
# Predicción para 'they'-'would'-'virtually': SIN PREDICCIÓN. Debería ser: 'halt'
# Predicción para 'would'-'virtually'-'halt': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'virtually'-'halt'-'exports': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'halt'-'exports'-'of': SIN PREDICCIÓN. Debería ser: 'products'
# Predicción para 'exports'-'of'-'products': SIN PREDICCIÓN. Debería ser: 'hit'
# Predicción para 'of'-'products'-'hit': SIN PREDICCIÓN. Debería ser: 'by'
# Predicción para 'products'-'hit'-'by': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'hit'-'by'-'the': SIN PREDICCIÓN. Debería ser: 'new'
# Predicción para 'by'-'the'-'new': SIN PREDICCIÓN. Debería ser: 'taxes'
# Predicción para 'the'-'new'-'taxes': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'new'-'taxes'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'taxes'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'we'
# Predicción para '.'-'``'-'we': SIN PREDICCIÓN. Debería ser: 'would'
# Predicción para '``'-'we'-'would': SIN PREDICCIÓN. Debería ser: 'n't'
# Predicción para 'we'-'would'-'n't': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'would'-'n't'-'be': SIN PREDICCIÓN. Debería ser: 'able'
# Predicción para 'n't'-'be'-'able': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'be'-'able'-'to': SIN PREDICCIÓN. Debería ser: 'do'
# Predicción para 'able'-'to'-'do': SIN PREDICCIÓN. Debería ser: 'business'
# Predicción para 'to'-'do'-'business': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'do'-'business'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'business'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para ''''-'said'-'a': SIN PREDICCIÓN. Debería ser: 'spokesman'
# Predicción para 'said'-'a'-'spokesman': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'a'-'spokesman'-'for': SIN PREDICCIÓN. Debería ser: 'leading'
# Predicción para 'spokesman'-'for'-'leading': SIN PREDICCIÓN. Debería ser: 'japanese'
# Predicción para 'for'-'leading'-'japanese': SIN PREDICCIÓN. Debería ser: 'electronics'
# Predicción para 'leading'-'japanese'-'electronics': SIN PREDICCIÓN. Debería ser: 'firm'
# Predicción para 'japanese'-'electronics'-'firm': SIN PREDICCIÓN. Debería ser: 'matsushita'
# Predicción para 'electronics'-'firm'-'matsushita': SIN PREDICCIÓN. Debería ser: 'electric'
# Predicción para 'firm'-'matsushita'-'electric': SIN PREDICCIÓN. Debería ser: 'industrial'
# Predicción para 'matsushita'-'electric'-'industrial': SIN PREDICCIÓN. Debería ser: 'co'
# Predicción para 'electric'-'industrial'-'co': SIN PREDICCIÓN. Debería ser: 'ltd'
# Predicción para 'industrial'-'co'-'ltd': SIN PREDICCIÓN. Debería ser: '&'
# Predicción para 'co'-'ltd'-'&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'ltd'-'&'-'lt': SIN PREDICCIÓN. Debería ser: ';'
# Predicción para '&'-'lt'-';': SIN PREDICCIÓN. Debería ser: 'mc.t'
# Predicción para 'lt'-';'-'mc.t': SIN PREDICCIÓN. Debería ser: '>'
# Predicción para ';'-'mc.t'-'>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'mc.t'-'>'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '>'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'if'
# Predicción para '.'-'``'-'if': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para '``'-'if'-'the': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'if'-'the'-'tariffs': SIN PREDICCIÓN. Debería ser: 'remain'
# Predicción para 'the'-'tariffs'-'remain': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'tariffs'-'remain'-'in': SIN PREDICCIÓN. Debería ser: 'place'
# Predicción para 'remain'-'in'-'place': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'in'-'place'-'for': SIN PREDICCIÓN. Debería ser: 'any'
# Predicción para 'place'-'for'-'any': SIN PREDICCIÓN. Debería ser: 'length'
# Predicción para 'for'-'any'-'length': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'any'-'length'-'of': SIN PREDICCIÓN. Debería ser: 'time'
# Predicción para 'length'-'of'-'time': SIN PREDICCIÓN. Debería ser: 'beyond'
# Predicción para 'of'-'time'-'beyond': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'time'-'beyond'-'a': SIN PREDICCIÓN. Debería ser: 'few'
# Predicción para 'beyond'-'a'-'few': SIN PREDICCIÓN. Debería ser: 'months'
# Predicción para 'a'-'few'-'months': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'few'-'months'-'it': SIN PREDICCIÓN. Debería ser: 'will'
# Predicción para 'months'-'it'-'will': SIN PREDICCIÓN. Debería ser: 'mean'
# Predicción para 'it'-'will'-'mean': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'will'-'mean'-'the': SIN PREDICCIÓN. Debería ser: 'complete'
# Predicción para 'mean'-'the'-'complete': SIN PREDICCIÓN. Debería ser: 'erosion'
# Predicción para 'the'-'complete'-'erosion': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'complete'-'erosion'-'of': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'erosion'-'of'-'exports': SIN PREDICCIÓN. Debería ser: '('
# Predicción para 'of'-'exports'-'(': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'exports'-'('-'of': SIN PREDICCIÓN. Debería ser: 'goods'
# Predicción para '('-'of'-'goods': SIN PREDICCIÓN. Debería ser: 'subject'
# Predicción para 'of'-'goods'-'subject': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'goods'-'subject'-'to': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'subject'-'to'-'tariffs': SIN PREDICCIÓN. Debería ser: ')'
# Predicción para 'to'-'tariffs'-')': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'tariffs'-')'-'to': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para ')'-'to'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'to'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'the'-'u.s.'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'u.s.'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'tom'
# Predicción para ''''-'said'-'tom': SIN PREDICCIÓN. Debería ser: 'murtha'
# Predicción para 'said'-'tom'-'murtha': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'tom'-'murtha'-',': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'murtha'-','-'a': SIN PREDICCIÓN. Debería ser: 'stock'
# Predicción para ','-'a'-'stock': SIN PREDICCIÓN. Debería ser: 'analyst'
# Predicción para 'a'-'stock'-'analyst': SIN PREDICCIÓN. Debería ser: 'at'
# Predicción para 'stock'-'analyst'-'at': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'analyst'-'at'-'the': SIN PREDICCIÓN. Debería ser: 'tokyo'
# Predicción para 'at'-'the'-'tokyo': SIN PREDICCIÓN. Debería ser: 'office'
# Predicción para 'the'-'tokyo'-'office': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'tokyo'-'office'-'of': SIN PREDICCIÓN. Debería ser: 'broker'
# Predicción para 'office'-'of'-'broker': SIN PREDICCIÓN. Debería ser: '&'
# Predicción para 'of'-'broker'-'&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'broker'-'&'-'lt': SIN PREDICCIÓN. Debería ser: ';'
# Predicción para '&'-'lt'-';': SIN PREDICCIÓN. Debería ser: 'james'
# Predicción para 'lt'-';'-'james': SIN PREDICCIÓN. Debería ser: 'capel'
# Predicción para ';'-'james'-'capel': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'james'-'capel'-'and': SIN PREDICCIÓN. Debería ser: 'co'
# Predicción para 'capel'-'and'-'co': SIN PREDICCIÓN. Debería ser: '>'
# Predicción para 'and'-'co'-'>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'co'-'>'-'.': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para '>'-'.'-'in': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para '.'-'in'-'taiwan': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'in'-'taiwan'-',': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'taiwan'-','-'businessmen': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para ','-'businessmen'-'and': SIN PREDICCIÓN. Debería ser: 'officials'
# Predicción para 'businessmen'-'and'-'officials': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para 'and'-'officials'-'are': SIN PREDICCIÓN. Debería ser: 'also'
# Predicción para 'officials'-'are'-'also': SIN PREDICCIÓN. Debería ser: 'worried'
# Predicción para 'are'-'also'-'worried': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'also'-'worried'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'worried'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'we'
# Predicción para '.'-'``'-'we': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para '``'-'we'-'are': SIN PREDICCIÓN. Debería ser: 'aware'
# Predicción para 'we'-'are'-'aware': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'are'-'aware'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'aware'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'seriousness'
# Predicción para 'of'-'the'-'seriousness': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'seriousness'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'seriousness'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'of'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'threat'
# Predicción para 'the'-'u.s.'-'threat': SIN PREDICCIÓN. Debería ser: 'against'
# Predicción para 'u.s.'-'threat'-'against': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'threat'-'against'-'japan': SIN PREDICCIÓN. Debería ser: 'because'
# Predicción para 'against'-'japan'-'because': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'japan'-'because'-'it': SIN PREDICCIÓN. Debería ser: 'serves'
# Predicción para 'because'-'it'-'serves': SIN PREDICCIÓN. Debería ser: 'as'
# Predicción para 'it'-'serves'-'as': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'serves'-'as'-'a': SIN PREDICCIÓN. Debería ser: 'warning'
# Predicción para 'as'-'a'-'warning': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'a'-'warning'-'to': SIN PREDICCIÓN. Debería ser: 'us'
# Predicción para 'warning'-'to'-'us': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'to'-'us'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'us'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para ''''-'said'-'a': SIN PREDICCIÓN. Debería ser: 'senior'
# Predicción para 'said'-'a'-'senior': SIN PREDICCIÓN. Debería ser: 'taiwanese'
# Predicción para 'a'-'senior'-'taiwanese': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'senior'-'taiwanese'-'trade': SIN PREDICCIÓN. Debería ser: 'official'
# Predicción para 'taiwanese'-'trade'-'official': SIN PREDICCIÓN. Debería ser: 'who'
# Predicción para 'trade'-'official'-'who': SIN PREDICCIÓN. Debería ser: 'asked'
# Predicción para 'official'-'who'-'asked': SIN PREDICCIÓN. Debería ser: 'not'
# Predicción para 'who'-'asked'-'not': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'asked'-'not'-'to': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'not'-'to'-'be': SIN PREDICCIÓN. Debería ser: 'named'
# Predicción para 'to'-'be'-'named': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'be'-'named'-'.': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'named'-'.'-'taiwan': SIN PREDICCIÓN. Debería ser: 'had'
# Predicción para '.'-'taiwan'-'had': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'taiwan'-'had'-'a': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'had'-'a'-'trade': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'a'-'trade'-'trade': SIN PREDICCIÓN. Debería ser: 'surplus'
# Predicción para 'trade'-'trade'-'surplus': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'trade'-'surplus'-'of': SIN PREDICCIÓN. Debería ser: '15.6'
# Predicción para 'surplus'-'of'-'15.6': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'of'-'15.6'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '15.6'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'billion'-'dlrs'-'last': SIN PREDICCIÓN. Debería ser: 'year'
# Predicción para 'dlrs'-'last'-'year': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'last'-'year'-',': SIN PREDICCIÓN. Debería ser: '95'
# Predicción para 'year'-','-'95': SIN PREDICCIÓN. Debería ser: 'pct'
# Predicción para ','-'95'-'pct': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para '95'-'pct'-'of': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'pct'-'of'-'it': SIN PREDICCIÓN. Debería ser: 'with'
# Predicción para 'of'-'it'-'with': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'it'-'with'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'with'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the'-'u.s.'-'the': SIN PREDICCIÓN. Debería ser: 'surplus'
# Predicción para 'u.s.'-'the'-'surplus': SIN PREDICCIÓN. Debería ser: 'helped'
# Predicción para 'the'-'surplus'-'helped': SIN PREDICCIÓN. Debería ser: 'swell'
# Predicción para 'surplus'-'helped'-'swell': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'helped'-'swell'-'taiwan': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'swell'-'taiwan'-''s': SIN PREDICCIÓN. Debería ser: 'foreign'
# Predicción para 'taiwan'-''s'-'foreign': SIN PREDICCIÓN. Debería ser: 'exchange'
# Predicción para ''s'-'foreign'-'exchange': SIN PREDICCIÓN. Debería ser: 'reserves'
# Predicción para 'foreign'-'exchange'-'reserves': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'exchange'-'reserves'-'to': SIN PREDICCIÓN. Debería ser: '53'
# Predicción para 'reserves'-'to'-'53': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'to'-'53'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '53'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'billion'-'dlrs'-',': SIN PREDICCIÓN. Debería ser: 'among'
# Predicción para 'dlrs'-','-'among': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para ','-'among'-'the': SIN PREDICCIÓN. Debería ser: 'world'
# Predicción para 'among'-'the'-'world': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'the'-'world'-''s': SIN PREDICCIÓN. Debería ser: 'largest'
# Predicción para 'world'-''s'-'largest': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para ''s'-'largest'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'largest'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'we'
# Predicción para '.'-'``'-'we': SIN PREDICCIÓN. Debería ser: 'must'
# Predicción para '``'-'we'-'must': SIN PREDICCIÓN. Debería ser: 'quickly'
# Predicción para 'we'-'must'-'quickly': SIN PREDICCIÓN. Debería ser: 'open'
# Predicción para 'must'-'quickly'-'open': SIN PREDICCIÓN. Debería ser: 'our'
# Predicción para 'quickly'-'open'-'our': SIN PREDICCIÓN. Debería ser: 'markets'
# Predicción para 'open'-'our'-'markets': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'our'-'markets'-',': SIN PREDICCIÓN. Debería ser: 'remove'
# Predicción para 'markets'-','-'remove': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para ','-'remove'-'trade': SIN PREDICCIÓN. Debería ser: 'barriers'
# Predicción para 'remove'-'trade'-'barriers': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'trade'-'barriers'-'and': SIN PREDICCIÓN. Debería ser: 'cut'
# Predicción para 'barriers'-'and'-'cut': SIN PREDICCIÓN. Debería ser: 'import'
# Predicción para 'and'-'cut'-'import': SIN PREDICCIÓN. Debería ser: 'tariffs'
# Predicción para 'cut'-'import'-'tariffs': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'import'-'tariffs'-'to': SIN PREDICCIÓN. Debería ser: 'allow'
# Predicción para 'tariffs'-'to'-'allow': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'to'-'allow'-'imports': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'allow'-'imports'-'of': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'imports'-'of'-'u.s.': SIN PREDICCIÓN. Debería ser: 'products'
# Predicción para 'of'-'u.s.'-'products': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'u.s.'-'products'-',': SIN PREDICCIÓN. Debería ser: 'if'
# Predicción para 'products'-','-'if': SIN PREDICCIÓN. Debería ser: 'we'
# Predicción para ','-'if'-'we': SIN PREDICCIÓN. Debería ser: 'want'
# Predicción para 'if'-'we'-'want': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'we'-'want'-'to': SIN PREDICCIÓN. Debería ser: 'defuse'
# Predicción para 'want'-'to'-'defuse': SIN PREDICCIÓN. Debería ser: 'problems'
# Predicción para 'to'-'defuse'-'problems': SIN PREDICCIÓN. Debería ser: 'from'
# Predicción para 'defuse'-'problems'-'from': SIN PREDICCIÓN. Debería ser: 'possible'
# Predicción para 'problems'-'from'-'possible': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'from'-'possible'-'u.s.': SIN PREDICCIÓN. Debería ser: 'retaliation'
# Predicción para 'possible'-'u.s.'-'retaliation': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'u.s.'-'retaliation'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'retaliation'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'paul'
# Predicción para ''''-'said'-'paul': SIN PREDICCIÓN. Debería ser: 'sheen'
# Predicción para 'said'-'paul'-'sheen': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'paul'-'sheen'-',': SIN PREDICCIÓN. Debería ser: 'chairman'
# Predicción para 'sheen'-','-'chairman': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para ','-'chairman'-'of': SIN PREDICCIÓN. Debería ser: 'textile'
# Predicción para 'chairman'-'of'-'textile': SIN PREDICCIÓN. Debería ser: 'exporters'
# Predicción para 'of'-'textile'-'exporters': SIN PREDICCIÓN. Debería ser: '&'
# Predicción para 'textile'-'exporters'-'&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'exporters'-'&'-'lt': SIN PREDICCIÓN. Debería ser: ';'
# Predicción para '&'-'lt'-';': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'lt'-';'-'taiwan': SIN PREDICCIÓN. Debería ser: 'safe'
# Predicción para ';'-'taiwan'-'safe': SIN PREDICCIÓN. Debería ser: 'group'
# Predicción para 'taiwan'-'safe'-'group': SIN PREDICCIÓN. Debería ser: '>'
# Predicción para 'safe'-'group'-'>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'group'-'>'-'.': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para '>'-'.'-'a': SIN PREDICCIÓN. Debería ser: 'senior'
# Predicción para '.'-'a'-'senior': SIN PREDICCIÓN. Debería ser: 'official'
# Predicción para 'a'-'senior'-'official': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'senior'-'official'-'of': SIN PREDICCIÓN. Debería ser: 'south'
# Predicción para 'official'-'of'-'south': SIN PREDICCIÓN. Debería ser: 'korea'
# Predicción para 'of'-'south'-'korea': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'south'-'korea'-''s': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'korea'-''s'-'trade': SIN PREDICCIÓN. Debería ser: 'promotion'
# Predicción para ''s'-'trade'-'promotion': SIN PREDICCIÓN. Debería ser: 'association'
# Predicción para 'trade'-'promotion'-'association': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'promotion'-'association'-'said': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'association'-'said'-'the': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'said'-'the'-'trade': SIN PREDICCIÓN. Debería ser: 'dispute'
# Predicción para 'the'-'trade'-'dispute': SIN PREDICCIÓN. Debería ser: 'between'
# Predicción para 'trade'-'dispute'-'between': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'dispute'-'between'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'between'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'the'-'u.s.'-'and': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'u.s.'-'and'-'japan': SIN PREDICCIÓN. Debería ser: 'might'
# Predicción para 'and'-'japan'-'might': SIN PREDICCIÓN. Debería ser: 'also'
# Predicción para 'japan'-'might'-'also': SIN PREDICCIÓN. Debería ser: 'lead'
# Predicción para 'might'-'also'-'lead': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'also'-'lead'-'to': SIN PREDICCIÓN. Debería ser: 'pressure'
# Predicción para 'lead'-'to'-'pressure': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'to'-'pressure'-'on': SIN PREDICCIÓN. Debería ser: 'south'
# Predicción para 'pressure'-'on'-'south': SIN PREDICCIÓN. Debería ser: 'korea'
# Predicción para 'on'-'south'-'korea': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'south'-'korea'-',': SIN PREDICCIÓN. Debería ser: 'whose'
# Predicción para 'korea'-','-'whose': SIN PREDICCIÓN. Debería ser: 'chief'
# Predicción para ','-'whose'-'chief': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'whose'-'chief'-'exports': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para 'chief'-'exports'-'are': SIN PREDICCIÓN. Debería ser: 'similar'
# Predicción para 'exports'-'are'-'similar': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'are'-'similar'-'to': SIN PREDICCIÓN. Debería ser: 'those'
# Predicción para 'similar'-'to'-'those': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'to'-'those'-'of': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'those'-'of'-'japan': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'of'-'japan'-'.': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'japan'-'.'-'last': SIN PREDICCIÓN. Debería ser: 'year'
# Predicción para '.'-'last'-'year': SIN PREDICCIÓN. Debería ser: 'south'
# Predicción para 'last'-'year'-'south': SIN PREDICCIÓN. Debería ser: 'korea'
# Predicción para 'year'-'south'-'korea': SIN PREDICCIÓN. Debería ser: 'had'
# Predicción para 'south'-'korea'-'had': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'korea'-'had'-'a': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'had'-'a'-'trade': SIN PREDICCIÓN. Debería ser: 'surplus'
# Predicción para 'a'-'trade'-'surplus': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'trade'-'surplus'-'of': SIN PREDICCIÓN. Debería ser: '7.1'
# Predicción para 'surplus'-'of'-'7.1': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'of'-'7.1'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '7.1'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: 'with'
# Predicción para 'billion'-'dlrs'-'with': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'dlrs'-'with'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'with'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'the'-'u.s.'-',': SIN PREDICCIÓN. Debería ser: 'up'
# Predicción para 'u.s.'-','-'up': SIN PREDICCIÓN. Debería ser: 'from'
# Predicción para ','-'up'-'from': SIN PREDICCIÓN. Debería ser: '4.9'
# Predicción para 'up'-'from'-'4.9': SIN PREDICCIÓN. Debería ser: 'billion'
# Predicción para 'from'-'4.9'-'billion': SIN PREDICCIÓN. Debería ser: 'dlrs'
# Predicción para '4.9'-'billion'-'dlrs': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'billion'-'dlrs'-'in': SIN PREDICCIÓN. Debería ser: '1985.'
# Predicción para 'dlrs'-'in'-'1985.': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'in'-'1985.'-'in': SIN PREDICCIÓN. Debería ser: 'malaysia'
# Predicción para '1985.'-'in'-'malaysia': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'in'-'malaysia'-',': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'malaysia'-','-'trade': SIN PREDICCIÓN. Debería ser: 'officers'
# Predicción para ','-'trade'-'officers': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'trade'-'officers'-'and': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'officers'-'and'-'businessmen': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'and'-'businessmen'-'said': SIN PREDICCIÓN. Debería ser: 'tough'
# Predicción para 'businessmen'-'said'-'tough': SIN PREDICCIÓN. Debería ser: 'curbs'
# Predicción para 'said'-'tough'-'curbs': SIN PREDICCIÓN. Debería ser: 'against'
# Predicción para 'tough'-'curbs'-'against': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'curbs'-'against'-'japan': SIN PREDICCIÓN. Debería ser: 'might'
# Predicción para 'against'-'japan'-'might': SIN PREDICCIÓN. Debería ser: 'allow'
# Predicción para 'japan'-'might'-'allow': SIN PREDICCIÓN. Debería ser: 'hard-hit'
# Predicción para 'might'-'allow'-'hard-hit': SIN PREDICCIÓN. Debería ser: 'producers'
# Predicción para 'allow'-'hard-hit'-'producers': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'hard-hit'-'producers'-'of': SIN PREDICCIÓN. Debería ser: 'semiconductors'
# Predicción para 'producers'-'of'-'semiconductors': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'of'-'semiconductors'-'in': SIN PREDICCIÓN. Debería ser: 'third'
# Predicción para 'semiconductors'-'in'-'third': SIN PREDICCIÓN. Debería ser: 'countries'
# Predicción para 'in'-'third'-'countries': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'third'-'countries'-'to': SIN PREDICCIÓN. Debería ser: 'expand'
# Predicción para 'countries'-'to'-'expand': SIN PREDICCIÓN. Debería ser: 'their'
# Predicción para 'to'-'expand'-'their': SIN PREDICCIÓN. Debería ser: 'sales'
# Predicción para 'expand'-'their'-'sales': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'their'-'sales'-'to': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'sales'-'to'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'to'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'the'-'u.s.'-'in': SIN PREDICCIÓN. Debería ser: 'hong'
# Predicción para 'u.s.'-'in'-'hong': SIN PREDICCIÓN. Debería ser: 'kong'
# Predicción para 'in'-'hong'-'kong': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'hong'-'kong'-',': SIN PREDICCIÓN. Debería ser: 'where'
# Predicción para 'kong'-','-'where': SIN PREDICCIÓN. Debería ser: 'newspapers'
# Predicción para ','-'where'-'newspapers': SIN PREDICCIÓN. Debería ser: 'have'
# Predicción para 'where'-'newspapers'-'have': SIN PREDICCIÓN. Debería ser: 'alleged'
# Predicción para 'newspapers'-'have'-'alleged': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'have'-'alleged'-'japan': SIN PREDICCIÓN. Debería ser: 'has'
# Predicción para 'alleged'-'japan'-'has': SIN PREDICCIÓN. Debería ser: 'been'
# Predicción para 'japan'-'has'-'been': SIN PREDICCIÓN. Debería ser: 'selling'
# Predicción para 'has'-'been'-'selling': SIN PREDICCIÓN. Debería ser: 'below-cost'
# Predicción para 'been'-'selling'-'below-cost': SIN PREDICCIÓN. Debería ser: 'semiconductors'
# Predicción para 'selling'-'below-cost'-'semiconductors': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'below-cost'-'semiconductors'-',': SIN PREDICCIÓN. Debería ser: 'some'
# Predicción para 'semiconductors'-','-'some': SIN PREDICCIÓN. Debería ser: 'electronics'
# Predicción para ','-'some'-'electronics': SIN PREDICCIÓN. Debería ser: 'manufacturers'
# Predicción para 'some'-'electronics'-'manufacturers': SIN PREDICCIÓN. Debería ser: 'share'
# Predicción para 'electronics'-'manufacturers'-'share': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para 'manufacturers'-'share'-'that': SIN PREDICCIÓN. Debería ser: 'view'
# Predicción para 'share'-'that'-'view': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'that'-'view'-'.': SIN PREDICCIÓN. Debería ser: 'but'
# Predicción para 'view'-'.'-'but': SIN PREDICCIÓN. Debería ser: 'other'
# Predicción para '.'-'but'-'other': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'but'-'other'-'businessmen': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'other'-'businessmen'-'said': SIN PREDICCIÓN. Debería ser: 'such'
# Predicción para 'businessmen'-'said'-'such': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'said'-'such'-'a': SIN PREDICCIÓN. Debería ser: 'short-term'
# Predicción para 'such'-'a'-'short-term': SIN PREDICCIÓN. Debería ser: 'commercial'
# Predicción para 'a'-'short-term'-'commercial': SIN PREDICCIÓN. Debería ser: 'advantage'
# Predicción para 'short-term'-'commercial'-'advantage': SIN PREDICCIÓN. Debería ser: 'would'
# Predicción para 'commercial'-'advantage'-'would': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'advantage'-'would'-'be': SIN PREDICCIÓN. Debería ser: 'outweighed'
# Predicción para 'would'-'be'-'outweighed': SIN PREDICCIÓN. Debería ser: 'by'
# Predicción para 'be'-'outweighed'-'by': SIN PREDICCIÓN. Debería ser: 'further'
# Predicción para 'outweighed'-'by'-'further': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'by'-'further'-'u.s.': SIN PREDICCIÓN. Debería ser: 'pressure'
# Predicción para 'further'-'u.s.'-'pressure': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'u.s.'-'pressure'-'to': SIN PREDICCIÓN. Debería ser: 'block'
# Predicción para 'pressure'-'to'-'block': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'to'-'block'-'imports': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'block'-'imports'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'imports'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para '.'-'``'-'that': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para '``'-'that'-'is': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'that'-'is'-'a': SIN PREDICCIÓN. Debería ser: 'very'
# Predicción para 'is'-'a'-'very': SIN PREDICCIÓN. Debería ser: 'short-term'
# Predicción para 'a'-'very'-'short-term': SIN PREDICCIÓN. Debería ser: 'view'
# Predicción para 'very'-'short-term'-'view': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'short-term'-'view'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'view'-','-'''': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ','-''''-'said': SIN PREDICCIÓN. Debería ser: 'lawrence'
# Predicción para ''''-'said'-'lawrence': SIN PREDICCIÓN. Debería ser: 'mills'
# Predicción para 'said'-'lawrence'-'mills': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'lawrence'-'mills'-',': SIN PREDICCIÓN. Debería ser: 'director-general'
# Predicción para 'mills'-','-'director-general': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para ','-'director-general'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'director-general'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'federation'
# Predicción para 'of'-'the'-'federation': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'federation'-'of': SIN PREDICCIÓN. Debería ser: 'hong'
# Predicción para 'federation'-'of'-'hong': SIN PREDICCIÓN. Debería ser: 'kong'
# Predicción para 'of'-'hong'-'kong': SIN PREDICCIÓN. Debería ser: 'industry'
# Predicción para 'hong'-'kong'-'industry': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'kong'-'industry'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'industry'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'if'
# Predicción para '.'-'``'-'if': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para '``'-'if'-'the': SIN PREDICCIÓN. Debería ser: 'whole'
# Predicción para 'if'-'the'-'whole': SIN PREDICCIÓN. Debería ser: 'purpose'
# Predicción para 'the'-'whole'-'purpose': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para 'whole'-'purpose'-'is': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'purpose'-'is'-'to': SIN PREDICCIÓN. Debería ser: 'prevent'
# Predicción para 'is'-'to'-'prevent': SIN PREDICCIÓN. Debería ser: 'imports'
# Predicción para 'to'-'prevent'-'imports': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'prevent'-'imports'-',': SIN PREDICCIÓN. Debería ser: 'one'
# Predicción para 'imports'-','-'one': SIN PREDICCIÓN. Debería ser: 'day'
# Predicción para ','-'one'-'day': SIN PREDICCIÓN. Debería ser: 'it'
# Predicción para 'one'-'day'-'it': SIN PREDICCIÓN. Debería ser: 'will'
# Predicción para 'day'-'it'-'will': SIN PREDICCIÓN. Debería ser: 'be'
# Predicción para 'it'-'will'-'be': SIN PREDICCIÓN. Debería ser: 'extended'
# Predicción para 'will'-'be'-'extended': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'be'-'extended'-'to': SIN PREDICCIÓN. Debería ser: 'other'
# Predicción para 'extended'-'to'-'other': SIN PREDICCIÓN. Debería ser: 'sources'
# Predicción para 'to'-'other'-'sources': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'other'-'sources'-'.': SIN PREDICCIÓN. Debería ser: 'much'
# Predicción para 'sources'-'.'-'much': SIN PREDICCIÓN. Debería ser: 'more'
# Predicción para '.'-'much'-'more': SIN PREDICCIÓN. Debería ser: 'serious'
# Predicción para 'much'-'more'-'serious': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'more'-'serious'-'for': SIN PREDICCIÓN. Debería ser: 'hong'
# Predicción para 'serious'-'for'-'hong': SIN PREDICCIÓN. Debería ser: 'kong'
# Predicción para 'for'-'hong'-'kong': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para 'hong'-'kong'-'is': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'kong'-'is'-'the': SIN PREDICCIÓN. Debería ser: 'disadvantage'
# Predicción para 'is'-'the'-'disadvantage': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'disadvantage'-'of': SIN PREDICCIÓN. Debería ser: 'action'
# Predicción para 'disadvantage'-'of'-'action': SIN PREDICCIÓN. Debería ser: 'restraining'
# Predicción para 'of'-'action'-'restraining': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'action'-'restraining'-'trade': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'restraining'-'trade'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'trade'-','-'''': SIN PREDICCIÓN. Debería ser: 'he'
# Predicción para ','-''''-'he': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ''''-'he'-'said': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'he'-'said'-'.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'said'-'.'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para '.'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'the'-'u.s.'-'last': SIN PREDICCIÓN. Debería ser: 'year'
# Predicción para 'u.s.'-'last'-'year': SIN PREDICCIÓN. Debería ser: 'was'
# Predicción para 'last'-'year'-'was': SIN PREDICCIÓN. Debería ser: 'hong'
# Predicción para 'year'-'was'-'hong': SIN PREDICCIÓN. Debería ser: 'kong'
# Predicción para 'was'-'hong'-'kong': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'hong'-'kong'-''s': SIN PREDICCIÓN. Debería ser: 'biggest'
# Predicción para 'kong'-''s'-'biggest': SIN PREDICCIÓN. Debería ser: 'export'
# Predicción para ''s'-'biggest'-'export': SIN PREDICCIÓN. Debería ser: 'market'
# Predicción para 'biggest'-'export'-'market': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'export'-'market'-',': SIN PREDICCIÓN. Debería ser: 'accounting'
# Predicción para 'market'-','-'accounting': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para ','-'accounting'-'for': SIN PREDICCIÓN. Debería ser: 'over'
# Predicción para 'accounting'-'for'-'over': SIN PREDICCIÓN. Debería ser: '30'
# Predicción para 'for'-'over'-'30': SIN PREDICCIÓN. Debería ser: 'pct'
# Predicción para 'over'-'30'-'pct': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para '30'-'pct'-'of': SIN PREDICCIÓN. Debería ser: 'domestically'
# Predicción para 'pct'-'of'-'domestically': SIN PREDICCIÓN. Debería ser: 'produced'
# Predicción para 'of'-'domestically'-'produced': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'domestically'-'produced'-'exports': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'produced'-'exports'-'.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'exports'-'.'-'the': SIN PREDICCIÓN. Debería ser: 'australian'
# Predicción para '.'-'the'-'australian': SIN PREDICCIÓN. Debería ser: 'government'
# Predicción para 'the'-'australian'-'government': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para 'australian'-'government'-'is': SIN PREDICCIÓN. Debería ser: 'awaiting'
# Predicción para 'government'-'is'-'awaiting': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'is'-'awaiting'-'the': SIN PREDICCIÓN. Debería ser: 'outcome'
# Predicción para 'awaiting'-'the'-'outcome': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'the'-'outcome'-'of': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'outcome'-'of'-'trade': SIN PREDICCIÓN. Debería ser: 'talks'
# Predicción para 'of'-'trade'-'talks': SIN PREDICCIÓN. Debería ser: 'between'
# Predicción para 'trade'-'talks'-'between': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'talks'-'between'-'the': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'between'-'the'-'u.s.': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'the'-'u.s.'-'and': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'u.s.'-'and'-'japan': SIN PREDICCIÓN. Debería ser: 'with'
# Predicción para 'and'-'japan'-'with': SIN PREDICCIÓN. Debería ser: 'interest'
# Predicción para 'japan'-'with'-'interest': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'with'-'interest'-'and': SIN PREDICCIÓN. Debería ser: 'concern'
# Predicción para 'interest'-'and'-'concern': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'and'-'concern'-',': SIN PREDICCIÓN. Debería ser: 'industry'
# Predicción para 'concern'-','-'industry': SIN PREDICCIÓN. Debería ser: 'minister'
# Predicción para ','-'industry'-'minister': SIN PREDICCIÓN. Debería ser: 'john'
# Predicción para 'industry'-'minister'-'john': SIN PREDICCIÓN. Debería ser: 'button'
# Predicción para 'minister'-'john'-'button': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para 'john'-'button'-'said': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'button'-'said'-'in': SIN PREDICCIÓN. Debería ser: 'canberra'
# Predicción para 'said'-'in'-'canberra': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'in'-'canberra'-'last': SIN PREDICCIÓN. Debería ser: 'friday'
# Predicción para 'canberra'-'last'-'friday': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'last'-'friday'-'.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para 'friday'-'.'-'``': SIN PREDICCIÓN. Debería ser: 'this'
# Predicción para '.'-'``'-'this': SIN PREDICCIÓN. Debería ser: 'kind'
# Predicción para '``'-'this'-'kind': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'this'-'kind'-'of': SIN PREDICCIÓN. Debería ser: 'deterioration'
# Predicción para 'kind'-'of'-'deterioration': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'of'-'deterioration'-'in': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'deterioration'-'in'-'trade': SIN PREDICCIÓN. Debería ser: 'relations'
# Predicción para 'in'-'trade'-'relations': SIN PREDICCIÓN. Debería ser: 'between'
# Predicción para 'trade'-'relations'-'between': SIN PREDICCIÓN. Debería ser: 'two'
# Predicción para 'relations'-'between'-'two': SIN PREDICCIÓN. Debería ser: 'countries'
# Predicción para 'between'-'two'-'countries': SIN PREDICCIÓN. Debería ser: 'which'
# Predicción para 'two'-'countries'-'which': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para 'countries'-'which'-'are': SIN PREDICCIÓN. Debería ser: 'major'
# Predicción para 'which'-'are'-'major': SIN PREDICCIÓN. Debería ser: 'trading'
# Predicción para 'are'-'major'-'trading': SIN PREDICCIÓN. Debería ser: 'partners'
# Predicción para 'major'-'trading'-'partners': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'trading'-'partners'-'of': SIN PREDICCIÓN. Debería ser: 'ours'
# Predicción para 'partners'-'of'-'ours': SIN PREDICCIÓN. Debería ser: 'is'
# Predicción para 'of'-'ours'-'is': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'ours'-'is'-'a': SIN PREDICCIÓN. Debería ser: 'very'
# Predicción para 'is'-'a'-'very': SIN PREDICCIÓN. Debería ser: 'serious'
# Predicción para 'a'-'very'-'serious': SIN PREDICCIÓN. Debería ser: 'matter'
# Predicción para 'very'-'serious'-'matter': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'serious'-'matter'-',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para 'matter'-','-'''': SIN PREDICCIÓN. Debería ser: 'button'
# Predicción para ','-''''-'button': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para ''''-'button'-'said': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'button'-'said'-'.': SIN PREDICCIÓN. Debería ser: 'he'
# Predicción para 'said'-'.'-'he': SIN PREDICCIÓN. Debería ser: 'said'
# Predicción para '.'-'he'-'said': SIN PREDICCIÓN. Debería ser: 'australia'
# Predicción para 'he'-'said'-'australia': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'said'-'australia'-''s': SIN PREDICCIÓN. Debería ser: 'concerns'
# Predicción para 'australia'-''s'-'concerns': SIN PREDICCIÓN. Debería ser: 'centred'
# Predicción para ''s'-'concerns'-'centred': SIN PREDICCIÓN. Debería ser: 'on'
# Predicción para 'concerns'-'centred'-'on': SIN PREDICCIÓN. Debería ser: 'coal'
# Predicción para 'centred'-'on'-'coal': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'on'-'coal'-'and': SIN PREDICCIÓN. Debería ser: 'beef'
# Predicción para 'coal'-'and'-'beef': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'and'-'beef'-',': SIN PREDICCIÓN. Debería ser: 'australia'
# Predicción para 'beef'-','-'australia': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para ','-'australia'-''s': SIN PREDICCIÓN. Debería ser: 'two'
# Predicción para 'australia'-''s'-'two': SIN PREDICCIÓN. Debería ser: 'largest'
# Predicción para ''s'-'two'-'largest': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'two'-'largest'-'exports': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'largest'-'exports'-'to': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'exports'-'to'-'japan': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'to'-'japan'-'and': SIN PREDICCIÓN. Debería ser: 'also'
# Predicción para 'japan'-'and'-'also': SIN PREDICCIÓN. Debería ser: 'significant'
# Predicción para 'and'-'also'-'significant': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para 'also'-'significant'-'u.s.': SIN PREDICCIÓN. Debería ser: 'exports'
# Predicción para 'significant'-'u.s.'-'exports': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'u.s.'-'exports'-'to': SIN PREDICCIÓN. Debería ser: 'that'
# Predicción para 'exports'-'to'-'that': SIN PREDICCIÓN. Debería ser: 'country'
# Predicción para 'to'-'that'-'country': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'that'-'country'-'.': SIN PREDICCIÓN. Debería ser: 'meanwhile'
# Predicción para 'country'-'.'-'meanwhile': SIN PREDICCIÓN. Debería ser: 'u.s.-japanese'
# Predicción para '.'-'meanwhile'-'u.s.-japanese': SIN PREDICCIÓN. Debería ser: 'diplomatic'
# Predicción para 'meanwhile'-'u.s.-japanese'-'diplomatic': SIN PREDICCIÓN. Debería ser: 'manoeuvres'
# Predicción para 'u.s.-japanese'-'diplomatic'-'manoeuvres': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'diplomatic'-'manoeuvres'-'to': SIN PREDICCIÓN. Debería ser: 'solve'
# Predicción para 'manoeuvres'-'to'-'solve': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'to'-'solve'-'the': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'solve'-'the'-'trade': SIN PREDICCIÓN. Debería ser: 'stand-off'
# Predicción para 'the'-'trade'-'stand-off': SIN PREDICCIÓN. Debería ser: 'continue'
# Predicción para 'trade'-'stand-off'-'continue': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'stand-off'-'continue'-'.': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'continue'-'.'-'japan': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para '.'-'japan'-''s': SIN PREDICCIÓN. Debería ser: 'ruling'
# Predicción para 'japan'-''s'-'ruling': SIN PREDICCIÓN. Debería ser: 'liberal'
# Predicción para ''s'-'ruling'-'liberal': SIN PREDICCIÓN. Debería ser: 'democratic'
# Predicción para 'ruling'-'liberal'-'democratic': SIN PREDICCIÓN. Debería ser: 'party'
# Predicción para 'liberal'-'democratic'-'party': SIN PREDICCIÓN. Debería ser: 'yesterday'
# Predicción para 'democratic'-'party'-'yesterday': SIN PREDICCIÓN. Debería ser: 'outlined'
# Predicción para 'party'-'yesterday'-'outlined': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'yesterday'-'outlined'-'a': SIN PREDICCIÓN. Debería ser: 'package'
# Predicción para 'outlined'-'a'-'package': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'a'-'package'-'of': SIN PREDICCIÓN. Debería ser: 'economic'
# Predicción para 'package'-'of'-'economic': SIN PREDICCIÓN. Debería ser: 'measures'
# Predicción para 'of'-'economic'-'measures': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'economic'-'measures'-'to': SIN PREDICCIÓN. Debería ser: 'boost'
# Predicción para 'measures'-'to'-'boost': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'to'-'boost'-'the': SIN PREDICCIÓN. Debería ser: 'japanese'
# Predicción para 'boost'-'the'-'japanese': SIN PREDICCIÓN. Debería ser: 'economy'
# Predicción para 'the'-'japanese'-'economy': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'japanese'-'economy'-'.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'economy'-'.'-'the': SIN PREDICCIÓN. Debería ser: 'measures'
# Predicción para '.'-'the'-'measures': SIN PREDICCIÓN. Debería ser: 'proposed'
# Predicción para 'the'-'measures'-'proposed': SIN PREDICCIÓN. Debería ser: 'include'
# Predicción para 'measures'-'proposed'-'include': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'proposed'-'include'-'a': SIN PREDICCIÓN. Debería ser: 'large'
# Predicción para 'include'-'a'-'large': SIN PREDICCIÓN. Debería ser: 'supplementary'
# Predicción para 'a'-'large'-'supplementary': SIN PREDICCIÓN. Debería ser: 'budget'
# Predicción para 'large'-'supplementary'-'budget': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'supplementary'-'budget'-'and': SIN PREDICCIÓN. Debería ser: 'record'
# Predicción para 'budget'-'and'-'record': SIN PREDICCIÓN. Debería ser: 'public'
# Predicción para 'and'-'record'-'public': SIN PREDICCIÓN. Debería ser: 'works'
# Predicción para 'record'-'public'-'works': SIN PREDICCIÓN. Debería ser: 'spending'
# Predicción para 'public'-'works'-'spending': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'works'-'spending'-'in': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'spending'-'in'-'the': SIN PREDICCIÓN. Debería ser: 'first'
# Predicción para 'in'-'the'-'first': SIN PREDICCIÓN. Debería ser: 'half'
# Predicción para 'the'-'first'-'half': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'first'-'half'-'of': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'half'-'of'-'the': SIN PREDICCIÓN. Debería ser: 'financial'
# Predicción para 'of'-'the'-'financial': SIN PREDICCIÓN. Debería ser: 'year'
# Predicción para 'the'-'financial'-'year': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'financial'-'year'-'.': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'year'-'.'-'they': SIN PREDICCIÓN. Debería ser: 'also'
# Predicción para '.'-'they'-'also': SIN PREDICCIÓN. Debería ser: 'call'
# Predicción para 'they'-'also'-'call': SIN PREDICCIÓN. Debería ser: 'for'
# Predicción para 'also'-'call'-'for': SIN PREDICCIÓN. Debería ser: 'stepped-up'
# Predicción para 'call'-'for'-'stepped-up': SIN PREDICCIÓN. Debería ser: 'spending'
# Predicción para 'for'-'stepped-up'-'spending': SIN PREDICCIÓN. Debería ser: 'as'
# Predicción para 'stepped-up'-'spending'-'as': SIN PREDICCIÓN. Debería ser: 'an'
# Predicción para 'spending'-'as'-'an': SIN PREDICCIÓN. Debería ser: 'emergency'
# Predicción para 'as'-'an'-'emergency': SIN PREDICCIÓN. Debería ser: 'measure'
# Predicción para 'an'-'emergency'-'measure': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'emergency'-'measure'-'to': SIN PREDICCIÓN. Debería ser: 'stimulate'
# Predicción para 'measure'-'to'-'stimulate': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'to'-'stimulate'-'the': SIN PREDICCIÓN. Debería ser: 'economy'
# Predicción para 'stimulate'-'the'-'economy': SIN PREDICCIÓN. Debería ser: 'despite'
# Predicción para 'the'-'economy'-'despite': SIN PREDICCIÓN. Debería ser: 'prime'
# Predicción para 'economy'-'despite'-'prime': SIN PREDICCIÓN. Debería ser: 'minister'
# Predicción para 'despite'-'prime'-'minister': SIN PREDICCIÓN. Debería ser: 'yasuhiro'
# Predicción para 'prime'-'minister'-'yasuhiro': SIN PREDICCIÓN. Debería ser: 'nakasone'
# Predicción para 'minister'-'yasuhiro'-'nakasone': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para 'yasuhiro'-'nakasone'-''s': SIN PREDICCIÓN. Debería ser: 'avowed'
# Predicción para 'nakasone'-''s'-'avowed': SIN PREDICCIÓN. Debería ser: 'fiscal'
# Predicción para ''s'-'avowed'-'fiscal': SIN PREDICCIÓN. Debería ser: 'reform'
# Predicción para 'avowed'-'fiscal'-'reform': SIN PREDICCIÓN. Debería ser: 'program'
# Predicción para 'fiscal'-'reform'-'program': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para 'reform'-'program'-'.': SIN PREDICCIÓN. Debería ser: 'deputy'
# Predicción para 'program'-'.'-'deputy': SIN PREDICCIÓN. Debería ser: 'u.s.'
# Predicción para '.'-'deputy'-'u.s.': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'deputy'-'u.s.'-'trade': SIN PREDICCIÓN. Debería ser: 'representative'
# Predicción para 'u.s.'-'trade'-'representative': SIN PREDICCIÓN. Debería ser: 'michael'
# Predicción para 'trade'-'representative'-'michael': SIN PREDICCIÓN. Debería ser: 'smith'
# Predicción para 'representative'-'michael'-'smith': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'michael'-'smith'-'and': SIN PREDICCIÓN. Debería ser: 'makoto'
# Predicción para 'smith'-'and'-'makoto': SIN PREDICCIÓN. Debería ser: 'kuroda'
# Predicción para 'and'-'makoto'-'kuroda': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'makoto'-'kuroda'-',': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'kuroda'-','-'japan': SIN PREDICCIÓN. Debería ser: ''s'
# Predicción para ','-'japan'-''s': SIN PREDICCIÓN. Debería ser: 'deputy'
# Predicción para 'japan'-''s'-'deputy': SIN PREDICCIÓN. Debería ser: 'minister'
# Predicción para ''s'-'deputy'-'minister': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'deputy'-'minister'-'of': SIN PREDICCIÓN. Debería ser: 'international'
# Predicción para 'minister'-'of'-'international': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'of'-'international'-'trade': SIN PREDICCIÓN. Debería ser: 'and'
# Predicción para 'international'-'trade'-'and': SIN PREDICCIÓN. Debería ser: 'industry'
# Predicción para 'trade'-'and'-'industry': SIN PREDICCIÓN. Debería ser: '('
# Predicción para 'and'-'industry'-'(': SIN PREDICCIÓN. Debería ser: 'miti'
# Predicción para 'industry'-'('-'miti': SIN PREDICCIÓN. Debería ser: ')'
# Predicción para '('-'miti'-')': SIN PREDICCIÓN. Debería ser: ','
# Predicción para 'miti'-')'-',': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para ')'-','-'are': SIN PREDICCIÓN. Debería ser: 'due'
# Predicción para ','-'are'-'due': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'are'-'due'-'to': SIN PREDICCIÓN. Debería ser: 'meet'
# Predicción para 'due'-'to'-'meet': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'to'-'meet'-'in': SIN PREDICCIÓN. Debería ser: 'washington'
# Predicción para 'meet'-'in'-'washington': SIN PREDICCIÓN. Debería ser: 'this'
# Predicción para 'in'-'washington'-'this': SIN PREDICCIÓN. Debería ser: 'week'
# Predicción para 'washington'-'this'-'week': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'this'-'week'-'in': SIN PREDICCIÓN. Debería ser: 'an'
# Predicción para 'week'-'in'-'an': SIN PREDICCIÓN. Debería ser: 'effort'
# Predicción para 'in'-'an'-'effort': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'an'-'effort'-'to': SIN PREDICCIÓN. Debería ser: 'end'
# Predicción para 'effort'-'to'-'end': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'to'-'end'-'the': SIN PREDICCIÓN. Debería ser: 'dispute'
#
# Aciertos: 0/807 = 0.00%

# %%
print("2-skip-2-grama con signos de puntuación:\n")
evaluar(text, skip_2_gram_model_with_punctuation, 2)
# Out:
# 2-skip-2-grama con signos de puntuación:
#
# Predicción para 'asian': 'the'. Debería ser: 'exporters'
# Predicción para 'exporters': 'tonnes'. Debería ser: 'fear'
# Predicción para 'fear': 'will'. Debería ser: 'damage'
# Predicción para 'damage': 'pipeline'. Debería ser: 'from'
# Predicción para 'from': 'in'. Debería ser: 'u.s.-japan'
# Predicción para 'u.s.-japan': 'trade'. Debería ser: 'rift'
# Predicción para 'rift': 'friction'. Debería ser: 'mounting'
# Predicción para 'mounting': ','. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'friction'
# Predicción para 'friction': 'two'. Debería ser: 'between'
# Predicción para 'between': 'and'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'has'
# Predicción para 'has': 'to'. Debería ser: 'raised'
# Predicción para 'raised': 'in'. Debería ser: 'fears'
# Predicción para 'fears': 'inflation'. Debería ser: 'among'
# Predicción para 'among': ','. Debería ser: 'many'
# Predicción para 'many': 'the'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'asia'
# Predicción para 'asia': 'said'. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'exporting'
# Predicción para 'exporting': 'opec'. Debería ser: 'nations'
# Predicción para 'nations': ','. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'row'
# Predicción para 'row': 'the'. Debería ser: 'could'
# Predicción para 'could': 'to'. Debería ser: 'inflict'
# Predicción para 'inflict': 'damage'. Debería ser: 'far-reaching'
# Predicción para 'far-reaching': ','. Debería ser: 'economic'
# Predicción para 'economic': 'the'. Debería ser: 'damage'
# Predicción para 'damage': 'pipeline'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'businessmen'
# Predicción para 'businessmen': '.'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'officials'
# Predicción para 'officials': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'they'
# Predicción para 'they': 'the'. Debería ser: 'told'
# Predicción para 'told': 'conference'. Debería ser: 'reuter'
# Predicción para 'reuter': 'opec'. Debería ser: 'correspondents'
# Predicción para 'correspondents': 'capitals'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'asian'
# Predicción para 'asian': 'the'. Debería ser: 'capitals'
# Predicción para 'capitals': 'move'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'move'
# Predicción para 'move': 'the'. Debería ser: 'against'
# Predicción para 'against': 'in'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'might'
# Predicción para 'might': 'to'. Debería ser: 'boost'
# Predicción para 'boost': ','. Debería ser: 'protectionist'
# Predicción para 'protectionist': 'the'. Debería ser: 'sentiment'
# Predicción para 'sentiment': 'u.s.'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'lead'
# Predicción para 'lead': '.'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'curbs'
# Predicción para 'curbs': 'exports'. Debería ser: 'on'
# Predicción para 'on': ','. Debería ser: 'american'
# Predicción para 'american': 'lt'. Debería ser: 'imports'
# Predicción para 'imports': 'to'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'their'
# Predicción para 'their': 'the'. Debería ser: 'products'
# Predicción para 'products': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'but'
# Predicción para 'but': 'the'. Debería ser: 'some'
# Predicción para 'some': 'the'. Debería ser: 'exporters'
# Predicción para 'exporters': 'tonnes'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'while'
# Predicción para 'while': 'to'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'conflict'
# Predicción para 'conflict': ','. Debería ser: 'would'
# Predicción para 'would': 'to'. Debería ser: 'hurt'
# Predicción para 'hurt': '.'. Debería ser: 'them'
# Predicción para 'them': '.'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'long-run'
# Predicción para 'long-run': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'short-term'
# Predicción para 'short-term': 'rates'. Debería ser: 'tokyo'
# Predicción para 'tokyo': 'the'. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'loss'
# Predicción para 'loss': 'vs'. Debería ser: 'might'
# Predicción para 'might': 'to'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'their'
# Predicción para 'their': 'the'. Debería ser: 'gain'
# Predicción para 'gain': 'dlrs'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'has'
# Predicción para 'has': 'to'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'will'
# Predicción para 'will': 'to'. Debería ser: 'impose'
# Predicción para 'impose': 'on'. Debería ser: '300'
# Predicción para '300': 'in'. Debería ser: 'mln'
# Predicción para 'mln': 'mln'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'tariffs'
# Predicción para 'tariffs': '('. Debería ser: 'on'
# Predicción para 'on': ','. Debería ser: 'imports'
# Predicción para 'imports': 'to'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'japanese'
# Predicción para 'japanese': 'the'. Debería ser: 'electronics'
# Predicción para 'electronics': 'lt'. Debería ser: 'goods'
# Predicción para 'goods': ','. Debería ser: 'on'
# Predicción para 'on': ','. Debería ser: 'april'
# Predicción para 'april': 'march'. Debería ser: '17'
# Predicción para '17': 'share'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'retaliation'
# Predicción para 'retaliation': ''s'. Debería ser: 'for'
# Predicción para 'for': '.'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'alleged'
# Predicción para 'alleged': 'live'. Debería ser: 'failure'
# Predicción para 'failure': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'stick'
# Predicción para 'stick': 'policy'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'pact'
# Predicción para 'pact': 'the'. Debería ser: 'not'
# Predicción para 'not': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'sell'
# Predicción para 'sell': 'of'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'markets'. Debería ser: 'on'
# Predicción para 'on': ','. Debería ser: 'world'
# Predicción para 'world': '.'. Debería ser: 'markets'
# Predicción para 'markets': 'the'. Debería ser: 'at'
# Predicción para 'at': 'of'. Debería ser: 'below'
# Predicción para 'below': '.'. Debería ser: 'cost'
# Predicción para 'cost': 'and'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'unofficial'
# Predicción para 'unofficial': 'put'. Debería ser: 'japanese'
# Predicción para 'japanese': 'the'. Debería ser: 'estimates'
# Predicción para 'estimates': 'the'. Debería ser: 'put'
# Predicción para 'put': 'on'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'impact'
# Predicción para 'impact': ','. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': '('. Debería ser: 'at'
# Predicción para 'at': 'of'. Debería ser: '10'
# Predicción para '10': 'the'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'spokesmen'
# Predicción para 'spokesmen': 'the'. Debería ser: 'for'
# Predicción para 'for': '.'. Debería ser: 'major'
# Predicción para 'major': 'the'. Debería ser: 'electronics'
# Predicción para 'electronics': 'lt'. Debería ser: 'firms'
# Predicción para 'firms': 'to'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'they'
# Predicción para 'they': 'the'. Debería ser: 'would'
# Predicción para 'would': 'to'. Debería ser: 'virtually'
# Predicción para 'virtually': '.'. Debería ser: 'halt'
# Predicción para 'halt': 'in'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'products'
# Predicción para 'products': ','. Debería ser: 'hit'
# Predicción para 'hit': 'the'. Debería ser: 'by'
# Predicción para 'by': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'new'
# Predicción para 'new': 'the'. Debería ser: 'taxes'
# Predicción para 'taxes': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'we'
# Predicción para 'we': 'to'. Debería ser: 'would'
# Predicción para 'would': 'to'. Debería ser: 'n't'
# Predicción para 'n't': 'to'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'able'
# Predicción para 'able': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'do'
# Predicción para 'do': 'the'. Debería ser: 'business'
# Predicción para 'business': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: ''''
# Predicción para '''': '.'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'spokesman'
# Predicción para 'spokesman': 'said'. Debería ser: 'for'
# Predicción para 'for': '.'. Debería ser: 'leading'
# Predicción para 'leading': '.'. Debería ser: 'japanese'
# Predicción para 'japanese': 'the'. Debería ser: 'electronics'
# Predicción para 'electronics': 'lt'. Debería ser: 'firm'
# Predicción para 'firm': 'the'. Debería ser: 'matsushita'
# Predicción para 'matsushita': 'co'. Debería ser: 'electric'
# Predicción para 'electric': 'lt'. Debería ser: 'industrial'
# Predicción para 'industrial': 'the'. Debería ser: 'co'
# Predicción para 'co': ';'. Debería ser: 'ltd'
# Predicción para 'ltd': ';'. Debería ser: '&'
# Predicción para '&': 'xon'. Debería ser: 'lt'
# Predicción para 'lt': '>'. Debería ser: ';'
# Predicción para ';': '4th'. Debería ser: 'mc.t'
# Predicción para 'mc.t': '``'. Debería ser: '>'
# Predicción para '>': 'net'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'if'
# Predicción para 'if': 'to'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': '('. Debería ser: 'remain'
# Predicción para 'remain': 'the'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'place'
# Predicción para 'place': '.'. Debería ser: 'for'
# Predicción para 'for': '.'. Debería ser: 'any'
# Predicción para 'any': 'the'. Debería ser: 'length'
# Predicción para 'length': 'extension'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'time'
# Predicción para 'time': 'the'. Debería ser: 'beyond'
# Predicción para 'beyond': 'of'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'few'
# Predicción para 'few': 'the'. Debería ser: 'months'
# Predicción para 'months': ','. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'will'
# Predicción para 'will': 'to'. Debería ser: 'mean'
# Predicción para 'mean': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'complete'
# Predicción para 'complete': '.'. Debería ser: 'erosion'
# Predicción para 'erosion': 'markets'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: '('
# Predicción para '(': ','. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'goods'
# Predicción para 'goods': ','. Debería ser: 'subject'
# Predicción para 'subject': 'by'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'tariffs'
# Predicción para 'tariffs': '('. Debería ser: ')'
# Predicción para ')': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: ''''
# Predicción para '''': '.'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'tom'
# Predicción para 'tom': 'd-iowa'. Debería ser: 'murtha'
# Predicción para 'murtha': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'stock'
# Predicción para 'stock': 'the'. Debería ser: 'analyst'
# Predicción para 'analyst': '.'. Debería ser: 'at'
# Predicción para 'at': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'tokyo'
# Predicción para 'tokyo': 'the'. Debería ser: 'office'
# Predicción para 'office': 'the'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'broker'
# Predicción para 'broker': ';'. Debería ser: '&'
# Predicción para '&': 'xon'. Debería ser: 'lt'
# Predicción para 'lt': '>'. Debería ser: ';'
# Predicción para ';': '4th'. Debería ser: 'james'
# Predicción para 'james': 'the'. Debería ser: 'capel'
# Predicción para 'capel': '``'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'co'
# Predicción para 'co': ';'. Debería ser: '>'
# Predicción para '>': 'net'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'taiwan'
# Predicción para 'taiwan': 'to'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'businessmen'
# Predicción para 'businessmen': '.'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'officials'
# Predicción para 'officials': 'the'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'also'
# Predicción para 'also': 'the'. Debería ser: 'worried'
# Predicción para 'worried': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'we'
# Predicción para 'we': 'to'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'aware'
# Predicción para 'aware': 'may'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'seriousness'
# Predicción para 'seriousness': 'u.s.'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'threat'
# Predicción para 'threat': 'a'. Debería ser: 'against'
# Predicción para 'against': 'in'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'because'
# Predicción para 'because': 'the'. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'serves'
# Predicción para 'serves': 'customers'. Debería ser: 'as'
# Predicción para 'as': 'of'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'warning'
# Predicción para 'warning': 'against'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'us'
# Predicción para 'us': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: ''''
# Predicción para '''': '.'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'senior'
# Predicción para 'senior': 'said'. Debería ser: 'taiwanese'
# Predicción para 'taiwanese': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'official'
# Predicción para 'official': 'the'. Debería ser: 'who'
# Predicción para 'who': 'to'. Debería ser: 'asked'
# Predicción para 'asked': 'be'. Debería ser: 'not'
# Predicción para 'not': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'named'
# Predicción para 'named': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'taiwan'
# Predicción para 'taiwan': 'to'. Debería ser: 'had'
# Predicción para 'had': 'to'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'surplus'
# Predicción para 'surplus': 'billion'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: '15.6'
# Predicción para '15.6': 'in'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'last'
# Predicción para 'last': 'the'. Debería ser: 'year'
# Predicción para 'year': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: '95'
# Predicción para '95': 'share'. Debería ser: 'pct'
# Predicción para 'pct': ','. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'with'
# Predicción para 'with': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'surplus'
# Predicción para 'surplus': 'billion'. Debería ser: 'helped'
# Predicción para 'helped': 'the'. Debería ser: 'swell'
# Predicción para 'swell': 'foreign'. Debería ser: 'taiwan'
# Predicción para 'taiwan': 'to'. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'foreign'
# Predicción para 'foreign': 'the'. Debería ser: 'exchange'
# Predicción para 'exchange': 'the'. Debería ser: 'reserves'
# Predicción para 'reserves': 'billion'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: '53'
# Predicción para '53': 'loss'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'among'
# Predicción para 'among': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'world'
# Predicción para 'world': '.'. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'largest'
# Predicción para 'largest': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'we'
# Predicción para 'we': 'to'. Debería ser: 'must'
# Predicción para 'must': 'to'. Debería ser: 'quickly'
# Predicción para 'quickly': '.'. Debería ser: 'open'
# Predicción para 'open': 'to'. Debería ser: 'our'
# Predicción para 'our': ''''. Debería ser: 'markets'
# Predicción para 'markets': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'remove'
# Predicción para 'remove': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'barriers'
# Predicción para 'barriers': 'by'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'cut'
# Predicción para 'cut': 'to'. Debería ser: 'import'
# Predicción para 'import': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': '('. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'allow'
# Predicción para 'allow': 'to'. Debería ser: 'imports'
# Predicción para 'imports': 'to'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'products'
# Predicción para 'products': ','. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'if'
# Predicción para 'if': 'to'. Debería ser: 'we'
# Predicción para 'we': 'to'. Debería ser: 'want'
# Predicción para 'want': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'defuse'
# Predicción para 'defuse': 'and'. Debería ser: 'problems'
# Predicción para 'problems': 'the'. Debería ser: 'from'
# Predicción para 'from': 'in'. Debería ser: 'possible'
# Predicción para 'possible': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'retaliation'
# Predicción para 'retaliation': ''s'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: ''''
# Predicción para '''': '.'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'paul'
# Predicción para 'paul': 'a'. Debería ser: 'sheen'
# Predicción para 'sheen': 'of'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'chairman'
# Predicción para 'chairman': 'said'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'textile'
# Predicción para 'textile': 'of'. Debería ser: 'exporters'
# Predicción para 'exporters': 'tonnes'. Debería ser: '&'
# Predicción para '&': 'xon'. Debería ser: 'lt'
# Predicción para 'lt': '>'. Debería ser: ';'
# Predicción para ';': '4th'. Debería ser: 'taiwan'
# Predicción para 'taiwan': 'to'. Debería ser: 'safe'
# Predicción para 'safe': '.'. Debería ser: 'group'
# Predicción para 'group': 'lt'. Debería ser: '>'
# Predicción para '>': 'net'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'senior'
# Predicción para 'senior': 'said'. Debería ser: 'official'
# Predicción para 'official': 'the'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'south'
# Predicción para 'south': 'the'. Debería ser: 'korea'
# Predicción para 'korea': ','. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'promotion'
# Predicción para 'promotion': 'lipc'. Debería ser: 'association'
# Predicción para 'association': '.'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'dispute'
# Predicción para 'dispute': 'u.s.'. Debería ser: 'between'
# Predicción para 'between': 'and'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'might'
# Predicción para 'might': 'to'. Debería ser: 'also'
# Predicción para 'also': 'the'. Debería ser: 'lead'
# Predicción para 'lead': '.'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'pressure'
# Predicción para 'pressure': 'to'. Debería ser: 'on'
# Predicción para 'on': ','. Debería ser: 'south'
# Predicción para 'south': 'the'. Debería ser: 'korea'
# Predicción para 'korea': ','. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'whose'
# Predicción para 'whose': 'is'. Debería ser: 'chief'
# Predicción para 'chief': 'of'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'similar'
# Predicción para 'similar': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'those'
# Predicción para 'those': 'the'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'last'
# Predicción para 'last': 'the'. Debería ser: 'year'
# Predicción para 'year': 'the'. Debería ser: 'south'
# Predicción para 'south': 'the'. Debería ser: 'korea'
# Predicción para 'korea': ','. Debería ser: 'had'
# Predicción para 'had': 'to'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'surplus'
# Predicción para 'surplus': 'billion'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: '7.1'
# Predicción para '7.1': ','. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'with'
# Predicción para 'with': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'up'
# Predicción para 'up': 'mln'. Debería ser: 'from'
# Predicción para 'from': 'in'. Debería ser: '4.9'
# Predicción para '4.9': 'in'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: '1985.'
# Predicción para '1985.': 'the'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'malaysia'
# Predicción para 'malaysia': ','. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'officers'
# Predicción para 'officers': 'company'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'businessmen'
# Predicción para 'businessmen': '.'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'tough'
# Predicción para 'tough': '.'. Debería ser: 'curbs'
# Predicción para 'curbs': 'exports'. Debería ser: 'against'
# Predicción para 'against': 'in'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'might'
# Predicción para 'might': 'to'. Debería ser: 'allow'
# Predicción para 'allow': 'to'. Debería ser: 'hard-hit'
# Predicción para 'hard-hit': 'semiconductors'. Debería ser: 'producers'
# Predicción para 'producers': 'to'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'markets'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'third'
# Predicción para 'third': 'the'. Debería ser: 'countries'
# Predicción para 'countries': 'to'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'expand'
# Predicción para 'expand': ','. Debería ser: 'their'
# Predicción para 'their': 'the'. Debería ser: 'sales'
# Predicción para 'sales': 'vs'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'hong'
# Predicción para 'hong': ','. Debería ser: 'kong'
# Predicción para 'kong': ','. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'where'
# Predicción para 'where': 'to'. Debería ser: 'newspapers'
# Predicción para 'newspapers': 'the'. Debería ser: 'have'
# Predicción para 'have': 'to'. Debería ser: 'alleged'
# Predicción para 'alleged': 'live'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'has'
# Predicción para 'has': 'to'. Debería ser: 'been'
# Predicción para 'been': 'the'. Debería ser: 'selling'
# Predicción para 'selling': 'to'. Debería ser: 'below-cost'
# Predicción para 'below-cost': 'some'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'markets'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'some'
# Predicción para 'some': 'the'. Debería ser: 'electronics'
# Predicción para 'electronics': 'lt'. Debería ser: 'manufacturers'
# Predicción para 'manufacturers': 'said'. Debería ser: 'share'
# Predicción para 'share': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'view'
# Predicción para 'view': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'but'
# Predicción para 'but': 'the'. Debería ser: 'other'
# Predicción para 'other': 'the'. Debería ser: 'businessmen'
# Predicción para 'businessmen': '.'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'such'
# Predicción para 'such': ','. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'short-term'
# Predicción para 'short-term': 'rates'. Debería ser: 'commercial'
# Predicción para 'commercial': 'the'. Debería ser: 'advantage'
# Predicción para 'advantage': '.'. Debería ser: 'would'
# Predicción para 'would': 'to'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'outweighed'
# Predicción para 'outweighed': 'u.s.'. Debería ser: 'by'
# Predicción para 'by': ','. Debería ser: 'further'
# Predicción para 'further': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'pressure'
# Predicción para 'pressure': 'to'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'block'
# Predicción para 'block': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'to'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'very'
# Predicción para 'very': 'the'. Debería ser: 'short-term'
# Predicción para 'short-term': 'rates'. Debería ser: 'view'
# Predicción para 'view': '.'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: ''''
# Predicción para '''': '.'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'lawrence'
# Predicción para 'lawrence': 'the'. Debería ser: 'mills'
# Predicción para 'mills': '.'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'director-general'
# Predicción para 'director-general': 'federation'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'federation'
# Predicción para 'federation': '.'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'hong'
# Predicción para 'hong': ','. Debería ser: 'kong'
# Predicción para 'kong': ','. Debería ser: 'industry'
# Predicción para 'industry': '.'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'if'
# Predicción para 'if': 'to'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'whole'
# Predicción para 'whole': ','. Debería ser: 'purpose'
# Predicción para 'purpose': 'he'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'prevent'
# Predicción para 'prevent': 'from'. Debería ser: 'imports'
# Predicción para 'imports': 'to'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'one'
# Predicción para 'one': '.'. Debería ser: 'day'
# Predicción para 'day': ')'. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'will'
# Predicción para 'will': 'to'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'extended'
# Predicción para 'extended': 'offer'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'other'
# Predicción para 'other': 'the'. Debería ser: 'sources'
# Predicción para 'sources': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'much'
# Predicción para 'much': 'mln'. Debería ser: 'more'
# Predicción para 'more': 'the'. Debería ser: 'serious'
# Predicción para 'serious': 'the'. Debería ser: 'for'
# Predicción para 'for': '.'. Debería ser: 'hong'
# Predicción para 'hong': ','. Debería ser: 'kong'
# Predicción para 'kong': ','. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'disadvantage'
# Predicción para 'disadvantage': 'restraining'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'action'
# Predicción para 'action': 'the'. Debería ser: 'restraining'
# Predicción para 'restraining': 'mark'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: ''''
# Predicción para '''': '.'. Debería ser: 'he'
# Predicción para 'he': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'last'
# Predicción para 'last': 'the'. Debería ser: 'year'
# Predicción para 'year': 'the'. Debería ser: 'was'
# Predicción para 'was': 'the'. Debería ser: 'hong'
# Predicción para 'hong': ','. Debería ser: 'kong'
# Predicción para 'kong': ','. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'biggest'
# Predicción para 'biggest': ','. Debería ser: 'export'
# Predicción para 'export': 'the'. Debería ser: 'market'
# Predicción para 'market': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'accounting'
# Predicción para 'accounting': 'pct'. Debería ser: 'for'
# Predicción para 'for': '.'. Debería ser: 'over'
# Predicción para 'over': 'of'. Debería ser: '30'
# Predicción para '30': ','. Debería ser: 'pct'
# Predicción para 'pct': ','. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'domestically'
# Predicción para 'domestically': '.'. Debería ser: 'produced'
# Predicción para 'produced': 'of'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'australian'
# Predicción para 'australian': 'the'. Debería ser: 'government'
# Predicción para 'government': 'to'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'awaiting'
# Predicción para 'awaiting': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'outcome'
# Predicción para 'outcome': 'talks'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'talks'
# Predicción para 'talks': '.'. Debería ser: 'between'
# Predicción para 'between': 'and'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'with'
# Predicción para 'with': 'of'. Debería ser: 'interest'
# Predicción para 'interest': 'the'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'concern'
# Predicción para 'concern': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'industry'
# Predicción para 'industry': '.'. Debería ser: 'minister'
# Predicción para 'minister': 'said'. Debería ser: 'john'
# Predicción para 'john': 'in'. Debería ser: 'button'
# Predicción para 'button': 'canberra'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'canberra'
# Predicción para 'canberra': '.'. Debería ser: 'last'
# Predicción para 'last': 'the'. Debería ser: 'friday'
# Predicción para 'friday': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'this'
# Predicción para 'this': 'the'. Debería ser: 'kind'
# Predicción para 'kind': 'we'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'deterioration'
# Predicción para 'deterioration': 'trade'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'relations'
# Predicción para 'relations': '.'. Debería ser: 'between'
# Predicción para 'between': 'and'. Debería ser: 'two'
# Predicción para 'two': 'the'. Debería ser: 'countries'
# Predicción para 'countries': 'to'. Debería ser: 'which'
# Predicción para 'which': 'to'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'major'
# Predicción para 'major': 'the'. Debería ser: 'trading'
# Predicción para 'trading': 'the'. Debería ser: 'partners'
# Predicción para 'partners': 'the'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'ours'
# Predicción para 'ours': 'very'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'very'
# Predicción para 'very': 'the'. Debería ser: 'serious'
# Predicción para 'serious': 'the'. Debería ser: 'matter'
# Predicción para 'matter': ','. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: ''''
# Predicción para '''': '.'. Debería ser: 'button'
# Predicción para 'button': 'canberra'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'he'
# Predicción para 'he': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'australia'
# Predicción para 'australia': ','. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'concerns'
# Predicción para 'concerns': 'the'. Debería ser: 'centred'
# Predicción para 'centred': ','. Debería ser: 'on'
# Predicción para 'on': ','. Debería ser: 'coal'
# Predicción para 'coal': 'the'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'beef'
# Predicción para 'beef': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'australia'
# Predicción para 'australia': ','. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'two'
# Predicción para 'two': 'the'. Debería ser: 'largest'
# Predicción para 'largest': ','. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'also'
# Predicción para 'also': 'the'. Debería ser: 'significant'
# Predicción para 'significant': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'country'
# Predicción para 'country': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'meanwhile'
# Predicción para 'meanwhile': 'began'. Debería ser: 'u.s.-japanese'
# Predicción para 'u.s.-japanese': ','. Debería ser: 'diplomatic'
# Predicción para 'diplomatic': '.'. Debería ser: 'manoeuvres'
# Predicción para 'manoeuvres': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'solve'
# Predicción para 'solve': 'problems'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'stand-off'
# Predicción para 'stand-off': 'japan'. Debería ser: 'continue'
# Predicción para 'continue': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'ruling'
# Predicción para 'ruling': 'party'. Debería ser: 'liberal'
# Predicción para 'liberal': '('. Debería ser: 'democratic'
# Predicción para 'democratic': 'ldp'. Debería ser: 'party'
# Predicción para 'party': ')'. Debería ser: 'yesterday'
# Predicción para 'yesterday': 'said'. Debería ser: 'outlined'
# Predicción para 'outlined': 'louvre'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'package'
# Predicción para 'package': 'the'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'economic'
# Predicción para 'economic': 'the'. Debería ser: 'measures'
# Predicción para 'measures': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'boost'
# Predicción para 'boost': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'japanese'
# Predicción para 'japanese': 'the'. Debería ser: 'economy'
# Predicción para 'economy': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'measures'
# Predicción para 'measures': 'the'. Debería ser: 'proposed'
# Predicción para 'proposed': 'the'. Debería ser: 'include'
# Predicción para 'include': 'of'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'large'
# Predicción para 'large': 'the'. Debería ser: 'supplementary'
# Predicción para 'supplementary': 'those'. Debería ser: 'budget'
# Predicción para 'budget': 'the'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'record'
# Predicción para 'record': '.'. Debería ser: 'public'
# Predicción para 'public': 'the'. Debería ser: 'works'
# Predicción para 'works': ';'. Debería ser: 'spending'
# Predicción para 'spending': 'to'. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'first'
# Predicción para 'first': 'of'. Debería ser: 'half'
# Predicción para 'half': 'year'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'financial'
# Predicción para 'financial': 'the'. Debería ser: 'year'
# Predicción para 'year': 'the'. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'they'
# Predicción para 'they': 'the'. Debería ser: 'also'
# Predicción para 'also': 'the'. Debería ser: 'call'
# Predicción para 'call': 'to'. Debería ser: 'for'
# Predicción para 'for': '.'. Debería ser: 'stepped-up'
# Predicción para 'stepped-up': 'an'. Debería ser: 'spending'
# Predicción para 'spending': 'to'. Debería ser: 'as'
# Predicción para 'as': 'of'. Debería ser: 'an'
# Predicción para 'an': 'of'. Debería ser: 'emergency'
# Predicción para 'emergency': '.'. Debería ser: 'measure'
# Predicción para 'measure': 'supply'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'stimulate'
# Predicción para 'stimulate': '.'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'economy'
# Predicción para 'economy': 'the'. Debería ser: 'despite'
# Predicción para 'despite': 'in'. Debería ser: 'prime'
# Predicción para 'prime': 'nakasone'. Debería ser: 'minister'
# Predicción para 'minister': 'said'. Debería ser: 'yasuhiro'
# Predicción para 'yasuhiro': 'a'. Debería ser: 'nakasone'
# Predicción para 'nakasone': 'to'. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'avowed'
# Predicción para 'avowed': 'program'. Debería ser: 'fiscal'
# Predicción para 'fiscal': 'march'. Debería ser: 'reform'
# Predicción para 'reform': 'the'. Debería ser: 'program'
# Predicción para 'program': ','. Debería ser: '.'
# Predicción para '.': 'the'. Debería ser: 'deputy'
# Predicción para 'deputy': 'of'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'representative'
# Predicción para 'representative': 'said'. Debería ser: 'michael'
# Predicción para 'michael': '.'. Debería ser: 'smith'
# Predicción para 'smith': 'harris'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'makoto'
# Predicción para 'makoto': 'the'. Debería ser: 'kuroda'
# Predicción para 'kuroda': 'u.s.'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: ''s'
# Predicción para ''s': ','. Debería ser: 'deputy'
# Predicción para 'deputy': 'of'. Debería ser: 'minister'
# Predicción para 'minister': 'said'. Debería ser: 'of'
# Predicción para 'of': ','. Debería ser: 'international'
# Predicción para 'international': ','. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'and'
# Predicción para 'and': ','. Debería ser: 'industry'
# Predicción para 'industry': '.'. Debería ser: '('
# Predicción para '(': ','. Debería ser: 'miti'
# Predicción para 'miti': 'to'. Debería ser: ')'
# Predicción para ')': 'the'. Debería ser: ','
# Predicción para ',': 'said'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'due'
# Predicción para 'due': ','. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'meet'
# Predicción para 'meet': ','. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'washington'
# Predicción para 'washington': 'the'. Debería ser: 'this'
# Predicción para 'this': 'the'. Debería ser: 'week'
# Predicción para 'week': ','. Debería ser: 'in'
# Predicción para 'in': ','. Debería ser: 'an'
# Predicción para 'an': 'of'. Debería ser: 'effort'
# Predicción para 'effort': 'the'. Debería ser: 'to'
# Predicción para 'to': ','. Debería ser: 'end'
# Predicción para 'end': ','. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'dispute'
#
# Aciertos: 19/809 = 2.35%

# %%
print("2-skip-2-grama sin signos de puntuación:\n")
evaluar(text, skip_2_gram_model_without_punctuation, 2)
# Out:
# 2-skip-2-grama sin signos de puntuación:
#
# Predicción para 'asian': 'the'. Debería ser: 'exporters'
# Predicción para 'exporters': 'tonnes'. Debería ser: 'fear'
# Predicción para 'fear': 'will'. Debería ser: 'damage'
# Predicción para 'damage': 'pipeline'. Debería ser: 'from'
# Predicción para 'from': 'in'. Debería ser: 'u.s.-japan'
# Predicción para 'u.s.-japan': 'trade'. Debería ser: 'rift'
# Predicción para 'rift': 'friction'. Debería ser: 'mounting'
# Predicción para 'mounting': 'to'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'friction'
# Predicción para 'friction': 'the'. Debería ser: 'between'
# Predicción para 'between': 'and'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'has'
# Predicción para 'has': 'to'. Debería ser: 'raised'
# Predicción para 'raised': 'in'. Debería ser: 'fears'
# Predicción para 'fears': 'inflation'. Debería ser: 'among'
# Predicción para 'among': 'the'. Debería ser: 'many'
# Predicción para 'many': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'asia'
# Predicción para 'asia': 'agricultural'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'exporting'
# Predicción para 'exporting': 'the'. Debería ser: 'nations'
# Predicción para 'nations': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'row'
# Predicción para 'row': 'the'. Debería ser: 'could'
# Predicción para 'could': 'to'. Debería ser: 'inflict'
# Predicción para 'inflict': 'damage'. Debería ser: 'far-reaching'
# Predicción para 'far-reaching': 'businessmen'. Debería ser: 'economic'
# Predicción para 'economic': 'the'. Debería ser: 'damage'
# Predicción para 'damage': 'pipeline'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'officials'
# Predicción para 'officials': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'they': 'to'. Debería ser: 'told'
# Predicción para 'told': 'conference'. Debería ser: 'reuter'
# Predicción para 'reuter': 'opec'. Debería ser: 'correspondents'
# Predicción para 'correspondents': 'capitals'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'asian'
# Predicción para 'asian': 'the'. Debería ser: 'capitals'
# Predicción para 'capitals': 'move'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'move'
# Predicción para 'move': 'the'. Debería ser: 'against'
# Predicción para 'against': 'in'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'might'
# Predicción para 'might': 'to'. Debería ser: 'boost'
# Predicción para 'boost': 'the'. Debería ser: 'protectionist'
# Predicción para 'protectionist': 'the'. Debería ser: 'sentiment'
# Predicción para 'sentiment': 'u.s.'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'lead'
# Predicción para 'lead': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'curbs'
# Predicción para 'curbs': 'exports'. Debería ser: 'on'
# Predicción para 'on': 'of'. Debería ser: 'american'
# Predicción para 'american': 'said'. Debería ser: 'imports'
# Predicción para 'imports': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'their'
# Predicción para 'their': 'the'. Debería ser: 'products'
# Predicción para 'products': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'but'
# Predicción para 'but': 'the'. Debería ser: 'some'
# Predicción para 'some': 'the'. Debería ser: 'exporters'
# Predicción para 'exporters': 'tonnes'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'while'
# Predicción para 'while': 'to'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'conflict'
# Predicción para 'conflict': 'past'. Debería ser: 'would'
# Predicción para 'would': 'to'. Debería ser: 'hurt'
# Predicción para 'hurt': 'the'. Debería ser: 'them'
# Predicción para 'them': 'said'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'long-run'
# Predicción para 'long-run': 'short-term'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'short-term'
# Predicción para 'short-term': 'rates'. Debería ser: 'tokyo'
# Predicción para 'tokyo': 'the'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'loss'
# Predicción para 'loss': 'vs'. Debería ser: 'might'
# Predicción para 'might': 'to'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'their'
# Predicción para 'their': 'the'. Debería ser: 'gain'
# Predicción para 'gain': 'dlrs'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'has'
# Predicción para 'has': 'to'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'will'
# Predicción para 'will': 'to'. Debería ser: 'impose'
# Predicción para 'impose': 'on'. Debería ser: '300'
# Predicción para '300': 'in'. Debería ser: 'mln'
# Predicción para 'mln': 'mln'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'gatt'. Debería ser: 'on'
# Predicción para 'on': 'of'. Debería ser: 'imports'
# Predicción para 'imports': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'japanese'
# Predicción para 'japanese': 'the'. Debería ser: 'electronics'
# Predicción para 'electronics': 'it'. Debería ser: 'goods'
# Predicción para 'goods': 'the'. Debería ser: 'on'
# Predicción para 'on': 'of'. Debería ser: 'april'
# Predicción para 'april': 'march'. Debería ser: '17'
# Predicción para '17': 'share'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'retaliation'
# Predicción para 'retaliation': ''s'. Debería ser: 'for'
# Predicción para 'for': 'of'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'alleged'
# Predicción para 'alleged': 'live'. Debería ser: 'failure'
# Predicción para 'failure': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'stick'
# Predicción para 'stick': 'policy'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'pact'
# Predicción para 'pact': 'the'. Debería ser: 'not'
# Predicción para 'not': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'sell'
# Predicción para 'sell': 'of'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'markets'. Debería ser: 'on'
# Predicción para 'on': 'of'. Debería ser: 'world'
# Predicción para 'world': 'the'. Debería ser: 'markets'
# Predicción para 'markets': 'the'. Debería ser: 'at'
# Predicción para 'at': 'of'. Debería ser: 'below'
# Predicción para 'below': 'mln'. Debería ser: 'cost'
# Predicción para 'cost': 'and'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'unofficial'
# Predicción para 'unofficial': 'put'. Debería ser: 'japanese'
# Predicción para 'japanese': 'the'. Debería ser: 'estimates'
# Predicción para 'estimates': 'the'. Debería ser: 'put'
# Predicción para 'put': 'on'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'impact'
# Predicción para 'impact': 'of'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'gatt'. Debería ser: 'at'
# Predicción para 'at': 'of'. Debería ser: '10'
# Predicción para '10': 'the'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'spokesmen'
# Predicción para 'spokesmen': 'electronics'. Debería ser: 'for'
# Predicción para 'for': 'of'. Debería ser: 'major'
# Predicción para 'major': 'the'. Debería ser: 'electronics'
# Predicción para 'electronics': 'it'. Debería ser: 'firms'
# Predicción para 'firms': 'to'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'they'
# Predicción para 'they': 'to'. Debería ser: 'would'
# Predicción para 'would': 'to'. Debería ser: 'virtually'
# Predicción para 'virtually': 'the'. Debería ser: 'halt'
# Predicción para 'halt': 'in'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'products'
# Predicción para 'products': 'the'. Debería ser: 'hit'
# Predicción para 'hit': 'the'. Debería ser: 'by'
# Predicción para 'by': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'new'
# Predicción para 'new': 'the'. Debería ser: 'taxes'
# Predicción para 'taxes': 'and'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'we'
# Predicción para 'we': 'to'. Debería ser: 'would'
# Predicción para 'would': 'to'. Debería ser: 'n't'
# Predicción para 'n't': 'the'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'able'
# Predicción para 'able': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'do'
# Predicción para 'do': 'to'. Debería ser: 'business'
# Predicción para 'business': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'spokesman'
# Predicción para 'spokesman': 'said'. Debería ser: 'for'
# Predicción para 'for': 'of'. Debería ser: 'leading'
# Predicción para 'leading': 'said'. Debería ser: 'japanese'
# Predicción para 'japanese': 'the'. Debería ser: 'electronics'
# Predicción para 'electronics': 'it'. Debería ser: 'firm'
# Predicción para 'firm': 'the'. Debería ser: 'matsushita'
# Predicción para 'matsushita': 'co'. Debería ser: 'electric'
# Predicción para 'electric': 'lt'. Debería ser: 'industrial'
# Predicción para 'industrial': 'the'. Debería ser: 'co'
# Predicción para 'co': 'it'. Debería ser: 'ltd'
# Predicción para 'ltd': 'said'. Debería ser: '&'
# Predicción para '&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'lt': 'qtr'. Debería ser: ';'
# Predicción para ';': SIN PREDICCIÓN. Debería ser: 'mc.t'
# Predicción para 'mc.t': 'the'. Debería ser: '>'
# Predicción para '>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'if'
# Predicción para 'if': 'to'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'gatt'. Debería ser: 'remain'
# Predicción para 'remain': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'place'
# Predicción para 'place': 'on'. Debería ser: 'for'
# Predicción para 'for': 'of'. Debería ser: 'any'
# Predicción para 'any': 'the'. Debería ser: 'length'
# Predicción para 'length': 'extension'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'time'
# Predicción para 'time': 'the'. Debería ser: 'beyond'
# Predicción para 'beyond': 'of'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'few'
# Predicción para 'few': 'the'. Debería ser: 'months'
# Predicción para 'months': 'the'. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'will'
# Predicción para 'will': 'to'. Debería ser: 'mean'
# Predicción para 'mean': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'complete'
# Predicción para 'complete': 'the'. Debería ser: 'erosion'
# Predicción para 'erosion': 'markets'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: '('
# Predicción para '(': SIN PREDICCIÓN. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'goods'
# Predicción para 'goods': 'the'. Debería ser: 'subject'
# Predicción para 'subject': 'by'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'gatt'. Debería ser: ')'
# Predicción para ')': SIN PREDICCIÓN. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'tom'
# Predicción para 'tom': 'of'. Debería ser: 'murtha'
# Predicción para 'murtha': 'james'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'stock'
# Predicción para 'stock': 'the'. Debería ser: 'analyst'
# Predicción para 'analyst': 'of'. Debería ser: 'at'
# Predicción para 'at': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'tokyo'
# Predicción para 'tokyo': 'the'. Debería ser: 'office'
# Predicción para 'office': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'broker'
# Predicción para 'broker': 'to'. Debería ser: '&'
# Predicción para '&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'lt': 'qtr'. Debería ser: ';'
# Predicción para ';': SIN PREDICCIÓN. Debería ser: 'james'
# Predicción para 'james': 'the'. Debería ser: 'capel'
# Predicción para 'capel': '``'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'co'
# Predicción para 'co': 'it'. Debería ser: '>'
# Predicción para '>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'taiwan'
# Predicción para 'taiwan': 'to'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'officials'
# Predicción para 'officials': 'the'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'also'
# Predicción para 'also': 'the'. Debería ser: 'worried'
# Predicción para 'worried': 'increased'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'we'
# Predicción para 'we': 'to'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'aware'
# Predicción para 'aware': '``'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'seriousness'
# Predicción para 'seriousness': 'u.s.'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'threat'
# Predicción para 'threat': 'a'. Debería ser: 'against'
# Predicción para 'against': 'in'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'because'
# Predicción para 'because': 'the'. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'serves'
# Predicción para 'serves': 'customers'. Debería ser: 'as'
# Predicción para 'as': 'of'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'warning'
# Predicción para 'warning': 'against'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'us'
# Predicción para 'us': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'senior'
# Predicción para 'senior': 'said'. Debería ser: 'taiwanese'
# Predicción para 'taiwanese': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'official'
# Predicción para 'official': 'the'. Debería ser: 'who'
# Predicción para 'who': 'to'. Debería ser: 'asked'
# Predicción para 'asked': 'be'. Debería ser: 'not'
# Predicción para 'not': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'named'
# Predicción para 'named': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'taiwan': 'to'. Debería ser: 'had'
# Predicción para 'had': 'to'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'surplus'
# Predicción para 'surplus': 'billion'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: '15.6'
# Predicción para '15.6': 'in'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'last'
# Predicción para 'last': 'the'. Debería ser: 'year'
# Predicción para 'year': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: '95'
# Predicción para '95': 'share'. Debería ser: 'pct'
# Predicción para 'pct': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'with'
# Predicción para 'with': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'surplus'
# Predicción para 'surplus': 'billion'. Debería ser: 'helped'
# Predicción para 'helped': 'the'. Debería ser: 'swell'
# Predicción para 'swell': 'foreign'. Debería ser: 'taiwan'
# Predicción para 'taiwan': 'to'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'foreign'
# Predicción para 'foreign': 'the'. Debería ser: 'exchange'
# Predicción para 'exchange': 'the'. Debería ser: 'reserves'
# Predicción para 'reserves': 'billion'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: '53'
# Predicción para '53': 'loss'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'among'
# Predicción para 'among': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'world'
# Predicción para 'world': 'the'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'largest'
# Predicción para 'largest': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'we'
# Predicción para 'we': 'to'. Debería ser: 'must'
# Predicción para 'must': 'to'. Debería ser: 'quickly'
# Predicción para 'quickly': 'the'. Debería ser: 'open'
# Predicción para 'open': 'to'. Debería ser: 'our'
# Predicción para 'our': ''''. Debería ser: 'markets'
# Predicción para 'markets': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'remove'
# Predicción para 'remove': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'barriers'
# Predicción para 'barriers': 'and'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'cut'
# Predicción para 'cut': 'to'. Debería ser: 'import'
# Predicción para 'import': 'the'. Debería ser: 'tariffs'
# Predicción para 'tariffs': 'gatt'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'allow'
# Predicción para 'allow': 'to'. Debería ser: 'imports'
# Predicción para 'imports': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'products'
# Predicción para 'products': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'if'
# Predicción para 'if': 'to'. Debería ser: 'we'
# Predicción para 'we': 'to'. Debería ser: 'want'
# Predicción para 'want': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'defuse'
# Predicción para 'defuse': 'and'. Debería ser: 'problems'
# Predicción para 'problems': 'the'. Debería ser: 'from'
# Predicción para 'from': 'in'. Debería ser: 'possible'
# Predicción para 'possible': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'retaliation'
# Predicción para 'retaliation': ''s'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'paul'
# Predicción para 'paul': 'the'. Debería ser: 'sheen'
# Predicción para 'sheen': 'textile'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'chairman'
# Predicción para 'chairman': 'said'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'textile'
# Predicción para 'textile': 'of'. Debería ser: 'exporters'
# Predicción para 'exporters': 'tonnes'. Debería ser: '&'
# Predicción para '&': SIN PREDICCIÓN. Debería ser: 'lt'
# Predicción para 'lt': 'qtr'. Debería ser: ';'
# Predicción para ';': SIN PREDICCIÓN. Debería ser: 'taiwan'
# Predicción para 'taiwan': 'to'. Debería ser: 'safe'
# Predicción para 'safe': 'the'. Debería ser: 'group'
# Predicción para 'group': 'it'. Debería ser: '>'
# Predicción para '>': SIN PREDICCIÓN. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'senior'
# Predicción para 'senior': 'said'. Debería ser: 'official'
# Predicción para 'official': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'south'
# Predicción para 'south': 'the'. Debería ser: 'korea'
# Predicción para 'korea': 'to'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'promotion'
# Predicción para 'promotion': 'said'. Debería ser: 'association'
# Predicción para 'association': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'dispute'
# Predicción para 'dispute': 'u.s.'. Debería ser: 'between'
# Predicción para 'between': 'and'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'might'
# Predicción para 'might': 'to'. Debería ser: 'also'
# Predicción para 'also': 'the'. Debería ser: 'lead'
# Predicción para 'lead': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'pressure'
# Predicción para 'pressure': 'to'. Debería ser: 'on'
# Predicción para 'on': 'of'. Debería ser: 'south'
# Predicción para 'south': 'the'. Debería ser: 'korea'
# Predicción para 'korea': 'to'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'whose'
# Predicción para 'whose': 'is'. Debería ser: 'chief'
# Predicción para 'chief': 'of'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'similar'
# Predicción para 'similar': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'those'
# Predicción para 'those': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'last'
# Predicción para 'last': 'the'. Debería ser: 'year'
# Predicción para 'year': 'the'. Debería ser: 'south'
# Predicción para 'south': 'the'. Debería ser: 'korea'
# Predicción para 'korea': 'to'. Debería ser: 'had'
# Predicción para 'had': 'to'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'surplus'
# Predicción para 'surplus': 'billion'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: '7.1'
# Predicción para '7.1': 'pay'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'with'
# Predicción para 'with': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'up'
# Predicción para 'up': 'mln'. Debería ser: 'from'
# Predicción para 'from': 'in'. Debería ser: '4.9'
# Predicción para '4.9': 'in'. Debería ser: 'billion'
# Predicción para 'billion': 'billion'. Debería ser: 'dlrs'
# Predicción para 'dlrs': 'dlrs'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: '1985.'
# Predicción para '1985.': 'said'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'malaysia'
# Predicción para 'malaysia': 'oil'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'officers'
# Predicción para 'officers': 'said'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'tough'
# Predicción para 'tough': 'said'. Debería ser: 'curbs'
# Predicción para 'curbs': 'exports'. Debería ser: 'against'
# Predicción para 'against': 'in'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'might'
# Predicción para 'might': 'to'. Debería ser: 'allow'
# Predicción para 'allow': 'to'. Debería ser: 'hard-hit'
# Predicción para 'hard-hit': 'semiconductors'. Debería ser: 'producers'
# Predicción para 'producers': 'to'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'markets'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'third'
# Predicción para 'third': 'the'. Debería ser: 'countries'
# Predicción para 'countries': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'expand'
# Predicción para 'expand': 'the'. Debería ser: 'their'
# Predicción para 'their': 'the'. Debería ser: 'sales'
# Predicción para 'sales': 'vs'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'the'. Debería ser: 'kong'
# Predicción para 'kong': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'where'
# Predicción para 'where': 'the'. Debería ser: 'newspapers'
# Predicción para 'newspapers': 'the'. Debería ser: 'have'
# Predicción para 'have': 'to'. Debería ser: 'alleged'
# Predicción para 'alleged': 'live'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'has'
# Predicción para 'has': 'to'. Debería ser: 'been'
# Predicción para 'been': 'the'. Debería ser: 'selling'
# Predicción para 'selling': 'to'. Debería ser: 'below-cost'
# Predicción para 'below-cost': 'electronics'. Debería ser: 'semiconductors'
# Predicción para 'semiconductors': 'markets'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'some'
# Predicción para 'some': 'the'. Debería ser: 'electronics'
# Predicción para 'electronics': 'it'. Debería ser: 'manufacturers'
# Predicción para 'manufacturers': 'co'. Debería ser: 'share'
# Predicción para 'share': 'of'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'view'
# Predicción para 'view': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'but'
# Predicción para 'but': 'the'. Debería ser: 'other'
# Predicción para 'other': 'the'. Debería ser: 'businessmen'
# Predicción para 'businessmen': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'such'
# Predicción para 'such': 'and'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'short-term'
# Predicción para 'short-term': 'rates'. Debería ser: 'commercial'
# Predicción para 'commercial': 'the'. Debería ser: 'advantage'
# Predicción para 'advantage': '``'. Debería ser: 'would'
# Predicción para 'would': 'to'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'outweighed'
# Predicción para 'outweighed': 'u.s.'. Debería ser: 'by'
# Predicción para 'by': 'of'. Debería ser: 'further'
# Predicción para 'further': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'pressure'
# Predicción para 'pressure': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'block'
# Predicción para 'block': 'the'. Debería ser: 'imports'
# Predicción para 'imports': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'very'
# Predicción para 'very': 'the'. Debería ser: 'short-term'
# Predicción para 'short-term': 'rates'. Debería ser: 'view'
# Predicción para 'view': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'lawrence'
# Predicción para 'lawrence': 'the'. Debería ser: 'mills'
# Predicción para 'mills': 'it'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'director-general'
# Predicción para 'director-general': 'federation'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'federation'
# Predicción para 'federation': 'organisations'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'the'. Debería ser: 'kong'
# Predicción para 'kong': 'the'. Debería ser: 'industry'
# Predicción para 'industry': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'if'
# Predicción para 'if': 'to'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'whole'
# Predicción para 'whole': 'the'. Debería ser: 'purpose'
# Predicción para 'purpose': 'said'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'prevent'
# Predicción para 'prevent': 'from'. Debería ser: 'imports'
# Predicción para 'imports': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'one'
# Predicción para 'one': 'the'. Debería ser: 'day'
# Predicción para 'day': 'said'. Debería ser: 'it'
# Predicción para 'it': 'the'. Debería ser: 'will'
# Predicción para 'will': 'to'. Debería ser: 'be'
# Predicción para 'be': 'the'. Debería ser: 'extended'
# Predicción para 'extended': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'other'
# Predicción para 'other': 'the'. Debería ser: 'sources'
# Predicción para 'sources': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'much'
# Predicción para 'much': 'the'. Debería ser: 'more'
# Predicción para 'more': 'the'. Debería ser: 'serious'
# Predicción para 'serious': 'the'. Debería ser: 'for'
# Predicción para 'for': 'of'. Debería ser: 'hong'
# Predicción para 'hong': 'the'. Debería ser: 'kong'
# Predicción para 'kong': 'the'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'disadvantage'
# Predicción para 'disadvantage': 'said'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'action'
# Predicción para 'action': 'the'. Debería ser: 'restraining'
# Predicción para 'restraining': 'mark'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'the'. Debería ser: 'he'
# Predicción para 'he': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'last'
# Predicción para 'last': 'the'. Debería ser: 'year'
# Predicción para 'year': 'the'. Debería ser: 'was'
# Predicción para 'was': 'the'. Debería ser: 'hong'
# Predicción para 'hong': 'the'. Debería ser: 'kong'
# Predicción para 'kong': 'the'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'biggest'
# Predicción para 'biggest': 'in'. Debería ser: 'export'
# Predicción para 'export': 'the'. Debería ser: 'market'
# Predicción para 'market': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'accounting'
# Predicción para 'accounting': 'pct'. Debería ser: 'for'
# Predicción para 'for': 'of'. Debería ser: 'over'
# Predicción para 'over': 'of'. Debería ser: '30'
# Predicción para '30': 'the'. Debería ser: 'pct'
# Predicción para 'pct': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'domestically'
# Predicción para 'domestically': 'the'. Debería ser: 'produced'
# Predicción para 'produced': 'of'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'australian'
# Predicción para 'australian': 'to'. Debería ser: 'government'
# Predicción para 'government': 'to'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'awaiting'
# Predicción para 'awaiting': 'of'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'outcome'
# Predicción para 'outcome': 'talks'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'talks'
# Predicción para 'talks': 'the'. Debería ser: 'between'
# Predicción para 'between': 'and'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'with'
# Predicción para 'with': 'of'. Debería ser: 'interest'
# Predicción para 'interest': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'concern'
# Predicción para 'concern': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'industry'
# Predicción para 'industry': 'the'. Debería ser: 'minister'
# Predicción para 'minister': 'said'. Debería ser: 'john'
# Predicción para 'john': 'in'. Debería ser: 'button'
# Predicción para 'button': 'canberra'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'canberra'
# Predicción para 'canberra': '``'. Debería ser: 'last'
# Predicción para 'last': 'the'. Debería ser: 'friday'
# Predicción para 'friday': 'said'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: '``'
# Predicción para '``': ''''. Debería ser: 'this'
# Predicción para 'this': 'the'. Debería ser: 'kind'
# Predicción para 'kind': 'we'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'deterioration'
# Predicción para 'deterioration': 'trade'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'relations'
# Predicción para 'relations': 'u.s.'. Debería ser: 'between'
# Predicción para 'between': 'and'. Debería ser: 'two'
# Predicción para 'two': 'the'. Debería ser: 'countries'
# Predicción para 'countries': 'to'. Debería ser: 'which'
# Predicción para 'which': 'to'. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'major'
# Predicción para 'major': 'the'. Debería ser: 'trading'
# Predicción para 'trading': 'the'. Debería ser: 'partners'
# Predicción para 'partners': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'ours'
# Predicción para 'ours': 'very'. Debería ser: 'is'
# Predicción para 'is': 'the'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'very'
# Predicción para 'very': 'the'. Debería ser: 'serious'
# Predicción para 'serious': 'the'. Debería ser: 'matter'
# Predicción para 'matter': 'before'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: ''''
# Predicción para '''': 'the'. Debería ser: 'button'
# Predicción para 'button': 'canberra'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'he'
# Predicción para 'he': 'the'. Debería ser: 'said'
# Predicción para 'said': 'the'. Debería ser: 'australia'
# Predicción para 'australia': 'the'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'concerns'
# Predicción para 'concerns': 'the'. Debería ser: 'centred'
# Predicción para 'centred': 'and'. Debería ser: 'on'
# Predicción para 'on': 'of'. Debería ser: 'coal'
# Predicción para 'coal': 'and'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'beef'
# Predicción para 'beef': 'the'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'australia'
# Predicción para 'australia': 'the'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'two'
# Predicción para 'two': 'the'. Debería ser: 'largest'
# Predicción para 'largest': 'the'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'also'
# Predicción para 'also': 'the'. Debería ser: 'significant'
# Predicción para 'significant': 'the'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'exports'
# Predicción para 'exports': 'to'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'that'
# Predicción para 'that': 'the'. Debería ser: 'country'
# Predicción para 'country': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'meanwhile'
# Predicción para 'meanwhile': 'today'. Debería ser: 'u.s.-japanese'
# Predicción para 'u.s.-japanese': 'july'. Debería ser: 'diplomatic'
# Predicción para 'diplomatic': 'they'. Debería ser: 'manoeuvres'
# Predicción para 'manoeuvres': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'solve'
# Predicción para 'solve': 'problems'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'stand-off'
# Predicción para 'stand-off': ''s'. Debería ser: 'continue'
# Predicción para 'continue': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'ruling'
# Predicción para 'ruling': 'party'. Debería ser: 'liberal'
# Predicción para 'liberal': 'ldp'. Debería ser: 'democratic'
# Predicción para 'democratic': 'byrd'. Debería ser: 'party'
# Predicción para 'party': 'the'. Debería ser: 'yesterday'
# Predicción para 'yesterday': 'the'. Debería ser: 'outlined'
# Predicción para 'outlined': 'louvre'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'package'
# Predicción para 'package': 'the'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'economic'
# Predicción para 'economic': 'the'. Debería ser: 'measures'
# Predicción para 'measures': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'boost'
# Predicción para 'boost': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'japanese'
# Predicción para 'japanese': 'the'. Debería ser: 'economy'
# Predicción para 'economy': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'measures'
# Predicción para 'measures': 'the'. Debería ser: 'proposed'
# Predicción para 'proposed': 'the'. Debería ser: 'include'
# Predicción para 'include': 'of'. Debería ser: 'a'
# Predicción para 'a': 'the'. Debería ser: 'large'
# Predicción para 'large': 'the'. Debería ser: 'supplementary'
# Predicción para 'supplementary': 'those'. Debería ser: 'budget'
# Predicción para 'budget': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'record'
# Predicción para 'record': 'the'. Debería ser: 'public'
# Predicción para 'public': 'the'. Debería ser: 'works'
# Predicción para 'works': 'the'. Debería ser: 'spending'
# Predicción para 'spending': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'first'
# Predicción para 'first': 'of'. Debería ser: 'half'
# Predicción para 'half': 'year'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'financial'
# Predicción para 'financial': 'the'. Debería ser: 'year'
# Predicción para 'year': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'they'
# Predicción para 'they': 'to'. Debería ser: 'also'
# Predicción para 'also': 'the'. Debería ser: 'call'
# Predicción para 'call': 'to'. Debería ser: 'for'
# Predicción para 'for': 'of'. Debería ser: 'stepped-up'
# Predicción para 'stepped-up': 'an'. Debería ser: 'spending'
# Predicción para 'spending': 'the'. Debería ser: 'as'
# Predicción para 'as': 'of'. Debería ser: 'an'
# Predicción para 'an': 'of'. Debería ser: 'emergency'
# Predicción para 'emergency': 'the'. Debería ser: 'measure'
# Predicción para 'measure': 'supply'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'stimulate'
# Predicción para 'stimulate': 'and'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'economy'
# Predicción para 'economy': 'the'. Debería ser: 'despite'
# Predicción para 'despite': 'in'. Debería ser: 'prime'
# Predicción para 'prime': 'nakasone'. Debería ser: 'minister'
# Predicción para 'minister': 'said'. Debería ser: 'yasuhiro'
# Predicción para 'yasuhiro': 'a'. Debería ser: 'nakasone'
# Predicción para 'nakasone': 'to'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'avowed'
# Predicción para 'avowed': 'program'. Debería ser: 'fiscal'
# Predicción para 'fiscal': 'march'. Debería ser: 'reform'
# Predicción para 'reform': '1986'. Debería ser: 'program'
# Predicción para 'program': 'the'. Debería ser: '.'
# Predicción para '.': SIN PREDICCIÓN. Debería ser: 'deputy'
# Predicción para 'deputy': 'of'. Debería ser: 'u.s.'
# Predicción para 'u.s.': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'representative'
# Predicción para 'representative': 'said'. Debería ser: 'michael'
# Predicción para 'michael': 'he'. Debería ser: 'smith'
# Predicción para 'smith': 'upham'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'makoto'
# Predicción para 'makoto': 'the'. Debería ser: 'kuroda'
# Predicción para 'kuroda': 'u.s.'. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'japan'
# Predicción para 'japan': 'to'. Debería ser: ''s'
# Predicción para ''s': 'the'. Debería ser: 'deputy'
# Predicción para 'deputy': 'of'. Debería ser: 'minister'
# Predicción para 'minister': 'said'. Debería ser: 'of'
# Predicción para 'of': 'the'. Debería ser: 'international'
# Predicción para 'international': 'the'. Debería ser: 'trade'
# Predicción para 'trade': 'the'. Debería ser: 'and'
# Predicción para 'and': 'the'. Debería ser: 'industry'
# Predicción para 'industry': 'the'. Debería ser: '('
# Predicción para '(': SIN PREDICCIÓN. Debería ser: 'miti'
# Predicción para 'miti': 'to'. Debería ser: ')'
# Predicción para ')': SIN PREDICCIÓN. Debería ser: ','
# Predicción para ',': SIN PREDICCIÓN. Debería ser: 'are'
# Predicción para 'are': 'the'. Debería ser: 'due'
# Predicción para 'due': 'in'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'meet'
# Predicción para 'meet': 'to'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'washington'
# Predicción para 'washington': 'the'. Debería ser: 'this'
# Predicción para 'this': 'the'. Debería ser: 'week'
# Predicción para 'week': 'the'. Debería ser: 'in'
# Predicción para 'in': 'the'. Debería ser: 'an'
# Predicción para 'an': 'of'. Debería ser: 'effort'
# Predicción para 'effort': 'the'. Debería ser: 'to'
# Predicción para 'to': 'the'. Debería ser: 'end'
# Predicción para 'end': 'year'. Debería ser: 'the'
# Predicción para 'the': 'the'. Debería ser: 'dispute'
#
# Aciertos: 25/809 = 3.09%

# %% [markdown]
# * **Realizar una generación de texto comenzando en dos diferentes *seeds*.**

# %%
import numpy as np

# Función para que los modelos generen texto de forma automática
def generar_texto(seed, model, n, total_len=25):
    """
    Genera texto a partir de un seed dado utilizando un modelo entrenado.
    
    :param seed: Semilla inicial de n-1 palabras (tupla)
    :param model: Modelo entrenado de n-gramas
    :param n: Tamaño del n-grama
    :param total_len: Longitud total del texto a generar (número de palabras)
    """
    word_tuple = seed
    pos = 0
    
    # Imprimir el seed
    print(" ".join(word_tuple), end=' ')
    
    # Generar texto
    while pos < total_len:
        next_word = predict_next_word(model, " ".join(word_tuple), n)
        
        if not next_word:
            break  # Si no hay predicción, detener la generación de texto
        
        print(next_word, end=' ')
        word_tuple = word_tuple[1:] + (next_word,)  # Actualizar el tuple de palabras
        pos += 1
    
    print("\n")  # Salto de línea al final del texto generado

# %%
# Modelo 2-grama con signos de puntuación (semilla 1)
print("Texto generado con 2-grama con signos de puntuación (semilla 1):")
seed_bigram = list(bigram_model_with_punctuation.keys())[90][:1]  # Obtener 1 palabra del propio vocabulario del modelo
generar_texto(seed_bigram, bigram_model_with_punctuation, 2)

# Modelo 2-grama con signos de puntuación (semilla 2)
print("Texto generado con 2-grama con signos de puntuación (semilla 2):")
seed_bigram = list(bigram_model_with_punctuation.keys())[94][:1]  # Obtener 1 palabra del propio vocabulario del modelo
generar_texto(seed_bigram, bigram_model_with_punctuation, 2)
# Out:
# Texto generado con 2-grama con signos de puntuación (semilla 1):
# semiconductors . the company said . the company said . the company said . the company said . the company said . the company said .
#
# Texto generado con 2-grama con signos de puntuación (semilla 2):
# below the company said . the company said . the company said . the company said . the company said . the company said . the

# %%
# Modelo 2-grama sin signos de puntuación (semilla 1)
print("Texto generado con 2-grama sin signos de puntuación (semilla 1):")
seed_bigram = list(bigram_model_without_punctuation.keys())[90][:1]  # Obtener 1 palabra del propio vocabulario del modelo
generar_texto(seed_bigram, bigram_model_with_punctuation, 2)

# Modelo 2-grama sin signos de puntuación (semilla 2)
print("Texto generado con 2-grama sin signos de puntuación (semilla 2):")
seed_bigram = list(bigram_model_without_punctuation.keys())[94][:1]  # Obtener 1 palabra del propio vocabulario del modelo
generar_texto(seed_bigram, bigram_model_with_punctuation, 2)
# Out:
# Texto generado con 2-grama sin signos de puntuación (semilla 1):
# markets . the company said . the company said . the company said . the company said . the company said . the company said .
#
# Texto generado con 2-grama sin signos de puntuación (semilla 2):
# unofficial targets for the company said . the company said . the company said . the company said . the company said . the company said

# %%
# Modelo 4-grama con signos de puntuación (semilla 1)
print("Texto generado con 4-grama con signos de puntuación (semilla 1):")
seed_fourgram = list(fourgram_model_with_punctuation.keys())[90][:3]  # Obtener 3 palabras del propio vocabulario del modelo
generar_texto(seed_fourgram, fourgram_model_with_punctuation, 4)

# Modelo 4-grama con signos de puntuación (semilla 2)
print("Texto generado con 4-grama con signos de puntuación (semilla 2):")
seed_fourgram = list(fourgram_model_with_punctuation.keys())[94][:3]  # Obtener 3 palabras del propio vocabulario del modelo
generar_texto(seed_fourgram, fourgram_model_with_punctuation, 4)
# Out:
# Texto generado con 4-grama con signos de puntuación (semilla 1):
# be their gain . the u.s. has been pressing west germany to stimulate economic growth and therefore an expansion of the cape spencer deposit had 200,000 tons .
#
# Texto generado con 4-grama con signos de puntuación (semilla 2):
# the u.s. has been pressing west germany to stimulate economic growth and therefore an expansion of the cape spencer deposit had 200,000 tons . gordex said the expansion

# %%
# Modelo 4-grama sin signos de puntuación (semilla 1)
print("Texto generado sin 4-grama con signos de puntuación (semilla 1):")
seed_fourgram = list(fourgram_model_without_punctuation.keys())[90][:3]  # Obtener 3 palabras del propio vocabulario del modelo
generar_texto(seed_fourgram, fourgram_model_with_punctuation, 4)

# Modelo 4-grama sin signos de puntuación (semilla 2)
print("Texto generado sin 4-grama con signos de puntuación (semilla 2):")
seed_fourgram = list(fourgram_model_without_punctuation.keys())[94][:3]  # Obtener 3 palabras del propio vocabulario del modelo
generar_texto(seed_fourgram, fourgram_model_with_punctuation, 4)
# Out:
# Texto generado sin 4-grama con signos de puntuación (semilla 1):
# u.s. has said it is in talks with the world bank and the international monetary fund ( imf ) to reduce the deficit , such as the sharp
#
# Texto generado sin 4-grama con signos de puntuación (semilla 2):
# will impose 300 mln dlrs in the first quarter of 1987 , the company said . the company said . the company said . the company said .

# %%
# Modelo 2-skip-2-grama con signos de puntuación (semilla 1)
print("Texto generado con 2-skip-2-grama con signos de puntuación:")
seed_skip_2_gram = list(skip_2_gram_model_with_punctuation.keys())[90][:1]  # Obtener 1 palabra del propio vocabulario del modelo
generar_texto(seed_skip_2_gram, skip_2_gram_model_with_punctuation, 2)

# Modelo 2-skip-2-grama con signos de puntuación (semilla 1)
print("Texto generado con 2-skip-2-grama con signos de puntuación:")
seed_skip_2_gram = list(skip_2_gram_model_with_punctuation.keys())[94][:1]  # Obtener 1 palabra del propio vocabulario del modelo
generar_texto(seed_skip_2_gram, skip_2_gram_model_with_punctuation, 2)
# Out:
# Texto generado con 2-skip-2-grama con signos de puntuación:
# official the the the the the the the the the the the the the the the the the the the the the the the the the
#
# Texto generado con 2-skip-2-grama con signos de puntuación:
# also the the the the the the the the the the the the the the the the the the the the the the the the the

# %%
# Modelo 2-skip-2-grama sin signos de puntuación (semilla 1)
print("Texto generado sin 2-skip-2-grama con signos de puntuación:")
seed_skip_2_gram = list(skip_2_gram_model_without_punctuation.keys())[90][:1]  # Obtener 1 palabra del propio vocabulario del modelo
generar_texto(seed_skip_2_gram, skip_2_gram_model_with_punctuation, 2)

# Modelo 2-skip-2-grama sin signos de puntuación (semilla 1)
print("Texto generado con 2-skip-2-grama sin signos de puntuación:")
seed_skip_2_gram = list(skip_2_gram_model_without_punctuation.keys())[94][:1]  # Obtener 1 palabra del propio vocabulario del modelo
generar_texto(seed_skip_2_gram, skip_2_gram_model_with_punctuation, 2)
# Out:
# Texto generado sin 2-skip-2-grama con signos de puntuación:
# pressure to , said the the the the the the the the the the the the the the the the the the the the the the
#
# Texto generado con 2-skip-2-grama sin signos de puntuación:
# malaysia , said the the the the the the the the the the the the the the the the the the the the the the the

# %% [markdown]
# ⭕ Discutir y redactar un reporte (en el mismo notebook) abordando los siguientes puntos:
#
# **1. ¿Qué modelo de los 6 logró mejores predicciones?**

# %% [markdown]
# En términos de precisión, los modelos de bigramas (2-gramas) con y sin signos de puntuación lograron las mejores predicciones, aunque sus tasas de aciertos fueron relativamente bajas (alrededor del 20.77% y 18.67%, respectivamente). Esto sugiere que, a pesar de las limitaciones inherentes a los bigramas, estos modelos fueron los más efectivos en capturar relaciones locales entre palabras en el corpus utilizado.

# %% [markdown]
# **2. ¿Qué modelo de los 6 tenía más problemas generando predicciones?**

# %% [markdown]
# Los modelos de 4-gramas, tanto con como sin signos de puntuación, presentaron serios problemas en la generación de predicciones, con una tasa de aciertos del 0%. Este comportamiento indica que los 4-gramas no fueron capaces de encontrar coincidencias adecuadas en el texto de prueba, lo que podría deberse a la falta de suficiente cobertura de los n-gramas en el corpus de entrenamiento o a una sobreespecificidad de los modelos que no pudo generalizar bien en el texto de prueba.

# %% [markdown]
# **3. ¿Qué efecto tiene el tipo de corpus en la construcción y desempeño del modelo?**

# %% [markdown]
# El tipo de corpus tiene un impacto significativo en la construcción y desempeño de los modelos de n-gramas. El corpus Reuters, utilizado en este ejercicio, es un conjunto de noticias financieras con un lenguaje específico y ciertas frases repetitivas, como "the company said". Esto explica por qué los bigramas tuvieron un rendimiento relativamente mejor: pudieron capturar estas frases repetidas. Sin embargo, la especificidad del corpus también significa que los modelos más complejos como los 4-gramas o los skip-gramas pueden carecer de suficiente información contextual en el entrenamiento para hacer predicciones precisas. Además, la repetitividad en el corpus puede llevar a que los modelos generen texto que simplemente repite las frases más comunes sin aportar nueva información.

# %% [markdown]
# **4. ¿Qué podríamos hacer para incrementar los aciertos?**

# %% [markdown]
# Para mejorar el rendimiento de los modelos de n-gramas, podríamos considerar varias estrategias:
#
# * **Aumentar el tamaño del corpus:** Un corpus más grande y diverso podría proporcionar una mejor cobertura de los posibles n-gramas y reducir la especificidad excesiva, permitiendo que los modelos generalicen mejor.
#
# * **Mejorar la preprocesamiento del texto:** Limpiar y normalizar el texto de manera más efectiva, como la eliminación de palabras muy comunes o el manejo de sinónimos, podría ayudar a mejorar la calidad de las predicciones.
#
# * **Incorporar técnicas de suavizado:** Técnicas como el suavizado de Laplace pueden ayudar a lidiar con el problema de la falta de cobertura en el modelo, asignando una probabilidad mínima a n-gramas no vistos.
